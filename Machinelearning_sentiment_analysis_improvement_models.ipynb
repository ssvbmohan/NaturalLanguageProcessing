# %% [markdown]
# ## Machine learning models built on 3000 reviews pulled from 4000 reviews in such a way that all the negative reviews are present in the 3000 reviews along with the remaining to be positive.

# %% [markdown]
# ## Machine learning models built are:
#  ### 1. logistic regression using count vectorizer on raw data(69% f1-score on test data)
#  ### 2. logistic regression using tfidf vectorizer on raw data (73% f1-score on test data)
#  ### 3. logistic regression using count vectorier on preprocessed review
#  ### 4. logistic regression using tfidf vectorizer on preprocessed review
#  ### 5. Random forest on pre processed review
#  ### 6. svm_grid search using count vectorizer on raw data
#  ### 7. svm_grid search using tfidf vectorizer on raw data(78% f1 score)

# %% [markdown]
# ## Initial Imports

# %%
import requests
import time

# %% [markdown]
# ## Creating header for review

# %%
headers = {'Referer':'https://www.rottentomatoes.com/m/the_lion_king_2019/reviews?type=user','User-Agent':'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/74.0.3729.108 Safari/537.36','X-Requested-With':'XMLHttpRequest',}

# %%
headers
# Out:
# {'Referer': 'https://www.rottentomatoes.com/m/the_lion_king_2019/reviews?type=user',
#  'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/74.0.3729.108 Safari/537.36',
#  'X-Requested-With': 'XMLHttpRequest'}

# %%
url ='https://www.rottentomatoes.com/napi/movie/9057c2cf-7cab-317f-876f-e50b245ca76e/reviews/user'

# %% [markdown]
# ## Initial payload parameters

# %%
payload = {'direction': 'next','endCursor': '','startCursor': ''}

# %% [markdown]
# ## Creating session Object

# %%
s = requests.Session()

# %% [markdown]
# ## Code to fetch 1page review

# %%
r = s.get(url, headers=headers, params=payload)    # GET Call 
data = r.json()

# %%
data
# Out:
# {'pageInfo': {'hasNextPage': True,
#   'hasPreviousPage': False,
#   'endCursor': 'eyJyZWFsbV91c2VySWQiOiJSVF84ODM5MDExNDAiLCJlbXNJZCI6IjkwNTdjMmNmLTdjYWItMzE3Zi04NzZmLWU1MGIyNDVjYTc2ZSIsImVtc0lkX2hhc1Jldmlld0lzVmlzaWJsZSI6IjkwNTdjMmNmLTdjYWItMzE3Zi04NzZmLWU1MGIyNDVjYTc2ZV9UIiwiY3JlYXRlRGF0ZSI6IjIwMTktMDgtMjdUMTg6Mzg6NDQuOTIzWiJ9',
#   'startCursor': None},
#  'reviews': [{'rating': 'STAR_2_5',
#    'review': "almost shot for shot. scar is a very weak character in this and trying to be too realistic you lose the magic of the original. it's safe. tilmon and pumba get the most laughs as they also have the most change.",
#    'displayName': None,
#    'displayImageUrl': None,
#    'isVerified': False,
#    'isSuperReviewer': False,
#    'hasSpoilers': False,
#    'hasProfanity': False,
#    'createDate': '2019-08-27T21:39:31.395Z',
#    'updateDate': '2019-08-27T21:39:31.395Z',
#    'user': {'userId': '260316344',
#     'realm': 'RT',
#     'displayName': None,
#     'accountLink': '/user/id/260316344'},
#    'score': 2.5,
#    'timeFromCreation': '23m ago'},
#   {'rating': 'STAR_5',
#    'review': 'Loved the movie! Great CGI, acting, music, felt like I was watching the original all over again! I could go on and on but it’s a great family film! HIGHLY RECOMMEND',
#    'displayName': 'Logan',
#    'displayImageUrl': None,
#    'isVerified': True,
#    'isSuperReviewer': False,
#    'hasSpoilers': False,
#    'hasProfanity': False,
#    'createDate': '2019-08-27T21:13:12.178Z',
#    'updateDate': '2019-08-27T21:13:12.178Z',
#    'user': {'userId': '02750CCE-D2AB-4E3B-A998-6576C1A240E0',
#     'realm': 'Fandango',
#     'displayName': 'Logan',
#     'accountLink': None},
#    'score': 5,
#    'timeFromCreation': '49m ago'},
#   {'rating': 'STAR_3',
#    'review': "If you grew up with (and love) the original animated version, you're not missing out. The live action animals were cute though.  As with the original, Timon & Pumba steal the show.",
#    'displayName': 'Rachel C',
#    'displayImageUrl': 'https://graph.facebook.com/v3.3/10221590382855950/picture',
#    'isVerified': False,
#    'isSuperReviewer': False,
#    'hasSpoilers': False,
#    'hasProfanity': False,
#    'createDate': '2019-08-27T20:58:51.447Z',
#    'updateDate': '2019-08-27T20:58:51.447Z',
#    'user': {'userId': '978214951',
#     'realm': 'RT',
#     'displayName': 'Rachel C',
#     'accountLink': '/user/id/978214951'},
#    'score': 3,
#    'timeFromCreation': '1h ago'},
#   {'rating': 'STAR_2_5',
#    'review': 'While it can take pride in its visual achievements, The Lion King is a by-the-numbers retelling that lacks the energy and heart that made the original so beloved-though for some fans that may just be enough.',
#    'displayName': 'Peter J',
#    'displayImageUrl': None,
#    'isVerified': False,
#    'isSuperReviewer': False,
#    'hasSpoilers': False,
#    'hasProfanity': False,
#    'createDate': '2019-08-27T20:27:50.707Z',
#    'updateDate': '2019-08-27T20:27:54.169Z',
#    'user': {'userId': '977694797',
#     'realm': 'RT',
#     'displayName': 'Peter J',
#     'accountLink': '/user/id/977694797'},
#    'score': 2.5,
#    'timeFromCreation': '2h ago'},
#   {'rating': 'STAR_5',
#    'review': 'It was seriously a stunning movie. Great graphics. Crisp. Adorable movie.',
#    'displayName': 'Devon',
#    'displayImageUrl': None,
#    'isVerified': True,
#    'isSuperReviewer': False,
#    'hasSpoilers': False,
#    'hasProfanity': False,
#    'createDate': '2019-08-27T20:15:05.755Z',
#    'updateDate': '2019-08-27T20:15:05.755Z',
#    'user': {'userId': 'AC172773-33D5-466B-8E82-C5178AB51CAF',
#     'realm': 'Fandango',
#     'displayName': 'Devon',
#     'accountLink': None},
#    'score': 5,
#    'timeFromCreation': '2h ago'},
#   {'rating': 'STAR_5',
#    'review': "I loved this remake. The cartoon is one of my favorite movies and this remake was extremely similar to the cartoon version. I'd say it matches like 90%, scene for scene and dialogue. It's almost like watching an episode of animal planet...but with singing animals and intense drama. I thought it did a phenomenal job sticking to the original while at the same time making some changes.  ",
#    'displayName': 'Samantha T',
#    'displayImageUrl': 'https://graph.facebook.com/v3.3/100001784076128/picture',
#    'isVerified': False,
#    'isSuperReviewer': False,
#    'hasSpoilers': False,
#    'hasProfanity': False,
#    'createDate': '2019-08-27T20:10:24.720Z',
#    'updateDate': '2019-08-27T20:10:24.720Z',
#    'user': {'userId': '923215533',
#     'realm': 'RT',
#     'displayName': 'Samantha T',
#     'accountLink': '/user/id/923215533'},
#    'score': 5,
#    'timeFromCreation': '2h ago'},
#   {'rating': 'STAR_2',
#    'review': 'the only thing i thought was a great scene was the fighting scenes. i dont think it beat the original in anyway',
#    'displayName': 'saiyanelite',
#    'displayImageUrl': None,
#    'isVerified': True,
#    'isSuperReviewer': False,
#    'hasSpoilers': False,
#    'hasProfanity': False,
#    'createDate': '2019-08-27T19:41:11.714Z',
#    'updateDate': '2019-08-27T19:42:52.104Z',
#    'user': {'userId': 'd452e337-0bf3-4df6-9a73-a37d5c2cfb94',
#     'realm': 'Fandango',
#     'displayName': 'saiyanelite',
#     'accountLink': None},
#    'score': 2,
#    'timeFromCreation': '2h ago'},
#   {'rating': 'STAR_5',
#    'review': 'Good movie, we enjoyed it a lot',
#    'displayName': 'Lisa',
#    'displayImageUrl': None,
#    'isVerified': True,
#    'isSuperReviewer': False,
#    'hasSpoilers': False,
#    'hasProfanity': False,
#    'createDate': '2019-08-27T19:39:19.611Z',
#    'updateDate': '2019-08-27T19:39:19.611Z',
#    'user': {'userId': '7aec84e7-5aec-418c-ac92-31e3fbdbe81e',
#     'realm': 'Fandango',
#     'displayName': 'Lisa',
#     'accountLink': None},
#    'score': 5,
#    'timeFromCreation': '2h ago'},
#   {'rating': 'STAR_3',
#    'review': 'I liked it, my kids loved it. I prefer the original -- my kinds asked "There\'s an original!?!?" Parenting fail.',
#    'displayName': 'Levy M',
#    'displayImageUrl': 'https://graph.facebook.com/v3.3/1112244759/picture',
#    'isVerified': False,
#    'isSuperReviewer': False,
#    'hasSpoilers': False,
#    'hasProfanity': False,
#    'createDate': '2019-08-27T19:03:20.510Z',
#    'updateDate': '2019-08-27T19:03:20.510Z',
#    'user': {'userId': '823571697',
#     'realm': 'RT',
#     'displayName': 'Levy M',
#     'accountLink': '/user/id/823571697'},
#    'score': 3,
#    'timeFromCreation': '3h ago'},
#   {'rating': 'STAR_2',
#    'review': '😁I just saw the Lion King and I have to say.........\nI was bored out of my mind. It\'s rant time:\n\n😟Hear me out! The animators were the shit. I have had a peek into the process and know it took a MONSTROUS amount of work to create the characters. You could see the muscles and even the veins!! They did an AMAZING job creating the world and it\'s animals in this movie.\n\n😡However, I\'ve got a lot of beef with this movie. It was like a delicious looking cake that had no flavor and no ice cream on the side. This is Disney, and I want my side of fucking ice cream.\n.\n1) Character design: It looked fantastic and super realistic, but that\'s the problem right there; It looked SOOOO realistic, that the expressions on the characters were nearly non existent. It is possible to create this kind of realism, but still have enough imaginative unrealistic designs that wont clash. Look at Smaug and how Bennedict played that character; it looked real, and the performance is fucking GREAT. Just go look up the youtube vid of him in the motion capture suit.  Without good BODY LANGUAGE AND FACIAL EXPRESSIONS, you could easily tell it was just actors standing in front of a mic and not throwing themselves into the role. \n\n2) Voice Actors: They were also flat as fuck. I was hyped about the cast, so this was really disappointing. The inflections on the lines just didnt come off of the screen. It sounded like all the animals were shitty high school kids that happened to have nice singing voices do their first Lion King play 1 week after getting the script. I was looking forward to that moment where Scar warns Mufasa not to turn his back on him and suddenly Mufasa has this THREATENING voice saying "Is that a challenge?!". That moment came on screen and I was bored (seriously, look at the original). No emotional content. The voice directing was trash.\n\n1+2=3) With one and two combined, it\'s just crap. Emotionless crap. I didnt feel Simba\'s pain or fear when his father died, and I wanted to. When you have super realistic animals, you dont get facial expressions. Combine that with weak voice inflections and I felt nothing. No pauses or moments where you could feel tension or any sort of movement of emotion.\n\n4) Carbon Copy: I KNOW it is a remake, but I feel like they majorly missed an opportunity. They should have dropped every damn song but Hakuna Matata and made more time for character development. I cant believe Scar breaking into song looking like that. \n\nWhat do I mean by character development? I LOVE DC\'s animated movies. Under the Red Hood is fucking dope. However, if you copy that exactly into a live action movie, the characters will likely seem a bit flat. I think when you bring more realism to the screen, you have to care more about your characters. I dont fully know how to explain it. More story to support a character\'s emotional journey is needed the closer it gets to reality I think. Drop the songs and add more scenes or dialogue along those lines and MAYBE I would have felt it more. \n\nThe battle for pride rock mostly sucked. Why copy? You have so much to build on!! What if Scar had a small army of animals that were "protected" going up against Simba and his rebels at the end? What if it was closer to a war? Just a thought...\n\n5) The story boarding was trash. Too much lifted from the original. If you cant use facial expressions, then you need to pick your shots and place your figures (i forget the term for that) better to make the audience feel certain emotions. \nOk, there have been worse, but again...with all this technology, your visual storytelling should have been much better. \n\nThe movie looks fantastic, but I wanted to walk out. I stayed hoping that the final battle or Childish Gambino would rock it. Nope. The original Lion King movie better. \n\nAnyways, rant over. I should have made a youtube vid out of this.',
#    'displayName': 'Xavier P',
#    'displayImageUrl': 'https://graph.facebook.com/v3.3/1320956777/picture',
#    'isVerified': False,
#    'isSuperReviewer': False,
#    'hasSpoilers': False,
#    'hasProfanity': True,
#    'createDate': '2019-08-27T18:38:44.923Z',
#    'updateDate': '2019-08-27T18:38:44.923Z',
#    'user': {'userId': '883901140',
#     'realm': 'RT',
#     'displayName': 'Xavier P',
#     'accountLink': '/user/id/883901140'},
#    'score': 2,
#    'timeFromCreation': '3h ago'}]}

# %% [markdown]
# ## Loop function for pulling out 3000 reviews from 300 pages

# %%
# using 3000 records
theLionKing_reviews=[]
endCursor= ''
startCursor= ''
for i in range(400):
    #payload initialization
    payload = {'direction':'next','endCursor': endCursor ,'startCursor': startCursor ,}
    #time interval of 8secs
    time.sleep(5) 
    #getting the review data in an order.
    r= s.get(url, params=payload, headers=headers)
    data = r.json()
    theLionKing_reviews = theLionKing_reviews + data['reviews']
    endCursor = data['pageInfo']['endCursor']
    startCursor = data['pageInfo']['startCursor']

theLionKing_reviews
# Out:
# [{'rating': 'STAR_2_5',
#   'review': "almost shot for shot. scar is a very weak character in this and trying to be too realistic you lose the magic of the original. it's safe. tilmon and pumba get the most laughs as they also have the most change.",
#   'displayName': None,
#   'displayImageUrl': None,
#   'isVerified': False,
#   'isSuperReviewer': False,
#   'hasSpoilers': False,
#   'hasProfanity': False,
#   'createDate': '2019-08-27T21:39:31.395Z',
#   'updateDate': '2019-08-27T21:39:31.395Z',
#   'user': {'userId': '260316344',
#    'realm': 'RT',
#    'displayName': None,
#    'accountLink': '/user/id/260316344'},
#   'score': 2.5,
#   'timeFromCreation': '24m ago'},
#  {'rating': 'STAR_5',
#   'review': 'Loved the movie! Great CGI, acting, music, felt like I was watching the original all over again! I could go on and on but it’s a great family film! HIGHLY RECOMMEND',
#   'displayName': 'Logan',
#   'displayImageUrl': None,
#   'isVerified': True,
#   'isSuperReviewer': False,
#   'hasSpoilers': False,
#   'hasProfanity': False,
#   'createDate': '2019-08-27T21:13:12.178Z',
#   'updateDate': '2019-08-27T21:13:12.178Z',
#   'user': {'userId': '02750CCE-D2AB-4E3B-A998-6576C1A240E0',
#    'realm': 'Fandango',
#    'displayName': 'Logan',
#    'accountLink': None},
#   'score': 5,
#   'timeFromCreation': '50m ago'},
#  {'rating': 'STAR_3',
#   'review': "If you grew up with (and love) the original animated version, you're not missing out. The live action animals were cute though.  As with the original, Timon & Pumba steal the show.",
#   'displayName': 'Rachel C',
#   'displayImageUrl': 'https://graph.facebook.com/v3.3/10221590382855950/picture',
#   'isVerified': False,
#   'isSuperReviewer': False,
#   'hasSpoilers': False,
#   'hasProfanity': False,
#   'createDate': '2019-08-27T20:58:51.447Z',
#   'updateDate': '2019-08-27T20:58:51.447Z',
#   'user': {'userId': '978214951',
#    'realm': 'RT',
#    'displayName': 'Rachel C',
#    'accountLink': '/user/id/978214951'},
#   'score': 3,
#   'timeFromCreation': '1h ago'},
#  {'rating': 'STAR_2_5',
#   'review': 'While it can take pride in its visual achievements, The Lion King is a by-the-numbers retelling that lacks the energy and heart that made the original so beloved-though for some fans that may just be enough.',
#   'displayName': 'Peter J',
#   'displayImageUrl': None,
#   'isVerified': False,
#   'isSuperReviewer': False,
#   'hasSpoilers': False,
#   'hasProfanity': False,
#   'createDate': '2019-08-27T20:27:50.707Z',
#   'updateDate': '2019-08-27T20:27:54.169Z',
#   'user': {'userId': '977694797',
#    'realm': 'RT',
#    'displayName': 'Peter J',
#    'accountLink': '/user/id/977694797'},
#   'score': 2.5,
#   'timeFromCreation': '2h ago'},
#  {'rating': 'STAR_5',
#   'review': 'It was seriously a stunning movie. Great graphics. Crisp. Adorable movie.',
#   'displayName': 'Devon',
#   'displayImageUrl': None,
#   'isVerified': True,
#   'isSuperReviewer': False,
#   'hasSpoilers': False,
#   'hasProfanity': False,
#   'createDate': '2019-08-27T20:15:05.755Z',
#   'updateDate': '2019-08-27T20:15:05.755Z',
#   'user': {'userId': 'AC172773-33D5-466B-8E82-C5178AB51CAF',
#    'realm': 'Fandango',
#    'displayName': 'Devon',
#    'accountLink': None},
#   'score': 5,
#   'timeFromCreation': '2h ago'},
#  {'rating': 'STAR_5',
#   'review': "I loved this remake. The cartoon is one of my favorite movies and this remake was extremely similar to the cartoon version. I'd say it matches like 90%, scene for scene and dialogue. It's almost like watching an episode of animal planet...but with singing animals and intense drama. I thought it did a phenomenal job sticking to the original while at the same time making some changes.  ",
#   'displayName': 'Samantha T',
#   'displayImageUrl': 'https://graph.facebook.com/v3.3/100001784076128/picture',
#   'isVerified': False,
#   'isSuperReviewer': False,
#   'hasSpoilers': False,
#   'hasProfanity': False,
#   'createDate': '2019-08-27T20:10:24.720Z',
#   'updateDate': '2019-08-27T20:10:24.720Z',
#   'user': {'userId': '923215533',
#    'realm': 'RT',
#    'displayName': 'Samantha T',
#    'accountLink': '/user/id/923215533'},
#   'score': 5,
#   'timeFromCreation': '2h ago'},
#  {'rating': 'STAR_2',
#   'review': 'the only thing i thought was a great scene was the fighting scenes. i dont think it beat the original in anyway',
#   'displayName': 'saiyanelite',
#   'displayImageUrl': None,
#   'isVerified': True,
#   'isSuperReviewer': False,
#   'hasSpoilers': False,
#   'hasProfanity': False,
#   'createDate': '2019-08-27T19:41:11.714Z',
#   'updateDate': '2019-08-27T19:42:52.104Z',
#   'user': {'userId': 'd452e337-0bf3-4df6-9a73-a37d5c2cfb94',
#    'realm': 'Fandango',
#    'displayName': 'saiyanelite',
#    'accountLink': None},
#   'score': 2,
#   'timeFromCreation': '2h ago'},
#  {'rating': 'STAR_5',
#   'review': 'Good movie, we enjoyed it a lot',
#   'displayName': 'Lisa',
#   'displayImageUrl': None,
#   'isVerified': True,
#   'isSuperReviewer': False,
#   'hasSpoilers': False,
#   'hasProfanity': False,
#   'createDate': '2019-08-27T19:39:19.611Z',
#   'updateDate': '2019-08-27T19:39:19.611Z',
#   'user': {'userId': '7aec84e7-5aec-418c-ac92-31e3fbdbe81e',
#    'realm': 'Fandango',
#    'displayName': 'Lisa',
#    'accountLink': None},
#   'score': 5,
#   'timeFromCreation': '2h ago'},
#  {'rating': 'STAR_3',
#   'review': 'I liked it, my kids loved it. I prefer the original -- my kinds asked "There\'s an original!?!?" Parenting fail.',
#   'displayName': 'Levy M',
#   'displayImageUrl': 'https://graph.facebook.com/v3.3/1112244759/picture',
#   'isVerified': False,
#   'isSuperReviewer': False,
#   'hasSpoilers': False,
#   'hasProfanity': False,
#   'createDate': '2019-08-27T19:03:20.510Z',
#   'updateDate': '2019-08-27T19:03:20.510Z',
#   'user': {'userId': '823571697',
#    'realm': 'RT',
#    'displayName': 'Levy M',
#    'accountLink': '/user/id/823571697'},
#   'score': 3,
#   'timeFromCreation': '3h ago'},
#  {'rating': 'STAR_2',
#   'review': '😁I just saw the Lion King and I have to say.........\nI was bored out of my mind. It\'s rant time:\n\n😟Hear me out! The animators were the shit. I have had a peek into the process and know it took a MONSTROUS amount of work to create the characters. You could see the muscles and even the veins!! They did an AMAZING job creating the world and it\'s animals in this movie.\n\n😡However, I\'ve got a lot of beef with this movie. It was like a delicious looking cake that had no flavor and no ice cream on the side. This is Disney, and I want my side of fucking ice cream.\n.\n1) Character design: It looked fantastic and super realistic, but that\'s the problem right there; It looked SOOOO realistic, that the expressions on the characters were nearly non existent. It is possible to create this kind of realism, but still have enough imaginative unrealistic designs that wont clash. Look at Smaug and how Bennedict played that character; it looked real, and the performance is fucking GREAT. Just go look up the youtube vid of him in the motion capture suit.  Without good BODY LANGUAGE AND FACIAL EXPRESSIONS, you could easily tell it was just actors standing in front of a mic and not throwing themselves into the role. \n\n2) Voice Actors: They were also flat as fuck. I was hyped about the cast, so this was really disappointing. The inflections on the lines just didnt come off of the screen. It sounded like all the animals were shitty high school kids that happened to have nice singing voices do their first Lion King play 1 week after getting the script. I was looking forward to that moment where Scar warns Mufasa not to turn his back on him and suddenly Mufasa has this THREATENING voice saying "Is that a challenge?!". That moment came on screen and I was bored (seriously, look at the original). No emotional content. The voice directing was trash.\n\n1+2=3) With one and two combined, it\'s just crap. Emotionless crap. I didnt feel Simba\'s pain or fear when his father died, and I wanted to. When you have super realistic animals, you dont get facial expressions. Combine that with weak voice inflections and I felt nothing. No pauses or moments where you could feel tension or any sort of movement of emotion.\n\n4) Carbon Copy: I KNOW it is a remake, but I feel like they majorly missed an opportunity. They should have dropped every damn song but Hakuna Matata and made more time for character development. I cant believe Scar breaking into song looking like that. \n\nWhat do I mean by character development? I LOVE DC\'s animated movies. Under the Red Hood is fucking dope. However, if you copy that exactly into a live action movie, the characters will likely seem a bit flat. I think when you bring more realism to the screen, you have to care more about your characters. I dont fully know how to explain it. More story to support a character\'s emotional journey is needed the closer it gets to reality I think. Drop the songs and add more scenes or dialogue along those lines and MAYBE I would have felt it more. \n\nThe battle for pride rock mostly sucked. Why copy? You have so much to build on!! What if Scar had a small army of animals that were "protected" going up against Simba and his rebels at the end? What if it was closer to a war? Just a thought...\n\n5) The story boarding was trash. Too much lifted from the original. If you cant use facial expressions, then you need to pick your shots and place your figures (i forget the term for that) better to make the audience feel certain emotions. \nOk, there have been worse, but again...with all this technology, your visual storytelling should have been much better. \n\nThe movie looks fantastic, but I wanted to walk out. I stayed hoping that the final battle or Childish Gambino would rock it. Nope. The original Lion King movie better. \n\nAnyways, rant over. I should have made a youtube vid out of this.',
#   'displayName': 'Xavier P',
#   'displayImageUrl': 'https://graph.facebook.com/v3.3/1320956777/picture',
#   'isVerified': False,
#   'isSuperReviewer': False,
#   'hasSpoilers': False,
#   'hasProfanity': True,
#   'createDate': '2019-08-27T18:38:44.923Z',
#   'updateDate': '2019-08-27T18:38:44.923Z',
#   'user': {'userId': '883901140',
#    'realm': 'RT',
#    'displayName': 'Xavier P',
#    'accountLink': '/user/id/883901140'},
#   'score': 2,
#   'timeFromCreation': '3h ago'},
#  {'rating': 'STAR_2_5',
#   'review': 'Pretty much a shot for shot remake of the classic animated movie. Kinda boring',
#   'displayName': None,
#   'displayImageUrl': None,
#   'isVerified': False,
#   'isSuperReviewer': False,
#   'hasSpoilers': False,
#   'hasProfanity': False,
#   'createDate': '2019-08-27T17:45:03.573Z',
#   'updateDate': '2019-08-27T17:45:03.573Z',
#   'user': {'userId': '976495119',
#    'realm': 'RT',
#    'displayName': None,
#    'accountLink': '/user/id/976495119'},
#   'score': 2.5,
#   'timeFromCreation': '4h ago'},
#  {'rating': 'STAR_3_5',
#   'review': 'although this movie doesent realy add anything to the original film it is still fun to watch.\n',
#   'displayName': 'robin m',
#   'displayImageUrl': None,
#   'isVerified': False,
#   'isSuperReviewer': False,
#   'hasSpoilers': False,
#   'hasProfanity': False,
#   'createDate': '2019-08-27T17:41:24.358Z',
#   'updateDate': '2019-08-27T17:41:24.358Z',
#   'user': {'userId': '975498867',
#    'realm': 'RT',
#    'displayName': 'robin m',
#    'accountLink': '/user/id/975498867'},
#   'score': 3.5,
#   'timeFromCreation': '4h ago'},
#  {'rating': 'STAR_4',
#   'review': "The absolute best animation/computer graphics I've seen. This movie should sweep the awards for that reason alone. Stunning. The movie itself was great also - but I have to say that this format really brought out the dark and violent, evil side inherent in the plot ... somehow the circle of life was out-shadowed by the darkness. Doesn't feel like a kid's movie in the respect. Or even a movie for adults seeking more.",
#   'displayName': 'Ginger',
#   'displayImageUrl': None,
#   'isVerified': True,
#   'isSuperReviewer': False,
#   'hasSpoilers': False,
#   'hasProfanity': False,
#   'createDate': '2019-08-27T17:08:42.618Z',
#   'updateDate': '2019-08-27T17:08:42.618Z',
#   'user': {'userId': '6dcf3c0f-5c43-4b92-9566-75586deae351',
#    'realm': 'Fandango',
#    'displayName': 'Ginger',
#    'accountLink': None},
#   'score': 4,
#   'timeFromCreation': '5h ago'},
#  {'rating': 'STAR_4',
#   'review': 'It was really good. I loved it! Just as good as the original.',
#   'displayName': 'Jessica T',
#   'displayImageUrl': None,
#   'isVerified': True,
#   'isSuperReviewer': False,
#   'hasSpoilers': False,
#   'hasProfanity': False,
#   'createDate': '2019-08-27T17:08:42.509Z',
#   'updateDate': '2019-08-27T17:08:42.509Z',
#   'user': {'userId': 'e5a8cfc3-6606-4567-b27c-b617d7618982',
#    'realm': 'Fandango',
#    'displayName': 'Jessica T',
#    'accountLink': None},
#   'score': 4,
#   'timeFromCreation': '5h ago'},
#  {'rating': 'STAR_4_5',
#   'review': 'I just wish the hyenas were funny. They played a major role in the original.',
#   'displayName': 'Kimberly',
#   'displayImageUrl': None,
#   'isVerified': True,
#   'isSuperReviewer': False,
#   'hasSpoilers': False,
#   'hasProfanity': False,
#   'createDate': '2019-08-27T16:36:52.867Z',
#   'updateDate': '2019-08-27T16:36:52.867Z',
#   'user': {'userId': 'bd1c1f84-a695-4f0d-91c8-6ed4abb1769c',
#    'realm': 'Fandango',
#    'displayName': 'Kimberly',
#    'accountLink': None},
#   'score': 4.5,
#   'timeFromCreation': '5h ago'},
#  {'rating': 'STAR_3_5',
#   'review': 'There is one word to describe this movie. That is word is average. It felt like watching the original adaptation all over again.',
#   'displayName': 'Robert A',
#   'displayImageUrl': None,
#   'isVerified': False,
#   'isSuperReviewer': False,
#   'hasSpoilers': False,
#   'hasProfanity': False,
#   'createDate': '2019-08-27T16:09:47.208Z',
#   'updateDate': '2019-08-27T16:16:23.661Z',
#   'user': {'userId': '978214701',
#    'realm': 'RT',
#    'displayName': 'Robert A',
#    'accountLink': '/user/id/978214701'},
#   'score': 3.5,
#   'timeFromCreation': '6h ago'},
#  {'rating': 'STAR_4',
#   'review': 'Love the story - wonderfully done',
#   'displayName': 'HKS',
#   'displayImageUrl': None,
#   'isVerified': False,
#   'isSuperReviewer': False,
#   'hasSpoilers': False,
#   'hasProfanity': False,
#   'createDate': '2019-08-27T16:00:30.362Z',
#   'updateDate': '2019-08-27T16:00:30.362Z',
#   'user': {'userId': 'A9B74183-273B-4188-B5C4-418ACDA9CE07',
#    'realm': 'Fandango',
#    'displayName': 'HKS',
#    'accountLink': None},
#   'score': 4,
#   'timeFromCreation': '6h ago'},
#  {'rating': 'STAR_0_5',
#   'review': "Walked out half way thru the movie my kids kept falling asleep and so was I. I  certainly wasn't going to stay watching it alone I hadnt chosen it in the first place!",
#   'displayName': 'Jesse',
#   'displayImageUrl': None,
#   'isVerified': True,
#   'isSuperReviewer': False,
#   'hasSpoilers': False,
#   'hasProfanity': False,
#   'createDate': '2019-08-27T15:49:34.888Z',
#   'updateDate': '2019-08-27T15:49:35.444Z',
#   'user': {'userId': 'bb3d4e53-12f1-4616-bd4d-ae7e419bcda1',
#    'realm': 'Fandango',
#    'displayName': 'Jesse',
#    'accountLink': None},
#   'score': 0.5,
#   'timeFromCreation': '6h ago'},
#  {'rating': 'STAR_5',
#   'review': 'The Lion King movie is so beautiful. It was able to capture the magic of the original. It was a special movie to share with my kids.',
#   'displayName': 'Mommytrex',
#   'displayImageUrl': None,
#   'isVerified': True,
#   'isSuperReviewer': False,
#   'hasSpoilers': False,
#   'hasProfanity': False,
#   'createDate': '2019-08-27T15:24:39.629Z',
#   'updateDate': '2019-08-27T15:24:39.629Z',
#   'user': {'userId': '0b6d99f2-dd01-460d-95bb-8fa2eda6acc3',
#    'realm': 'Fandango',
#    'displayName': 'Mommytrex',
#    'accountLink': None},
#   'score': 5,
#   'timeFromCreation': '7h ago'},
#  {'rating': 'STAR_5',
#   'review': 'No dislikes once so ever. Enjoyed the movie, and the theater very much.',
#   'displayName': 'Ashlee Barrette',
#   'displayImageUrl': None,
#   'isVerified': True,
#   'isSuperReviewer': False,
#   'hasSpoilers': False,
#   'hasProfanity': False,
#   'createDate': '2019-08-27T14:58:26.597Z',
#   'updateDate': '2019-08-27T14:58:29.150Z',
#   'user': {'userId': '169f6758-f3ea-45bf-b57d-2c2ac4f44488',
#    'realm': 'Fandango',
#    'displayName': 'Ashlee Barrette',
#    'accountLink': None},
#   'score': 5,
#   'timeFromCreation': '7h ago'},
#  {'rating': 'STAR_3',
#   'review': 'This movie was visually gorgeous as one would expect but in the end it just felt rushed. From the opening sequence it felt shorter and less grandiose than the original. The voice actors did a good job but not great. The originals did a much better job of selling their personalities as animals where this version failed to suspend the disbelief. Many of the moments felt like a person singing the songs rather than the actual characters. It also seemed like they changed each song slightly to fit the voice actors strengths rather than casting someone that could pull off the original ensembles. Overall it was a good watch because it was just visually breathtaking, but as whole this really falls flat considering the high hopes and expectations set for such a classic and nostalgic movie. ',
#   'displayName': 'Victor M',
#   'displayImageUrl': None,
#   'isVerified': False,
#   'isSuperReviewer': False,
#   'hasSpoilers': False,
#   'hasProfanity': False,
#   'createDate': '2019-08-27T14:56:07.298Z',
#   'updateDate': '2019-08-27T14:56:07.298Z',
#   'user': {'userId': '978099203',
#    'realm': 'RT',
#    'displayName': 'Victor M',
#    'accountLink': '/user/id/978099203'},
#   'score': 3,
#   'timeFromCreation': '7h ago'},
#  {'rating': 'STAR_1',
#   'review': 'Terrible acting, terrible editing, music was off, singing was bad. They tried to expand on the story where it didn’t need it and they took out the comedy. The only redeeming quality was the CGI.',
#   'displayName': 'E',
#   'displayImageUrl': None,
#   'isVerified': False,
#   'isSuperReviewer': False,
#   'hasSpoilers': False,
#   'hasProfanity': False,
#   'createDate': '2019-08-27T14:18:54.400Z',
#   'updateDate': '2019-08-27T14:18:54.400Z',
#   'user': {'userId': '9CCF03C9-1435-4EE8-898C-8085FE490F11',
#    'realm': 'Fandango',
#    'displayName': 'E',
#    'accountLink': None},
#   'score': 1,
#   'timeFromCreation': '8h ago'},
#  {'rating': 'STAR_4',
#   'review': 'I loved the realistic animation. However, the voices of the various characters could be improved ( ie Simba\'s voice never matured beyond a juvenile). The intensity of the "fight" scenes could be upsetting to young children.  I really loved it as an adult! Kids would miss alot as in other Disney productions.',
#   'displayName': 'Linda',
#   'displayImageUrl': None,
#   'isVerified': False,
#   'isSuperReviewer': False,
#   'hasSpoilers': False,
#   'hasProfanity': False,
#   'createDate': '2019-08-27T13:43:07.329Z',
#   'updateDate': '2019-08-27T13:43:07.329Z',
#   'user': {'userId': 'e7bf82ae-8f0c-4dcb-b98d-7c6dfb75eb8c',
#    'realm': 'Fandango',
#    'displayName': 'Linda',
#    'accountLink': None},
#   'score': 4,
#   'timeFromCreation': '8h ago'},
#  {'rating': 'STAR_5',
#   'review': "The story itself is beautiful and this real not animated made it more spectacular. But Beyonce did not add passion to Nala's voice. Her voice was too soft.",
#   'displayName': 'Maria N',
#   'displayImageUrl': None,
#   'isVerified': True,
#   'isSuperReviewer': False,
#   'hasSpoilers': False,
#   'hasProfanity': False,
#   'createDate': '2019-08-27T13:18:09.412Z',
#   'updateDate': '2019-08-27T13:18:09.412Z',
#   'user': {'userId': '4869189d-936c-4e6b-b716-783c594e8d3f',
#    'realm': 'Fandango',
#    'displayName': 'Maria N',
#    'accountLink': None},
#   'score': 5,
#   'timeFromCreation': '9h ago'},
#  {'rating': 'STAR_5',
#   'review': 'The movie stayed very true to the original but at the same time adding more life and humor. I loved it!',
#   'displayName': 'Danelle H',
#   'displayImageUrl': None,
#   'isVerified': False,
#   'isSuperReviewer': False,
#   'hasSpoilers': False,
#   'hasProfanity': False,
#   'createDate': '2019-08-27T13:17:10.242Z',
#   'updateDate': '2019-08-27T13:17:10.242Z',
#   'user': {'userId': '978186590',
#    'realm': 'RT',
#    'displayName': 'Danelle H',
#    'accountLink': '/user/id/978186590'},
#   'score': 5,
#   'timeFromCreation': '9h ago'},
#  {'rating': 'STAR_5',
#   'review': 'Just like the original movie! Visually stunning!',
#   'displayName': 'Andrew',
#   'displayImageUrl': None,
#   'isVerified': True,
#   'isSuperReviewer': False,
#   'hasSpoilers': False,
#   'hasProfanity': False,
#   'createDate': '2019-08-27T12:40:20.372Z',
#   'updateDate': '2019-08-27T12:40:20.813Z',
#   'user': {'userId': '4d7453b2-8052-4cd0-bfb3-8dbddd57de30',
#    'realm': 'Fandango',
#    'displayName': 'Andrew',
#    'accountLink': None},
#   'score': 5,
#   'timeFromCreation': '9h ago'},
#  {'rating': 'STAR_2',
#   'review': 'The story is sound, as it was in 1994. This animation update told the story. The casting was way off and was taken miles too seriously. Disney was clearly doing everything in its power to be relevant and diverse at the expense of quality. Nothing more than a cash grab to offset their recent billion dollar purchases. If you have seen Lion King... you have already seen this.',
#   'displayName': 'Shane G',
#   'displayImageUrl': 'https://graph.facebook.com/v3.3/10152507834680934/picture',
#   'isVerified': False,
#   'isSuperReviewer': False,
#   'hasSpoilers': False,
#   'hasProfanity': False,
#   'createDate': '2019-08-27T12:24:18.684Z',
#   'updateDate': '2019-08-27T12:24:18.684Z',
#   'user': {'userId': '974655827',
#    'realm': 'RT',
#    'displayName': 'Shane G',
#    'accountLink': '/user/id/974655827'},
#   'score': 2,
#   'timeFromCreation': '10h ago'},
#  {'rating': 'STAR_5',
#   'review': 'I liked the story and how they did the animation.',
#   'displayName': 'sherry',
#   'displayImageUrl': None,
#   'isVerified': True,
#   'isSuperReviewer': False,
#   'hasSpoilers': False,
#   'hasProfanity': False,
#   'createDate': '2019-08-27T10:53:02.119Z',
#   'updateDate': '2019-08-27T10:53:02.119Z',
#   'user': {'userId': '0791a557-c9c4-4f56-bdf3-c7c4a003b619',
#    'realm': 'Fandango',
#    'displayName': 'sherry',
#    'accountLink': None},
#   'score': 5,
#   'timeFromCreation': '11h ago'},
#  {'rating': 'STAR_4',
#   'review': 'Another great Disney movie!!',
#   'displayName': 'SP',
#   'displayImageUrl': None,
#   'isVerified': True,
#   'isSuperReviewer': False,
#   'hasSpoilers': False,
#   'hasProfanity': False,
#   'createDate': '2019-08-27T10:50:47.880Z',
#   'updateDate': '2019-08-27T10:50:47.880Z',
#   'user': {'userId': '6ba340da-3c16-4277-87d1-2dc62692caa4',
#    'realm': 'Fandango',
#    'displayName': 'SP',
#    'accountLink': None},
#   'score': 4,
#   'timeFromCreation': '11h ago'},
#  {'rating': 'STAR_3',
#   'review': 'Beyonce cannot act. Not even a little bit. That is all. ',
#   'displayName': None,
#   'displayImageUrl': None,
#   'isVerified': False,
#   'isSuperReviewer': False,
#   'hasSpoilers': False,
#   'hasProfanity': False,
#   'createDate': '2019-08-27T10:10:27.958Z',
#   'updateDate': '2019-08-27T10:10:27.958Z',
#   'user': {'userId': '867811394',
#    'realm': 'RT',
#    'displayName': None,
#    'accountLink': '/user/id/867811394'},
#   'score': 3,
#   'timeFromCreation': '12h ago'},
#  {'rating': 'STAR_5',
#   'review': 'We loved the movie!!  The storyline and integrity of the movie remained the same and the new modern elements were FANTASTIC! The actors character voices were PHENOMENAL! The songs (old and new) as well as the digital effects were OUTSTANDING! Thank you for keeping James Earl Jones as Mufasa! Lion King is simply a great movie for everyone to see!! THE BEST!!',
#   'displayName': 'Yolanda',
#   'displayImageUrl': None,
#   'isVerified': True,
#   'isSuperReviewer': False,
#   'hasSpoilers': False,
#   'hasProfanity': False,
#   'createDate': '2019-08-27T07:47:57.018Z',
#   'updateDate': '2019-08-27T07:48:01.447Z',
#   'user': {'userId': 'cf405655-e57b-445e-a67c-c026f75f63d4',
#    'realm': 'Fandango',
#    'displayName': 'Yolanda',
#    'accountLink': None},
#   'score': 5,
#   'timeFromCreation': '14h ago'},
#  {'rating': 'STAR_5',
#   'review': 'I liked everything, it is awesome to remember the marvelous story and the magnificent music!!',
#   'displayName': 'Maria',
#   'displayImageUrl': None,
#   'isVerified': True,
#   'isSuperReviewer': False,
#   'hasSpoilers': False,
#   'hasProfanity': False,
#   'createDate': '2019-08-27T07:20:02.412Z',
#   'updateDate': '2019-08-27T07:20:02.412Z',
#   'user': {'userId': '5414369d-cee7-41ae-8aab-4b366fb03c40',
#    'realm': 'Fandango',
#    'displayName': 'Maria',
#    'accountLink': None},
#   'score': 5,
#   'timeFromCreation': '15h ago'},
#  {'rating': 'STAR_5',
#   'review': 'Unbelievable imaging by computer.  I thought this was one of the best movies so far this year.',
#   'displayName': 'Dan',
#   'displayImageUrl': None,
#   'isVerified': True,
#   'isSuperReviewer': False,
#   'hasSpoilers': False,
#   'hasProfanity': False,
#   'createDate': '2019-08-27T05:38:02.493Z',
#   'updateDate': '2019-08-27T05:38:02.493Z',
#   'user': {'userId': 'ac9d6010-c559-42f5-8324-6ca667acd3c8',
#    'realm': 'Fandango',
#    'displayName': 'Dan',
#    'accountLink': None},
#   'score': 5,
#   'timeFromCreation': '16h ago'},
#  {'rating': 'STAR_2_5',
#   'review': 'Eh the movie was ok but literally a shot by shot remake of the original Lion King and seen a bit the original animated film at choir and I liked it more so the remake is a 6/10',
#   'displayName': 'Pokmon  G',
#   'displayImageUrl': None,
#   'isVerified': False,
#   'isSuperReviewer': False,
#   'hasSpoilers': False,
#   'hasProfanity': False,
#   'createDate': '2019-08-27T05:05:22.950Z',
#   'updateDate': '2019-08-27T05:05:22.950Z',
#   'user': {'userId': '978113631',
#    'realm': 'RT',
#    'displayName': 'Pokmon  G',
#    'accountLink': '/user/id/978113631'},
#   'score': 2.5,
#   'timeFromCreation': '17h ago'},
#  {'rating': 'STAR_5',
#   'review': "The movie was as emotional as the animated version and more dramatic because of it being live action, sort of . Jon Favreau does an excellent job as director Donald Glover, Beyonce Knowles-Carter were a great choice to voice Simba and Nala, as well as the other actors cast. Enjoyed that they included the new song Spirit and it fit in with all of the original songs. The critics who criticized the film were wrong I'm glad I ignored them. It's worth every dollar I spent to see it --18.70.",
#   'displayName': 'Sakinah A',
#   'displayImageUrl': None,
#   'isVerified': True,
#   'isSuperReviewer': False,
#   'hasSpoilers': False,
#   'hasProfanity': False,
#   'createDate': '2019-08-27T04:25:15.238Z',
#   'updateDate': '2019-08-27T04:25:15.238Z',
#   'user': {'userId': '0be115e3-b04c-4355-925a-2d94afdf2b2f',
#    'realm': 'Fandango',
#    'displayName': 'Sakinah A',
#    'accountLink': None},
#   'score': 5,
#   'timeFromCreation': '18h ago'},
#  {'rating': 'STAR_2',
#   'review': 'The original was way better.',
#   'displayName': 'Edurdo C',
#   'displayImageUrl': None,
#   'isVerified': True,
#   'isSuperReviewer': False,
#   'hasSpoilers': False,
#   'hasProfanity': False,
#   'createDate': '2019-08-27T04:02:28.129Z',
#   'updateDate': '2019-08-27T04:02:28.129Z',
#   'user': {'userId': '3914efd0-57cb-4d0a-8296-ffef76f877f7',
#    'realm': 'Fandango',
#    'displayName': 'Edurdo C',
#    'accountLink': None},
#   'score': 2,
#   'timeFromCreation': '18h ago'},
#  {'rating': 'STAR_5',
#   'review': 'Loved the Movie! It had the original story theme with more humor ! 5 stars !',
#   'displayName': 'Lorri',
#   'displayImageUrl': None,
#   'isVerified': True,
#   'isSuperReviewer': False,
#   'hasSpoilers': False,
#   'hasProfanity': False,
#   'createDate': '2019-08-27T03:10:47.578Z',
#   'updateDate': '2019-08-27T03:10:48.793Z',
#   'user': {'userId': '6c6b13c2-2f32-462c-bc99-93eef39da1e2',
#    'realm': 'Fandango',
#    'displayName': 'Lorri',
#    'accountLink': None},
#   'score': 5,
#   'timeFromCreation': '19h ago'},
#  {'rating': 'STAR_0_5',
#   'review': 'the picture of the movies was amazing. the reason for the half star. everything else with the movie was just horrible. they took out every good part from the original movie. there is no words to explain how horrible the singing was. dont care who they got to sing. honestly the 1980 movie was 100% better. even my 5yr old. said daddy can we go home and watch the original lion king. please you aim for the younger generation and they would rather watch the 1980 movie. now thays sad',
#   'displayName': None,
#   'displayImageUrl': None,
#   'isVerified': False,
#   'isSuperReviewer': False,
#   'hasSpoilers': False,
#   'hasProfanity': False,
#   'createDate': '2019-08-27T02:57:09.009Z',
#   'updateDate': '2019-08-27T02:57:09.009Z',
#   'user': {'userId': '260306393',
#    'realm': 'RT',
#    'displayName': None,
#    'accountLink': '/user/id/260306393'},
#   'score': 0.5,
#   'timeFromCreation': '19h ago'},
#  {'rating': 'STAR_3_5',
#   'review': 'I am just not a Beyoncé fan, however everything else was very cute and nostalgic!',
#   'displayName': 'dreastar',
#   'displayImageUrl': None,
#   'isVerified': True,
#   'isSuperReviewer': False,
#   'hasSpoilers': False,
#   'hasProfanity': False,
#   'createDate': '2019-08-27T02:24:25.377Z',
#   'updateDate': '2019-08-27T02:24:25.377Z',
#   'user': {'userId': 'C5EE83A1-187C-438E-8ABC-5170B3195159',
#    'realm': 'Fandango',
#    'displayName': 'dreastar',
#    'accountLink': None},
#   'score': 3.5,
#   'timeFromCreation': '20h ago'},
#  {'rating': 'STAR_2_5',
#   'review': 'Very low energy movie. Meh..  Zero excitement',
#   'displayName': 'Nichole C',
#   'displayImageUrl': None,
#   'isVerified': True,
#   'isSuperReviewer': False,
#   'hasSpoilers': False,
#   'hasProfanity': False,
#   'createDate': '2019-08-27T01:20:18.736Z',
#   'updateDate': '2019-08-27T15:20:53.718Z',
#   'user': {'userId': 'cb583034-8660-4736-ab31-45bab2794b36',
#    'realm': 'Fandango',
#    'displayName': 'Nichole C',
#    'accountLink': None},
#   'score': 2.5,
#   'timeFromCreation': '21h ago'},
#  {'rating': 'STAR_4_5',
#   'review': 'Really good, but missed some of the original moments.',
#   'displayName': 'Lindsey',
#   'displayImageUrl': None,
#   'isVerified': True,
#   'isSuperReviewer': False,
#   'hasSpoilers': False,
#   'hasProfanity': False,
#   'createDate': '2019-08-27T01:13:54.238Z',
#   'updateDate': '2019-08-27T01:13:54.238Z',
#   'user': {'userId': '4236761F-DFBB-4F10-8A89-C6B45AEA2178',
#    'realm': 'Fandango',
#    'displayName': 'Lindsey',
#    'accountLink': None},
#   'score': 4.5,
#   'timeFromCreation': '21h ago'},
#  {'rating': 'STAR_5',
#   'review': 'Great reproduction of the original animated film. Well done',
#   'displayName': 'Richard',
#   'displayImageUrl': None,
#   'isVerified': True,
#   'isSuperReviewer': False,
#   'hasSpoilers': False,
#   'hasProfanity': False,
#   'createDate': '2019-08-27T01:07:17.180Z',
#   'updateDate': '2019-08-27T01:07:17.180Z',
#   'user': {'userId': 'd06c19ad-9871-45d0-8bb3-b6fc5f086b2d',
#    'realm': 'Fandango',
#    'displayName': 'Richard',
#    'accountLink': None},
#   'score': 5,
#   'timeFromCreation': '21h ago'},
#  {'rating': 'STAR_5',
#   'review': 'Extraordinary. Animation was so lifelike. Entertaining, funny and emotional.',
#   'displayName': 'Francine',
#   'displayImageUrl': None,
#   'isVerified': True,
#   'isSuperReviewer': False,
#   'hasSpoilers': False,
#   'hasProfanity': False,
#   'createDate': '2019-08-27T00:55:12.486Z',
#   'updateDate': '2019-08-27T00:55:12.486Z',
#   'user': {'userId': 'c6698059-0d7f-48dc-a0d3-8c4537cc3ef9',
#    'realm': 'Fandango',
#    'displayName': 'Francine',
#    'accountLink': None},
#   'score': 5,
#   'timeFromCreation': '21h ago'},
#  {'rating': 'STAR_2_5',
#   'review': 'Seth Rogen was the only good thing in it. There were some songs they got right, but overall, not great.',
#   'displayName': 'Q T',
#   'displayImageUrl': None,
#   'isVerified': False,
#   'isSuperReviewer': False,
#   'hasSpoilers': False,
#   'hasProfanity': False,
#   'createDate': '2019-08-27T00:50:01.793Z',
#   'updateDate': '2019-08-27T00:50:01.793Z',
#   'user': {'userId': '972972878',
#    'realm': 'RT',
#    'displayName': 'Q T',
#    'accountLink': '/user/id/972972878'},
#   'score': 2.5,
#   'timeFromCreation': '21h ago'},
#  {'rating': 'STAR_4',
#   'review': 'Thought it was really good just some parts not appropriate for small children.',
#   'displayName': 'Wendy',
#   'displayImageUrl': None,
#   'isVerified': True,
#   'isSuperReviewer': False,
#   'hasSpoilers': False,
#   'hasProfanity': False,
#   'createDate': '2019-08-27T00:27:36.014Z',
#   'updateDate': '2019-08-27T00:27:36.014Z',
#   'user': {'userId': '318da3ee-5751-4b43-9032-fa774a35abd6',
#    'realm': 'Fandango',
#    'displayName': 'Wendy',
#    'accountLink': None},
#   'score': 4,
#   'timeFromCreation': '22h ago'},
#  {'rating': 'STAR_3',
#   'review': "Somewhat slow in beginning but very true to original. Beyonce's songs were awesome",
#   'displayName': 'LGG',
#   'displayImageUrl': None,
#   'isVerified': True,
#   'isSuperReviewer': False,
#   'hasSpoilers': False,
#   'hasProfanity': False,
#   'createDate': '2019-08-27T00:25:16.351Z',
#   'updateDate': '2019-08-27T00:25:16.351Z',
#   'user': {'userId': 'afddf757-4beb-4b2d-96cb-30d4ba921aa3',
#    'realm': 'Fandango',
#    'displayName': 'LGG',
#    'accountLink': None},
#   'score': 3,
#   'timeFromCreation': '22h ago'},
#  {'rating': 'STAR_4',
#   'review': 'a few great scenes from the original were missing, and should have been included.',
#   'displayName': 'Chris T',
#   'displayImageUrl': None,
#   'isVerified': True,
#   'isSuperReviewer': False,
#   'hasSpoilers': False,
#   'hasProfanity': False,
#   'createDate': '2019-08-26T23:35:26.089Z',
#   'updateDate': '2019-08-26T23:35:26.089Z',
#   'user': {'userId': '6c3daac0-3293-4d85-9db4-c6ede381a2fe',
#    'realm': 'Fandango',
#    'displayName': 'Chris T',
#    'accountLink': None},
#   'score': 4,
#   'timeFromCreation': '22h ago'},
#  {'rating': 'STAR_5',
#   'review': 'The live animation was amazing',
#   'displayName': 'Margaret',
#   'displayImageUrl': None,
#   'isVerified': True,
#   'isSuperReviewer': False,
#   'hasSpoilers': False,
#   'hasProfanity': False,
#   'createDate': '2019-08-26T23:33:03.538Z',
#   'updateDate': '2019-08-26T23:33:03.538Z',
#   'user': {'userId': 'bbaec584-bee3-4d13-8ae7-9ba0d46d416b',
#    'realm': 'Fandango',
#    'displayName': 'Margaret',
#    'accountLink': None},
#   'score': 5,
#   'timeFromCreation': '23h ago'},
#  {'rating': 'STAR_5',
#   'review': 'Very gd...Actors was great especially James Earl Jones...',
#   'displayName': 'Simon N',
#   'displayImageUrl': None,
#   'isVerified': True,
#   'isSuperReviewer': False,
#   'hasSpoilers': False,
#   'hasProfanity': False,
#   'createDate': '2019-08-26T23:15:15.148Z',
#   'updateDate': '2019-08-26T23:15:15.148Z',
#   'user': {'userId': '495dd7a6-2344-4dba-8c3d-ed2d44e8c087',
#    'realm': 'Fandango',
#    'displayName': 'Simon N',
#    'accountLink': None},
#   'score': 5,
#   'timeFromCreation': '23h ago'},
#  {'rating': 'STAR_5',
#   'review': 'Wonderful.     It made me feel like was back in Tanzania',
#   'displayName': 'Cindy E',
#   'displayImageUrl': None,
#   'isVerified': True,
#   'isSuperReviewer': False,
#   'hasSpoilers': False,
#   'hasProfanity': False,
#   'createDate': '2019-08-26T23:09:56.262Z',
#   'updateDate': '2019-08-26T23:09:56.262Z',
#   'user': {'userId': 'FC4FE3FF-A4A5-4C05-8434-F269811FFD70',
#    'realm': 'Fandango',
#    'displayName': 'Cindy E',
#    'accountLink': None},
#   'score': 5,
#   'timeFromCreation': '23h ago'},
#  {'rating': 'STAR_2_5',
#   'review': "Shot for shot remake of the original. As far as remakes go this was fine, but unfortunately most of what is praiseworthy about it belongs to a different movie. The animation was photorealistic, which deserves it's own sort of praise, but photorealistic lions don't emote much.",
#   'displayName': 'Kevin S',
#   'displayImageUrl': None,
#   'isVerified': False,
#   'isSuperReviewer': False,
#   'hasSpoilers': False,
#   'hasProfanity': False,
#   'createDate': '2019-08-26T22:49:07.853Z',
#   'updateDate': '2019-08-26T22:49:07.853Z',
#   'user': {'userId': '977880733',
#    'realm': 'RT',
#    'displayName': 'Kevin S',
#    'accountLink': '/user/id/977880733'},
#   'score': 2.5,
#   'timeFromCreation': '23h ago'},
#  {'rating': 'STAR_2_5',
#   'review': 'The Lion King in general is kind of a boring movie with a lot of long drawn out sequences (tuft of fur) but I loved the animation quality of this version and Timon was amazing. I’d recommend seeing it on a cheap day or matinee because it’s good but not full price ticket good.',
#   'displayName': 'Syd',
#   'displayImageUrl': None,
#   'isVerified': True,
#   'isSuperReviewer': False,
#   'hasSpoilers': False,
#   'hasProfanity': False,
#   'createDate': '2019-08-26T22:35:27.292Z',
#   'updateDate': '2019-08-26T22:35:27.292Z',
#   'user': {'userId': 'F0427196-46AB-4EBB-831E-543357040851',
#    'realm': 'Fandango',
#    'displayName': 'Syd',
#    'accountLink': None},
#   'score': 2.5,
#   'timeFromCreation': '23h ago'},
#  {'rating': 'STAR_3_5',
#   'review': "The cartoon was more emotional. \n(SPOILERS)\nWhat I don't understand is if they tried to copy the original almost scene by scene, why did they rush and changed the most important ones? Mufasa's death scene and the part when Nala and Simba find each other again and Nala talk to Pumbaa and Timon explaining Simba and Rafiki's interaction without running away quickly. Overall the movie was great, if you never saw the original one to make comparisons...",
#   'displayName': 'Serena S',
#   'displayImageUrl': 'https://graph.facebook.com/v3.3/10157063722973572/picture',
#   'isVerified': False,
#   'isSuperReviewer': False,
#   'hasSpoilers': False,
#   'hasProfanity': False,
#   'createDate': '2019-08-26T22:13:42.096Z',
#   'updateDate': '2019-08-26T22:24:49.321Z',
#   'user': {'userId': '977883009',
#    'realm': 'RT',
#    'displayName': 'Serena S',
#    'accountLink': '/user/id/977883009'},
#   'score': 3.5,
#   'timeFromCreation': 'Aug 26, 2019'},
#  {'rating': 'STAR_4_5',
#   'review': 'Minus Beyoncé as lion. Can’t act thought I was watching gold member all over again',
#   'displayName': 'Nelson',
#   'displayImageUrl': None,
#   'isVerified': True,
#   'isSuperReviewer': False,
#   'hasSpoilers': False,
#   'hasProfanity': False,
#   'createDate': '2019-08-26T22:08:25.913Z',
#   'updateDate': '2019-08-26T22:08:25.913Z',
#   'user': {'userId': '42D5FEB0-F5EE-4443-A41D-82B5D1EB19D0',
#    'realm': 'Fandango',
#    'displayName': 'Nelson',
#    'accountLink': None},
#   'score': 4.5,
#   'timeFromCreation': 'Aug 26, 2019'},
#  {'rating': 'STAR_5',
#   'review': 'It was cute, funny, entertaining, good all around family movie.',
#   'displayName': 'Lezlie Newton',
#   'displayImageUrl': None,
#   'isVerified': True,
#   'isSuperReviewer': False,
#   'hasSpoilers': False,
#   'hasProfanity': False,
#   'createDate': '2019-08-26T21:39:11.549Z',
#   'updateDate': '2019-08-26T21:39:12.094Z',
#   'user': {'userId': '7c696913-8365-494f-9219-1c4855e75445',
#    'realm': 'Fandango',
#    'displayName': 'Lezlie Newton',
#    'accountLink': None},
#   'score': 5,
#   'timeFromCreation': 'Aug 26, 2019'},
#  {'rating': 'STAR_4_5',
#   'review': 'Great movie!!!   The pictures and sound affect were amazing.  The theatre was clean and the employees were friendly.',
#   'displayName': 'Mary M',
#   'displayImageUrl': None,
#   'isVerified': True,
#   'isSuperReviewer': False,
#   'hasSpoilers': False,
#   'hasProfanity': False,
#   'createDate': '2019-08-26T21:23:28.078Z',
#   'updateDate': '2019-08-26T21:23:28.078Z',
#   'user': {'userId': '26140cf3-8e8e-4076-b43f-42235c2e15fc',
#    'realm': 'Fandango',
#    'displayName': 'Mary M',
#    'accountLink': None},
#   'score': 4.5,
#   'timeFromCreation': '1d ago'},
#  {'rating': 'STAR_0_5',
#   'review': 'Compared to the original one, this movie is dark, violent and depressing. ',
#   'displayName': 'David N',
#   'displayImageUrl': 'https://graph.facebook.com/v3.3/10157683556294180/picture',
#   'isVerified': False,
#   'isSuperReviewer': False,
#   'hasSpoilers': False,
#   'hasProfanity': False,
#   'createDate': '2019-08-26T20:58:40.039Z',
#   'updateDate': '2019-08-26T20:58:40.039Z',
#   'user': {'userId': '978213800',
#    'realm': 'RT',
#    'displayName': 'David N',
#    'accountLink': '/user/id/978213800'},
#   'score': 0.5,
#   'timeFromCreation': '1d ago'},
#  {'rating': 'STAR_5',
#   'review': 'Brought back memories!',
#   'displayName': None,
#   'displayImageUrl': None,
#   'isVerified': False,
#   'isSuperReviewer': False,
#   'hasSpoilers': False,
#   'hasProfanity': False,
#   'createDate': '2019-08-26T20:01:21.501Z',
#   'updateDate': '2019-08-26T20:01:21.501Z',
#   'user': {'userId': '921771525',
#    'realm': 'RT',
#    'displayName': None,
#    'accountLink': '/user/id/921771525'},
#   'score': 5,
#   'timeFromCreation': '1d ago'},
#  {'rating': 'STAR_3',
#   'review': 'Just made me want to watch the original instead ',
#   'displayName': 'jasmine e',
#   'displayImageUrl': None,
#   'isVerified': False,
#   'isSuperReviewer': False,
#   'hasSpoilers': False,
#   'hasProfanity': False,
#   'createDate': '2019-08-26T19:06:33.512Z',
#   'updateDate': '2019-08-26T19:06:33.512Z',
#   'user': {'userId': '978213361',
#    'realm': 'RT',
#    'displayName': 'jasmine e',
#    'accountLink': '/user/id/978213361'},
#   'score': 3,
#   'timeFromCreation': '1d ago'},
#  {'rating': 'STAR_3',
#   'review': 'Too similar to the cartoon.  I would have liked even a few unique differences.  The changes that were made was too few.',
#   'displayName': 'Christopher F',
#   'displayImageUrl': None,
#   'isVerified': True,
#   'isSuperReviewer': False,
#   'hasSpoilers': False,
#   'hasProfanity': False,
#   'createDate': '2019-08-26T18:48:00.383Z',
#   'updateDate': '2019-08-26T18:48:00.383Z',
#   'user': {'userId': 'a6cd65a4-27a7-479f-bd50-424fff9e5dab',
#    'realm': 'Fandango',
#    'displayName': 'Christopher F',
#    'accountLink': None},
#   'score': 3,
#   'timeFromCreation': '1d ago'},
#  {'rating': 'STAR_5',
#   'review': 'An outstanding recreating of the original! The CGI was amazing and the shot composition made for some truly outstanding scenes. The songs were still there but did not feel out of place. ',
#   'displayName': 'Forest N',
#   'displayImageUrl': None,
#   'isVerified': False,
#   'isSuperReviewer': False,
#   'hasSpoilers': False,
#   'hasProfanity': False,
#   'createDate': '2019-08-26T18:26:38.126Z',
#   'updateDate': '2019-08-26T18:26:38.126Z',
#   'user': {'userId': '977205517',
#    'realm': 'RT',
#    'displayName': 'Forest N',
#    'accountLink': '/user/id/977205517'},
#   'score': 5,
#   'timeFromCreation': '1d ago'},
#  {'rating': 'STAR_2_5',
#   'review': "If you want to watch the Lion King go see the original. The remake misses the mark. While the visuals are absolutely phenomenal everything else falls pretty flat. Due to the animals realism they lack facial expressions majorly taking you out of the story and making comedic moments fall flat. The voice casting was ok, though I found at some points Beyonce's voice lacked emotion at the most important times. And the most disappointing for me was all the covers of the original songs. \n\nTo sum it up: worth a watch for visuals and that's about it.",
#   'displayName': 'Delilah S',
#   'displayImageUrl': None,
#   'isVerified': False,
#   'isSuperReviewer': False,
#   'hasSpoilers': False,
#   'hasProfanity': False,
#   'createDate': '2019-08-26T17:31:48.474Z',
#   'updateDate': '2019-08-26T17:31:48.474Z',
#   'user': {'userId': '978213569',
#    'realm': 'RT',
#    'displayName': 'Delilah S',
#    'accountLink': '/user/id/978213569'},
#   'score': 2.5,
#   'timeFromCreation': '1d ago'},
#  {'rating': 'STAR_5',
#   'review': 'My Granddaughter and I loved this film.',
#   'displayName': 'Donna F',
#   'displayImageUrl': None,
#   'isVerified': True,
#   'isSuperReviewer': False,
#   'hasSpoilers': False,
#   'hasProfanity': False,
#   'createDate': '2019-08-26T17:31:28.492Z',
#   'updateDate': '2019-08-26T17:31:28.492Z',
#   'user': {'userId': 'b236f3c9-9375-4c72-a4f5-cada6485e11a',
#    'realm': 'Fandango',
#    'displayName': 'Donna F',
#    'accountLink': None},
#   'score': 5,
#   'timeFromCreation': '1d ago'},
#  {'rating': 'STAR_5',
#   'review': 'The cgi was amazing.  There should never be a need to use real animals for entertainment again.  These were creatures who looked real and had the behaviors of the real wild animals - except that they talked of course.  The story always gets and emotional reaction from me, but this movie was so much more than the other Lion Kings I have seen.',
#   'displayName': 'Tobylerone',
#   'displayImageUrl': None,
#   'isVerified': True,
#   'isSuperReviewer': False,
#   'hasSpoilers': False,
#   'hasProfanity': False,
#   'createDate': '2019-08-26T17:29:23.839Z',
#   'updateDate': '2019-08-26T17:29:23.839Z',
#   'user': {'userId': '8e79b8f1-0494-4e5e-85c3-8ab11d9c8dee',
#    'realm': 'Fandango',
#    'displayName': 'Tobylerone',
#    'accountLink': None},
#   'score': 5,
#   'timeFromCreation': '1d ago'},
#  {'rating': 'STAR_5',
#   'review': 'This movie was nicely done. It teaches families how to behave with one another and how animals are very similar to our  race. The movie teaches you lessons for children and adults. I recommend any age to watch this movie, and I would definitely see it again.',
#   'displayName': 'Lovelizzet.lc82',
#   'displayImageUrl': None,
#   'isVerified': True,
#   'isSuperReviewer': False,
#   'hasSpoilers': False,
#   'hasProfanity': False,
#   'createDate': '2019-08-26T16:55:56.406Z',
#   'updateDate': '2019-08-26T16:55:56.406Z',
#   'user': {'userId': 'de7fabc2-7a44-4f6d-8638-7cc4f0d915f0',
#    'realm': 'Fandango',
#    'displayName': 'Lovelizzet.lc82',
#    'accountLink': None},
#   'score': 5,
#   'timeFromCreation': '1d ago'},
#  {'rating': 'STAR_5',
#   'review': 'The impeccable details in this animation left me awe struck. It evoked more emotion than the original cartoon. I would definitely recommend to all ages for this reason.',
#   'displayName': 'Wendy',
#   'displayImageUrl': None,
#   'isVerified': True,
#   'isSuperReviewer': False,
#   'hasSpoilers': False,
#   'hasProfanity': False,
#   'createDate': '2019-08-26T16:39:20.794Z',
#   'updateDate': '2019-08-26T16:39:20.794Z',
#   'user': {'userId': '1d1a1719-a198-43a8-8a5e-daef73f2e6b2',
#    'realm': 'Fandango',
#    'displayName': 'Wendy',
#    'accountLink': None},
#   'score': 5,
#   'timeFromCreation': '1d ago'},
#  {'rating': 'STAR_4',
#   'review': 'It was good but not what I expected. Still has the feel of the original but not much of that “magic” factor',
#   'displayName': 'Long live the original!',
#   'displayImageUrl': None,
#   'isVerified': True,
#   'isSuperReviewer': False,
#   'hasSpoilers': False,
#   'hasProfanity': False,
#   'createDate': '2019-08-26T15:48:14.497Z',
#   'updateDate': '2019-08-26T15:48:14.497Z',
#   'user': {'userId': '7226CA2C-E8F6-41E7-AE2C-EC0480621DAD',
#    'realm': 'Fandango',
#    'displayName': 'Long live the original!',
#    'accountLink': None},
#   'score': 4,
#   'timeFromCreation': '1d ago'},
#  {'rating': 'STAR_5',
#   'review': 'Outstanding Entertainment for people of all ages',
#   'displayName': 'David F',
#   'displayImageUrl': None,
#   'isVerified': True,
#   'isSuperReviewer': False,
#   'hasSpoilers': False,
#   'hasProfanity': False,
#   'createDate': '2019-08-26T15:28:34.962Z',
#   'updateDate': '2019-08-26T15:28:34.962Z',
#   'user': {'userId': 'aa7cf1a0-24a9-4c00-97b1-b32473a2a1b5',
#    'realm': 'Fandango',
#    'displayName': 'David F',
#    'accountLink': None},
#   'score': 5,
#   'timeFromCreation': '1d ago'},
#  {'rating': 'STAR_4',
#   'review': "I love the movie!  But I'm only giving it 4 stars because I really think it was way more violent then it should have been.  The death scene wasn't really necessary and bothered me, even as a full grown adult!",
#   'displayName': 'Julie A',
#   'displayImageUrl': None,
#   'isVerified': True,
#   'isSuperReviewer': False,
#   'hasSpoilers': False,
#   'hasProfanity': False,
#   'createDate': '2019-08-26T14:32:11.884Z',
#   'updateDate': '2019-08-26T14:32:11.884Z',
#   'user': {'userId': '36658d88-4968-4228-a483-743f7cb659b1',
#    'realm': 'Fandango',
#    'displayName': 'Julie A',
#    'accountLink': None},
#   'score': 4,
#   'timeFromCreation': '1d ago'},
#  {'rating': 'STAR_5',
#   'review': 'Just wish they didn’t use, Beyoncé for, Nalas voice',
#   'displayName': 'Diane C',
#   'displayImageUrl': None,
#   'isVerified': True,
#   'isSuperReviewer': False,
#   'hasSpoilers': False,
#   'hasProfanity': False,
#   'createDate': '2019-08-26T13:45:58.907Z',
#   'updateDate': '2019-08-26T13:45:58.907Z',
#   'user': {'userId': '3BA51C54-A2FC-4063-A029-C8C3D04A23F4',
#    'realm': 'Fandango',
#    'displayName': 'Diane C',
#    'accountLink': None},
#   'score': 5,
#   'timeFromCreation': '1d ago'},
#  {'rating': 'STAR_5',
#   'review': 'Loved the animation and  adaptation to modern day conversing. \nDid think it was a bit over-violent',
#   'displayName': 'CAROLYN',
#   'displayImageUrl': None,
#   'isVerified': True,
#   'isSuperReviewer': False,
#   'hasSpoilers': False,
#   'hasProfanity': False,
#   'createDate': '2019-08-26T13:20:55.620Z',
#   'updateDate': '2019-08-26T13:20:55.620Z',
# ...
#   'score': 4.5,
#   'timeFromCreation': 'Aug 14, 2019'},
#  {'rating': 'STAR_4',
#   'review': 'The use of the real looking animals (and computer generated ones) were awesome. My wife and I are in our 40s and went to see it on a afternoon date. I thought it was great and would be for younger kids too...were just (old) kids at heart.',
#   'displayName': 'SAMUEL T',
#   'displayImageUrl': None,
#   'isVerified': True,
#   'isSuperReviewer': False,
#   'hasSpoilers': False,
#   'hasProfanity': False,
#   'createDate': '2019-08-14T11:07:00.956Z',
#   'updateDate': '2019-08-14T11:07:00.956Z',
#   'user': {'userId': '8b462ddd-5bb3-4684-86f9-0280430cc179',
#    'realm': 'Fandango',
#    'displayName': 'SAMUEL T',
#    'accountLink': None},
#   'score': 4,
#   'timeFromCreation': 'Aug 14, 2019'},
#  {'rating': 'STAR_5',
#   'review': 'Beautiful movie to see with my grandkids!',
#   'displayName': 'Michridley',
#   'displayImageUrl': None,
#   'isVerified': True,
#   'isSuperReviewer': False,
#   'hasSpoilers': False,
#   'hasProfanity': False,
#   'createDate': '2019-08-14T10:39:01.859Z',
#   'updateDate': '2019-08-14T10:39:01.859Z',
#   'user': {'userId': 'ffebf120-9791-48c6-b105-02b9ce435581',
#    'realm': 'Fandango',
#    'displayName': 'Michridley',
#    'accountLink': None},
#   'score': 5,
#   'timeFromCreation': 'Aug 14, 2019'},
#  {'rating': 'STAR_3',
#   'review': 'It was okay - took my granddaughter (10) and she liked it somewhat.  Although the story line was the same, and the movie was long, the characters were not developed enough - too choppy.  Recommend waiting for DVD',
#   'displayName': 'Cathy B',
#   'displayImageUrl': None,
#   'isVerified': True,
#   'isSuperReviewer': False,
#   'hasSpoilers': False,
#   'hasProfanity': False,
#   'createDate': '2019-08-14T10:28:55.930Z',
#   'updateDate': '2019-08-14T10:28:55.930Z',
#   'user': {'userId': 'd22dc3c6-f96d-4a6f-87d3-2f436efd1b29',
#    'realm': 'Fandango',
#    'displayName': 'Cathy B',
#    'accountLink': None},
#   'score': 3,
#   'timeFromCreation': 'Aug 14, 2019'},
#  {'rating': 'STAR_5',
#   'review': 'Animation was amazing!  Stuck close to the original, but with so much more. Very, very good!  Warning, though—Might be too much for young, sensitive viewers.',
#   'displayName': 'Penny',
#   'displayImageUrl': None,
#   'isVerified': True,
#   'isSuperReviewer': False,
#   'hasSpoilers': False,
#   'hasProfanity': False,
#   'createDate': '2019-08-14T08:00:00.989Z',
#   'updateDate': '2019-08-14T08:00:00.989Z',
#   'user': {'userId': '1ce0d873-32aa-46ce-a8ad-29d5d44d06d5',
#    'realm': 'Fandango',
#    'displayName': 'Penny',
#    'accountLink': None},
#   'score': 5,
#   'timeFromCreation': 'Aug 14, 2019'},
#  {'rating': 'STAR_5',
#   'review': 'It was amazing it made me cry❤️',
#   'displayName': 'Henry',
#   'displayImageUrl': None,
#   'isVerified': True,
#   'isSuperReviewer': False,
#   'hasSpoilers': False,
#   'hasProfanity': False,
#   'createDate': '2019-08-14T07:31:28.412Z',
#   'updateDate': '2019-08-14T07:31:28.412Z',
#   'user': {'userId': '31145206-15F4-4E0B-9640-09C5F0CA034C',
#    'realm': 'Fandango',
#    'displayName': 'Henry',
#    'accountLink': None},
#   'score': 5,
#   'timeFromCreation': 'Aug 14, 2019'},
#  {'rating': 'STAR_5',
#   'review': 'Everything about it was purrfect :)',
#   'displayName': 'Kamilla M',
#   'displayImageUrl': None,
#   'isVerified': False,
#   'isSuperReviewer': False,
#   'hasSpoilers': False,
#   'hasProfanity': False,
#   'createDate': '2019-08-14T07:10:42.435Z',
#   'updateDate': '2019-08-14T07:10:42.435Z',
#   'user': {'userId': '978198392',
#    'realm': 'RT',
#    'displayName': 'Kamilla M',
#    'accountLink': '/user/id/978198392'},
#   'score': 5,
#   'timeFromCreation': 'Aug 14, 2019'},
#  {'rating': 'STAR_4_5',
#   'review': 'Liked it better the second time I saw it for some reason. I’m so amazed by the amazing animal movements and expressions. Kudos!!! Wish it had more songs.',
#   'displayName': 'Alicia',
#   'displayImageUrl': None,
#   'isVerified': True,
#   'isSuperReviewer': False,
#   'hasSpoilers': False,
#   'hasProfanity': False,
#   'createDate': '2019-08-14T06:56:34.186Z',
#   'updateDate': '2019-08-14T06:56:34.186Z',
#   'user': {'userId': '24560D1A-115F-4901-BAE1-BEA805E40A18',
#    'realm': 'Fandango',
#    'displayName': 'Alicia',
#    'accountLink': None},
#   'score': 4.5,
#   'timeFromCreation': 'Aug 14, 2019'},
#  {'rating': 'STAR_5',
#   'review': 'Awesome Movie Love It',
#   'displayName': 'Giovanni H',
#   'displayImageUrl': None,
#   'isVerified': True,
#   'isSuperReviewer': False,
#   'hasSpoilers': False,
#   'hasProfanity': False,
#   'createDate': '2019-08-14T06:18:42.039Z',
#   'updateDate': '2019-08-14T06:18:42.039Z',
#   'user': {'userId': '12FA7D64-96FF-440D-BECB-B68128710A16',
#    'realm': 'Fandango',
#    'displayName': 'Giovanni H',
#    'accountLink': None},
#   'score': 5,
#   'timeFromCreation': 'Aug 14, 2019'},
#  {'rating': 'STAR_5',
#   'review': 'Could hardly believe this was animation the animals looked so real and the scenery was fantastic. Also enjoyed the music',
#   'displayName': 'Joy V',
#   'displayImageUrl': None,
#   'isVerified': True,
#   'isSuperReviewer': False,
#   'hasSpoilers': False,
#   'hasProfanity': False,
#   'createDate': '2019-08-14T05:56:15.111Z',
#   'updateDate': '2019-08-14T05:56:15.111Z',
#   'user': {'userId': '4dec4c47-e8c2-4547-b471-ddcc626704f7',
#    'realm': 'Fandango',
#    'displayName': 'Joy V',
#    'accountLink': None},
#   'score': 5,
#   'timeFromCreation': 'Aug 14, 2019'},
#  {'rating': 'STAR_4',
#   'review': "Great but the original voice cast can't be beat.",
#   'displayName': 'Jesse',
#   'displayImageUrl': None,
#   'isVerified': True,
#   'isSuperReviewer': False,
#   'hasSpoilers': False,
#   'hasProfanity': False,
#   'createDate': '2019-08-14T05:21:14.273Z',
#   'updateDate': '2019-08-14T05:21:14.273Z',
#   'user': {'userId': '146D473E-00BC-4541-9775-CD248226577D',
#    'realm': 'Fandango',
#    'displayName': 'Jesse',
#    'accountLink': None},
#   'score': 4,
#   'timeFromCreation': 'Aug 14, 2019'},
#  {'rating': 'STAR_1',
#   'review': 'Slow and a pointless remake',
#   'displayName': 'Chad',
#   'displayImageUrl': None,
#   'isVerified': True,
#   'isSuperReviewer': False,
#   'hasSpoilers': False,
#   'hasProfanity': False,
#   'createDate': '2019-08-14T04:28:18.506Z',
#   'updateDate': '2019-08-14T04:28:18.506Z',
#   'user': {'userId': '40bc01dd-32c8-4c2a-adf2-d2bd5c1a6b65',
#    'realm': 'Fandango',
#    'displayName': 'Chad',
#    'accountLink': None},
#   'score': 1,
#   'timeFromCreation': 'Aug 14, 2019'},
#  {'rating': 'STAR_4',
#   'review': 'I loved the graphics but the acting could have been a little better.',
#   'displayName': 'MT',
#   'displayImageUrl': None,
#   'isVerified': True,
#   'isSuperReviewer': False,
#   'hasSpoilers': False,
#   'hasProfanity': False,
#   'createDate': '2019-08-14T04:24:23.164Z',
#   'updateDate': '2019-08-14T04:24:23.164Z',
#   'user': {'userId': 'e0f11e9a-c79b-4211-9e07-77811565ee8f',
#    'realm': 'Fandango',
#    'displayName': 'MT',
#    'accountLink': None},
#   'score': 4,
#   'timeFromCreation': 'Aug 14, 2019'},
#  {'rating': 'STAR_5',
#   'review': 'my son really enjoyed the movie. it was really sweet the movie was great!',
#   'displayName': 'anna',
#   'displayImageUrl': None,
#   'isVerified': True,
#   'isSuperReviewer': False,
#   'hasSpoilers': False,
#   'hasProfanity': False,
#   'createDate': '2019-08-14T04:24:15.332Z',
#   'updateDate': '2019-08-14T04:24:15.332Z',
#   'user': {'userId': '8DC8E6C3-85DA-459B-AD6C-E6F4086F83E2',
#    'realm': 'Fandango',
#    'displayName': 'anna',
#    'accountLink': None},
#   'score': 5,
#   'timeFromCreation': 'Aug 14, 2019'},
#  {'rating': 'STAR_5',
#   'review': 'People walking in to movie late.  Issues with seats in front row after movie started.  Movie employee stood down front with light trying to figure out if people had wrong seats.  They just have had wrong seats.  Took forever for movie employee to determine.  All the while we are trying to see movie.',
#   'displayName': 'Debra',
#   'displayImageUrl': None,
#   'isVerified': True,
#   'isSuperReviewer': False,
#   'hasSpoilers': False,
#   'hasProfanity': False,
#   'createDate': '2019-08-14T04:17:48.285Z',
#   'updateDate': '2019-08-14T04:17:48.285Z',
#   'user': {'userId': '68b205ae-c433-47e2-afad-984d6c162a34',
#    'realm': 'Fandango',
#    'displayName': 'Debra',
#    'accountLink': None},
#   'score': 5,
#   'timeFromCreation': 'Aug 14, 2019'},
#  {'rating': 'STAR_5',
#   'review': 'nothing to report. great movie',
#   'displayName': 'Deanna',
#   'displayImageUrl': None,
#   'isVerified': True,
#   'isSuperReviewer': False,
#   'hasSpoilers': False,
#   'hasProfanity': False,
#   'createDate': '2019-08-14T04:16:15.152Z',
#   'updateDate': '2019-08-14T04:16:15.152Z',
#   'user': {'userId': 'D7FA1562-ABAE-4211-BAE8-ACE6EA5EE454',
#    'realm': 'Fandango',
#    'displayName': 'Deanna',
#    'accountLink': None},
#   'score': 5,
#   'timeFromCreation': 'Aug 14, 2019'},
#  {'rating': 'STAR_5',
#   'review': "It was amazing! How'd they do that!!",
#   'displayName': 'Sandy Lindquist',
#   'displayImageUrl': None,
#   'isVerified': False,
#   'isSuperReviewer': False,
#   'hasSpoilers': False,
#   'hasProfanity': False,
#   'createDate': '2019-08-14T04:15:30.140Z',
#   'updateDate': '2019-08-14T04:15:30.140Z',
#   'user': {'userId': 'e6e307f3-3f5f-48c3-afef-18aff05ba6a2',
#    'realm': 'Fandango',
#    'displayName': 'Sandy Lindquist',
#    'accountLink': None},
#   'score': 5,
#   'timeFromCreation': 'Aug 14, 2019'},
#  {'rating': 'STAR_5',
#   'review': 'Very nice! Very beautiful magical',
#   'displayName': 'Victor E',
#   'displayImageUrl': None,
#   'isVerified': True,
#   'isSuperReviewer': False,
#   'hasSpoilers': False,
#   'hasProfanity': False,
#   'createDate': '2019-08-14T03:37:20.600Z',
#   'updateDate': '2019-08-14T03:37:20.600Z',
#   'user': {'userId': '27D49262-D4D5-4F26-8CDA-40EB2198C9B6',
#    'realm': 'Fandango',
#    'displayName': 'Victor E',
#    'accountLink': None},
#   'score': 5,
#   'timeFromCreation': 'Aug 14, 2019'},
#  {'rating': 'STAR_3_5',
#   'review': 'Kept the legacy of this story going for a new generation ',
#   'displayName': 'Gary W',
#   'displayImageUrl': None,
#   'isVerified': False,
#   'isSuperReviewer': False,
#   'hasSpoilers': False,
#   'hasProfanity': False,
#   'createDate': '2019-08-14T03:36:43.086Z',
#   'updateDate': '2019-08-14T03:36:43.086Z',
#   'user': {'userId': '978102457',
#    'realm': 'RT',
#    'displayName': 'Gary W',
#    'accountLink': '/user/id/978102457'},
#   'score': 3.5,
#   'timeFromCreation': 'Aug 14, 2019'},
#  {'rating': 'STAR_5',
#   'review': 'The cinematography was great',
#   'displayName': 'Millie',
#   'displayImageUrl': None,
#   'isVerified': False,
#   'isSuperReviewer': False,
#   'hasSpoilers': False,
#   'hasProfanity': False,
#   'createDate': '2019-08-14T03:24:45.167Z',
#   'updateDate': '2019-08-14T03:24:45.167Z',
#   'user': {'userId': '827ee17c-e072-4687-98b8-b9c4f0b90060',
#    'realm': 'Fandango',
#    'displayName': 'Millie',
#    'accountLink': None},
#   'score': 5,
#   'timeFromCreation': 'Aug 14, 2019'},
#  {'rating': 'STAR_1_5',
#   'review': "This Lion King is a 'not-as-good' follow up. \nThank goodness for Beyonce who offers the only fresh thing worth seeing in this adaptation. \nWhile watching you want to leave the theatre and go watch the cartoon because they just didn't quite get the moments right, and it's super disappointing. \nSimilar to Robin Williams as the Genie, Rowan Atkinson brought so much life to Zazu that John Oliver just can't live up to.\nYa it was bad. Best go watch the 1994 cartoon version.",
#   'displayName': 'Graham S',
#   'displayImageUrl': 'https://graph.facebook.com/v3.3/501902118/picture',
#   'isVerified': False,
#   'isSuperReviewer': False,
#   'hasSpoilers': False,
#   'hasProfanity': False,
#   'createDate': '2019-08-14T03:22:51.500Z',
#   'updateDate': '2019-08-14T03:22:51.500Z',
#   'user': {'userId': '798702619',
#    'realm': 'RT',
#    'displayName': 'Graham S',
#    'accountLink': '/user/id/798702619'},
#   'score': 1.5,
#   'timeFromCreation': 'Aug 14, 2019'},
#  {'rating': 'STAR_4',
#   'review': 'Not much different than the 94 movie. Animals were realistic, good choice of voice actors, and dramatic scenes.',
#   'displayName': 'Chris S',
#   'displayImageUrl': None,
#   'isVerified': True,
#   'isSuperReviewer': False,
#   'hasSpoilers': False,
#   'hasProfanity': False,
#   'createDate': '2019-08-14T03:19:38.202Z',
#   'updateDate': '2019-08-14T03:19:38.202Z',
#   'user': {'userId': '4fddc77d-bf3c-4c0f-9c0d-aaa75f506d87',
#    'realm': 'Fandango',
#    'displayName': 'Chris S',
#    'accountLink': None},
#   'score': 4,
#   'timeFromCreation': 'Aug 14, 2019'},
#  {'rating': 'STAR_5',
#   'review': 'Loved it! Will definitely be buying it when it comes out on BluRay',
#   'displayName': 'Jessica',
#   'displayImageUrl': None,
#   'isVerified': True,
#   'isSuperReviewer': False,
#   'hasSpoilers': False,
#   'hasProfanity': False,
#   'createDate': '2019-08-14T03:08:48.572Z',
#   'updateDate': '2019-08-14T03:08:51.445Z',
#   'user': {'userId': '0ba1c6c5-0c30-49d8-886d-4c64bbcf5500',
#    'realm': 'Fandango',
#    'displayName': 'Jessica',
#    'accountLink': None},
#   'score': 5,
#   'timeFromCreation': 'Aug 14, 2019'},
#  {'rating': 'STAR_3_5',
#   'review': 'Disappointed in the singing',
#   'displayName': 'Google',
#   'displayImageUrl': None,
#   'isVerified': False,
#   'isSuperReviewer': False,
#   'hasSpoilers': False,
#   'hasProfanity': False,
#   'createDate': '2019-08-14T03:08:47.084Z',
#   'updateDate': '2019-08-14T03:08:47.084Z',
#   'user': {'userId': 'c5c4cef1-571b-46dd-b3f6-1b93495a6b97',
#    'realm': 'Fandango',
#    'displayName': 'Google',
#    'accountLink': None},
#   'score': 3.5,
#   'timeFromCreation': 'Aug 14, 2019'},
#  {'rating': 'STAR_5',
#   'review': 'As always, Disney produces an amazing show!!',
#   'displayName': 'love it',
#   'displayImageUrl': None,
#   'isVerified': True,
#   'isSuperReviewer': False,
#   'hasSpoilers': False,
#   'hasProfanity': False,
#   'createDate': '2019-08-14T02:40:52.336Z',
#   'updateDate': '2019-08-14T02:40:52.336Z',
#   'user': {'userId': '0CD36B14-3458-4B65-86C8-A02277631724',
#    'realm': 'Fandango',
#    'displayName': 'love it',
#    'accountLink': None},
#   'score': 5,
#   'timeFromCreation': 'Aug 14, 2019'},
#  {'rating': 'STAR_0_5',
#   'review': "As I would never in a million years actually pay disney money to watch their regurgitated garbage, I got a ticket from a friend and watched in horror as my favorite childhood film was turned into diarrhea garbage in front of my eyes. There was absolutely NOTHING good about this, from the music to the horrible, soulless visuals. There is no inspiration. No creativity. No improvement. Just the vapid urge to make as much easy money as possible. I hope they're ashamed of themselves for continuing to do this crap.",
#   'displayName': 'Victoria J',
#   'displayImageUrl': 'https://graph.facebook.com/v3.3/1736072991/picture',
#   'isVerified': False,
#   'isSuperReviewer': False,
#   'hasSpoilers': False,
#   'hasProfanity': True,
#   'createDate': '2019-08-14T02:33:35.095Z',
#   'updateDate': '2019-08-14T02:33:35.095Z',
#   'user': {'userId': '876487642',
#    'realm': 'RT',
#    'displayName': 'Victoria J',
#    'accountLink': '/user/id/876487642'},
#   'score': 0.5,
#   'timeFromCreation': 'Aug 14, 2019'},
#  {'rating': 'STAR_3',
#   'review': 'A pointless remake of a classic film that leaves viewers with nothing but a need to watch the original. Nostalgia is a wonderful drug and Hollywood is the dealer. ',
#   'displayName': 'David H',
#   'displayImageUrl': None,
#   'isVerified': False,
#   'isSuperReviewer': False,
#   'hasSpoilers': False,
#   'hasProfanity': False,
#   'createDate': '2019-08-14T02:29:56.584Z',
#   'updateDate': '2019-08-14T02:29:56.584Z',
#   'user': {'userId': '934080184',
#    'realm': 'RT',
#    'displayName': 'David H',
#    'accountLink': '/user/id/934080184'},
#   'score': 3,
#   'timeFromCreation': 'Aug 14, 2019'},
#  {'rating': 'STAR_5',
#   'review': 'it was amazing i liked it more then the kids and im 37',
#   'displayName': 'Tina',
#   'displayImageUrl': None,
#   'isVerified': True,
#   'isSuperReviewer': False,
#   'hasSpoilers': False,
#   'hasProfanity': False,
#   'createDate': '2019-08-14T02:24:07.827Z',
#   'updateDate': '2019-08-14T02:25:59.069Z',
#   'user': {'userId': '10E17509-A4D1-4E63-8844-8E5E16107CBD',
#    'realm': 'Fandango',
#    'displayName': 'Tina',
#    'accountLink': None},
#   'score': 5,
#   'timeFromCreation': 'Aug 14, 2019'},
#  ...]

# %% [markdown]
# Type data in which reviews are extracted

# %%
type(theLionKing_reviews)
# Out:
# list

# %% [markdown]
# Saving the given data in "json" format as backup

# %%
import json
with open('theLionKing_reviews.json', 'w', encoding='utf-8') as f:
    json.dump(theLionKing_reviews, f, ensure_ascii=False, indent=4)

# %% [markdown]
# ### Imports for other text preprocessing and classification

# %%
import urllib.request as url
from bs4 import BeautifulSoup as bs
import re
import requests
import warnings
warnings.filterwarnings("ignore")
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

import random
random.seed(123)

# %% [markdown]
# checking the no of reviews in the data

# %%
len(theLionKing_reviews)
# Out:
# 4000

# %% [markdown]
# ### converting JSON data to pandas data

# %%
theLionKing_reviews
# Out:
# [{'rating': 'STAR_2_5',
#   'review': "almost shot for shot. scar is a very weak character in this and trying to be too realistic you lose the magic of the original. it's safe. tilmon and pumba get the most laughs as they also have the most change.",
#   'displayName': None,
#   'displayImageUrl': None,
#   'isVerified': False,
#   'isSuperReviewer': False,
#   'hasSpoilers': False,
#   'hasProfanity': False,
#   'createDate': '2019-08-27T21:39:31.395Z',
#   'updateDate': '2019-08-27T21:39:31.395Z',
#   'user': {'userId': '260316344',
#    'realm': 'RT',
#    'displayName': None,
#    'accountLink': '/user/id/260316344'},
#   'score': 2.5,
#   'timeFromCreation': '24m ago'},
#  {'rating': 'STAR_5',
#   'review': 'Loved the movie! Great CGI, acting, music, felt like I was watching the original all over again! I could go on and on but it’s a great family film! HIGHLY RECOMMEND',
#   'displayName': 'Logan',
#   'displayImageUrl': None,
#   'isVerified': True,
#   'isSuperReviewer': False,
#   'hasSpoilers': False,
#   'hasProfanity': False,
#   'createDate': '2019-08-27T21:13:12.178Z',
#   'updateDate': '2019-08-27T21:13:12.178Z',
#   'user': {'userId': '02750CCE-D2AB-4E3B-A998-6576C1A240E0',
#    'realm': 'Fandango',
#    'displayName': 'Logan',
#    'accountLink': None},
#   'score': 5,
#   'timeFromCreation': '50m ago'},
#  {'rating': 'STAR_3',
#   'review': "If you grew up with (and love) the original animated version, you're not missing out. The live action animals were cute though.  As with the original, Timon & Pumba steal the show.",
#   'displayName': 'Rachel C',
#   'displayImageUrl': 'https://graph.facebook.com/v3.3/10221590382855950/picture',
#   'isVerified': False,
#   'isSuperReviewer': False,
#   'hasSpoilers': False,
#   'hasProfanity': False,
#   'createDate': '2019-08-27T20:58:51.447Z',
#   'updateDate': '2019-08-27T20:58:51.447Z',
#   'user': {'userId': '978214951',
#    'realm': 'RT',
#    'displayName': 'Rachel C',
#    'accountLink': '/user/id/978214951'},
#   'score': 3,
#   'timeFromCreation': '1h ago'},
#  {'rating': 'STAR_2_5',
#   'review': 'While it can take pride in its visual achievements, The Lion King is a by-the-numbers retelling that lacks the energy and heart that made the original so beloved-though for some fans that may just be enough.',
#   'displayName': 'Peter J',
#   'displayImageUrl': None,
#   'isVerified': False,
#   'isSuperReviewer': False,
#   'hasSpoilers': False,
#   'hasProfanity': False,
#   'createDate': '2019-08-27T20:27:50.707Z',
#   'updateDate': '2019-08-27T20:27:54.169Z',
#   'user': {'userId': '977694797',
#    'realm': 'RT',
#    'displayName': 'Peter J',
#    'accountLink': '/user/id/977694797'},
#   'score': 2.5,
#   'timeFromCreation': '2h ago'},
#  {'rating': 'STAR_5',
#   'review': 'It was seriously a stunning movie. Great graphics. Crisp. Adorable movie.',
#   'displayName': 'Devon',
#   'displayImageUrl': None,
#   'isVerified': True,
#   'isSuperReviewer': False,
#   'hasSpoilers': False,
#   'hasProfanity': False,
#   'createDate': '2019-08-27T20:15:05.755Z',
#   'updateDate': '2019-08-27T20:15:05.755Z',
#   'user': {'userId': 'AC172773-33D5-466B-8E82-C5178AB51CAF',
#    'realm': 'Fandango',
#    'displayName': 'Devon',
#    'accountLink': None},
#   'score': 5,
#   'timeFromCreation': '2h ago'},
#  {'rating': 'STAR_5',
#   'review': "I loved this remake. The cartoon is one of my favorite movies and this remake was extremely similar to the cartoon version. I'd say it matches like 90%, scene for scene and dialogue. It's almost like watching an episode of animal planet...but with singing animals and intense drama. I thought it did a phenomenal job sticking to the original while at the same time making some changes.  ",
#   'displayName': 'Samantha T',
#   'displayImageUrl': 'https://graph.facebook.com/v3.3/100001784076128/picture',
#   'isVerified': False,
#   'isSuperReviewer': False,
#   'hasSpoilers': False,
#   'hasProfanity': False,
#   'createDate': '2019-08-27T20:10:24.720Z',
#   'updateDate': '2019-08-27T20:10:24.720Z',
#   'user': {'userId': '923215533',
#    'realm': 'RT',
#    'displayName': 'Samantha T',
#    'accountLink': '/user/id/923215533'},
#   'score': 5,
#   'timeFromCreation': '2h ago'},
#  {'rating': 'STAR_2',
#   'review': 'the only thing i thought was a great scene was the fighting scenes. i dont think it beat the original in anyway',
#   'displayName': 'saiyanelite',
#   'displayImageUrl': None,
#   'isVerified': True,
#   'isSuperReviewer': False,
#   'hasSpoilers': False,
#   'hasProfanity': False,
#   'createDate': '2019-08-27T19:41:11.714Z',
#   'updateDate': '2019-08-27T19:42:52.104Z',
#   'user': {'userId': 'd452e337-0bf3-4df6-9a73-a37d5c2cfb94',
#    'realm': 'Fandango',
#    'displayName': 'saiyanelite',
#    'accountLink': None},
#   'score': 2,
#   'timeFromCreation': '2h ago'},
#  {'rating': 'STAR_5',
#   'review': 'Good movie, we enjoyed it a lot',
#   'displayName': 'Lisa',
#   'displayImageUrl': None,
#   'isVerified': True,
#   'isSuperReviewer': False,
#   'hasSpoilers': False,
#   'hasProfanity': False,
#   'createDate': '2019-08-27T19:39:19.611Z',
#   'updateDate': '2019-08-27T19:39:19.611Z',
#   'user': {'userId': '7aec84e7-5aec-418c-ac92-31e3fbdbe81e',
#    'realm': 'Fandango',
#    'displayName': 'Lisa',
#    'accountLink': None},
#   'score': 5,
#   'timeFromCreation': '2h ago'},
#  {'rating': 'STAR_3',
#   'review': 'I liked it, my kids loved it. I prefer the original -- my kinds asked "There\'s an original!?!?" Parenting fail.',
#   'displayName': 'Levy M',
#   'displayImageUrl': 'https://graph.facebook.com/v3.3/1112244759/picture',
#   'isVerified': False,
#   'isSuperReviewer': False,
#   'hasSpoilers': False,
#   'hasProfanity': False,
#   'createDate': '2019-08-27T19:03:20.510Z',
#   'updateDate': '2019-08-27T19:03:20.510Z',
#   'user': {'userId': '823571697',
#    'realm': 'RT',
#    'displayName': 'Levy M',
#    'accountLink': '/user/id/823571697'},
#   'score': 3,
#   'timeFromCreation': '3h ago'},
#  {'rating': 'STAR_2',
#   'review': '😁I just saw the Lion King and I have to say.........\nI was bored out of my mind. It\'s rant time:\n\n😟Hear me out! The animators were the shit. I have had a peek into the process and know it took a MONSTROUS amount of work to create the characters. You could see the muscles and even the veins!! They did an AMAZING job creating the world and it\'s animals in this movie.\n\n😡However, I\'ve got a lot of beef with this movie. It was like a delicious looking cake that had no flavor and no ice cream on the side. This is Disney, and I want my side of fucking ice cream.\n.\n1) Character design: It looked fantastic and super realistic, but that\'s the problem right there; It looked SOOOO realistic, that the expressions on the characters were nearly non existent. It is possible to create this kind of realism, but still have enough imaginative unrealistic designs that wont clash. Look at Smaug and how Bennedict played that character; it looked real, and the performance is fucking GREAT. Just go look up the youtube vid of him in the motion capture suit.  Without good BODY LANGUAGE AND FACIAL EXPRESSIONS, you could easily tell it was just actors standing in front of a mic and not throwing themselves into the role. \n\n2) Voice Actors: They were also flat as fuck. I was hyped about the cast, so this was really disappointing. The inflections on the lines just didnt come off of the screen. It sounded like all the animals were shitty high school kids that happened to have nice singing voices do their first Lion King play 1 week after getting the script. I was looking forward to that moment where Scar warns Mufasa not to turn his back on him and suddenly Mufasa has this THREATENING voice saying "Is that a challenge?!". That moment came on screen and I was bored (seriously, look at the original). No emotional content. The voice directing was trash.\n\n1+2=3) With one and two combined, it\'s just crap. Emotionless crap. I didnt feel Simba\'s pain or fear when his father died, and I wanted to. When you have super realistic animals, you dont get facial expressions. Combine that with weak voice inflections and I felt nothing. No pauses or moments where you could feel tension or any sort of movement of emotion.\n\n4) Carbon Copy: I KNOW it is a remake, but I feel like they majorly missed an opportunity. They should have dropped every damn song but Hakuna Matata and made more time for character development. I cant believe Scar breaking into song looking like that. \n\nWhat do I mean by character development? I LOVE DC\'s animated movies. Under the Red Hood is fucking dope. However, if you copy that exactly into a live action movie, the characters will likely seem a bit flat. I think when you bring more realism to the screen, you have to care more about your characters. I dont fully know how to explain it. More story to support a character\'s emotional journey is needed the closer it gets to reality I think. Drop the songs and add more scenes or dialogue along those lines and MAYBE I would have felt it more. \n\nThe battle for pride rock mostly sucked. Why copy? You have so much to build on!! What if Scar had a small army of animals that were "protected" going up against Simba and his rebels at the end? What if it was closer to a war? Just a thought...\n\n5) The story boarding was trash. Too much lifted from the original. If you cant use facial expressions, then you need to pick your shots and place your figures (i forget the term for that) better to make the audience feel certain emotions. \nOk, there have been worse, but again...with all this technology, your visual storytelling should have been much better. \n\nThe movie looks fantastic, but I wanted to walk out. I stayed hoping that the final battle or Childish Gambino would rock it. Nope. The original Lion King movie better. \n\nAnyways, rant over. I should have made a youtube vid out of this.',
#   'displayName': 'Xavier P',
#   'displayImageUrl': 'https://graph.facebook.com/v3.3/1320956777/picture',
#   'isVerified': False,
#   'isSuperReviewer': False,
#   'hasSpoilers': False,
#   'hasProfanity': True,
#   'createDate': '2019-08-27T18:38:44.923Z',
#   'updateDate': '2019-08-27T18:38:44.923Z',
#   'user': {'userId': '883901140',
#    'realm': 'RT',
#    'displayName': 'Xavier P',
#    'accountLink': '/user/id/883901140'},
#   'score': 2,
#   'timeFromCreation': '3h ago'},
#  {'rating': 'STAR_2_5',
#   'review': 'Pretty much a shot for shot remake of the classic animated movie. Kinda boring',
#   'displayName': None,
#   'displayImageUrl': None,
#   'isVerified': False,
#   'isSuperReviewer': False,
#   'hasSpoilers': False,
#   'hasProfanity': False,
#   'createDate': '2019-08-27T17:45:03.573Z',
#   'updateDate': '2019-08-27T17:45:03.573Z',
#   'user': {'userId': '976495119',
#    'realm': 'RT',
#    'displayName': None,
#    'accountLink': '/user/id/976495119'},
#   'score': 2.5,
#   'timeFromCreation': '4h ago'},
#  {'rating': 'STAR_3_5',
#   'review': 'although this movie doesent realy add anything to the original film it is still fun to watch.\n',
#   'displayName': 'robin m',
#   'displayImageUrl': None,
#   'isVerified': False,
#   'isSuperReviewer': False,
#   'hasSpoilers': False,
#   'hasProfanity': False,
#   'createDate': '2019-08-27T17:41:24.358Z',
#   'updateDate': '2019-08-27T17:41:24.358Z',
#   'user': {'userId': '975498867',
#    'realm': 'RT',
#    'displayName': 'robin m',
#    'accountLink': '/user/id/975498867'},
#   'score': 3.5,
#   'timeFromCreation': '4h ago'},
#  {'rating': 'STAR_4',
#   'review': "The absolute best animation/computer graphics I've seen. This movie should sweep the awards for that reason alone. Stunning. The movie itself was great also - but I have to say that this format really brought out the dark and violent, evil side inherent in the plot ... somehow the circle of life was out-shadowed by the darkness. Doesn't feel like a kid's movie in the respect. Or even a movie for adults seeking more.",
#   'displayName': 'Ginger',
#   'displayImageUrl': None,
#   'isVerified': True,
#   'isSuperReviewer': False,
#   'hasSpoilers': False,
#   'hasProfanity': False,
#   'createDate': '2019-08-27T17:08:42.618Z',
#   'updateDate': '2019-08-27T17:08:42.618Z',
#   'user': {'userId': '6dcf3c0f-5c43-4b92-9566-75586deae351',
#    'realm': 'Fandango',
#    'displayName': 'Ginger',
#    'accountLink': None},
#   'score': 4,
#   'timeFromCreation': '5h ago'},
#  {'rating': 'STAR_4',
#   'review': 'It was really good. I loved it! Just as good as the original.',
#   'displayName': 'Jessica T',
#   'displayImageUrl': None,
#   'isVerified': True,
#   'isSuperReviewer': False,
#   'hasSpoilers': False,
#   'hasProfanity': False,
#   'createDate': '2019-08-27T17:08:42.509Z',
#   'updateDate': '2019-08-27T17:08:42.509Z',
#   'user': {'userId': 'e5a8cfc3-6606-4567-b27c-b617d7618982',
#    'realm': 'Fandango',
#    'displayName': 'Jessica T',
#    'accountLink': None},
#   'score': 4,
#   'timeFromCreation': '5h ago'},
#  {'rating': 'STAR_4_5',
#   'review': 'I just wish the hyenas were funny. They played a major role in the original.',
#   'displayName': 'Kimberly',
#   'displayImageUrl': None,
#   'isVerified': True,
#   'isSuperReviewer': False,
#   'hasSpoilers': False,
#   'hasProfanity': False,
#   'createDate': '2019-08-27T16:36:52.867Z',
#   'updateDate': '2019-08-27T16:36:52.867Z',
#   'user': {'userId': 'bd1c1f84-a695-4f0d-91c8-6ed4abb1769c',
#    'realm': 'Fandango',
#    'displayName': 'Kimberly',
#    'accountLink': None},
#   'score': 4.5,
#   'timeFromCreation': '5h ago'},
#  {'rating': 'STAR_3_5',
#   'review': 'There is one word to describe this movie. That is word is average. It felt like watching the original adaptation all over again.',
#   'displayName': 'Robert A',
#   'displayImageUrl': None,
#   'isVerified': False,
#   'isSuperReviewer': False,
#   'hasSpoilers': False,
#   'hasProfanity': False,
#   'createDate': '2019-08-27T16:09:47.208Z',
#   'updateDate': '2019-08-27T16:16:23.661Z',
#   'user': {'userId': '978214701',
#    'realm': 'RT',
#    'displayName': 'Robert A',
#    'accountLink': '/user/id/978214701'},
#   'score': 3.5,
#   'timeFromCreation': '6h ago'},
#  {'rating': 'STAR_4',
#   'review': 'Love the story - wonderfully done',
#   'displayName': 'HKS',
#   'displayImageUrl': None,
#   'isVerified': False,
#   'isSuperReviewer': False,
#   'hasSpoilers': False,
#   'hasProfanity': False,
#   'createDate': '2019-08-27T16:00:30.362Z',
#   'updateDate': '2019-08-27T16:00:30.362Z',
#   'user': {'userId': 'A9B74183-273B-4188-B5C4-418ACDA9CE07',
#    'realm': 'Fandango',
#    'displayName': 'HKS',
#    'accountLink': None},
#   'score': 4,
#   'timeFromCreation': '6h ago'},
#  {'rating': 'STAR_0_5',
#   'review': "Walked out half way thru the movie my kids kept falling asleep and so was I. I  certainly wasn't going to stay watching it alone I hadnt chosen it in the first place!",
#   'displayName': 'Jesse',
#   'displayImageUrl': None,
#   'isVerified': True,
#   'isSuperReviewer': False,
#   'hasSpoilers': False,
#   'hasProfanity': False,
#   'createDate': '2019-08-27T15:49:34.888Z',
#   'updateDate': '2019-08-27T15:49:35.444Z',
#   'user': {'userId': 'bb3d4e53-12f1-4616-bd4d-ae7e419bcda1',
#    'realm': 'Fandango',
#    'displayName': 'Jesse',
#    'accountLink': None},
#   'score': 0.5,
#   'timeFromCreation': '6h ago'},
#  {'rating': 'STAR_5',
#   'review': 'The Lion King movie is so beautiful. It was able to capture the magic of the original. It was a special movie to share with my kids.',
#   'displayName': 'Mommytrex',
#   'displayImageUrl': None,
#   'isVerified': True,
#   'isSuperReviewer': False,
#   'hasSpoilers': False,
#   'hasProfanity': False,
#   'createDate': '2019-08-27T15:24:39.629Z',
#   'updateDate': '2019-08-27T15:24:39.629Z',
#   'user': {'userId': '0b6d99f2-dd01-460d-95bb-8fa2eda6acc3',
#    'realm': 'Fandango',
#    'displayName': 'Mommytrex',
#    'accountLink': None},
#   'score': 5,
#   'timeFromCreation': '7h ago'},
#  {'rating': 'STAR_5',
#   'review': 'No dislikes once so ever. Enjoyed the movie, and the theater very much.',
#   'displayName': 'Ashlee Barrette',
#   'displayImageUrl': None,
#   'isVerified': True,
#   'isSuperReviewer': False,
#   'hasSpoilers': False,
#   'hasProfanity': False,
#   'createDate': '2019-08-27T14:58:26.597Z',
#   'updateDate': '2019-08-27T14:58:29.150Z',
#   'user': {'userId': '169f6758-f3ea-45bf-b57d-2c2ac4f44488',
#    'realm': 'Fandango',
#    'displayName': 'Ashlee Barrette',
#    'accountLink': None},
#   'score': 5,
#   'timeFromCreation': '7h ago'},
#  {'rating': 'STAR_3',
#   'review': 'This movie was visually gorgeous as one would expect but in the end it just felt rushed. From the opening sequence it felt shorter and less grandiose than the original. The voice actors did a good job but not great. The originals did a much better job of selling their personalities as animals where this version failed to suspend the disbelief. Many of the moments felt like a person singing the songs rather than the actual characters. It also seemed like they changed each song slightly to fit the voice actors strengths rather than casting someone that could pull off the original ensembles. Overall it was a good watch because it was just visually breathtaking, but as whole this really falls flat considering the high hopes and expectations set for such a classic and nostalgic movie. ',
#   'displayName': 'Victor M',
#   'displayImageUrl': None,
#   'isVerified': False,
#   'isSuperReviewer': False,
#   'hasSpoilers': False,
#   'hasProfanity': False,
#   'createDate': '2019-08-27T14:56:07.298Z',
#   'updateDate': '2019-08-27T14:56:07.298Z',
#   'user': {'userId': '978099203',
#    'realm': 'RT',
#    'displayName': 'Victor M',
#    'accountLink': '/user/id/978099203'},
#   'score': 3,
#   'timeFromCreation': '7h ago'},
#  {'rating': 'STAR_1',
#   'review': 'Terrible acting, terrible editing, music was off, singing was bad. They tried to expand on the story where it didn’t need it and they took out the comedy. The only redeeming quality was the CGI.',
#   'displayName': 'E',
#   'displayImageUrl': None,
#   'isVerified': False,
#   'isSuperReviewer': False,
#   'hasSpoilers': False,
#   'hasProfanity': False,
#   'createDate': '2019-08-27T14:18:54.400Z',
#   'updateDate': '2019-08-27T14:18:54.400Z',
#   'user': {'userId': '9CCF03C9-1435-4EE8-898C-8085FE490F11',
#    'realm': 'Fandango',
#    'displayName': 'E',
#    'accountLink': None},
#   'score': 1,
#   'timeFromCreation': '8h ago'},
#  {'rating': 'STAR_4',
#   'review': 'I loved the realistic animation. However, the voices of the various characters could be improved ( ie Simba\'s voice never matured beyond a juvenile). The intensity of the "fight" scenes could be upsetting to young children.  I really loved it as an adult! Kids would miss alot as in other Disney productions.',
#   'displayName': 'Linda',
#   'displayImageUrl': None,
#   'isVerified': False,
#   'isSuperReviewer': False,
#   'hasSpoilers': False,
#   'hasProfanity': False,
#   'createDate': '2019-08-27T13:43:07.329Z',
#   'updateDate': '2019-08-27T13:43:07.329Z',
#   'user': {'userId': 'e7bf82ae-8f0c-4dcb-b98d-7c6dfb75eb8c',
#    'realm': 'Fandango',
#    'displayName': 'Linda',
#    'accountLink': None},
#   'score': 4,
#   'timeFromCreation': '8h ago'},
#  {'rating': 'STAR_5',
#   'review': "The story itself is beautiful and this real not animated made it more spectacular. But Beyonce did not add passion to Nala's voice. Her voice was too soft.",
#   'displayName': 'Maria N',
#   'displayImageUrl': None,
#   'isVerified': True,
#   'isSuperReviewer': False,
#   'hasSpoilers': False,
#   'hasProfanity': False,
#   'createDate': '2019-08-27T13:18:09.412Z',
#   'updateDate': '2019-08-27T13:18:09.412Z',
#   'user': {'userId': '4869189d-936c-4e6b-b716-783c594e8d3f',
#    'realm': 'Fandango',
#    'displayName': 'Maria N',
#    'accountLink': None},
#   'score': 5,
#   'timeFromCreation': '9h ago'},
#  {'rating': 'STAR_5',
#   'review': 'The movie stayed very true to the original but at the same time adding more life and humor. I loved it!',
#   'displayName': 'Danelle H',
#   'displayImageUrl': None,
#   'isVerified': False,
#   'isSuperReviewer': False,
#   'hasSpoilers': False,
#   'hasProfanity': False,
#   'createDate': '2019-08-27T13:17:10.242Z',
#   'updateDate': '2019-08-27T13:17:10.242Z',
#   'user': {'userId': '978186590',
#    'realm': 'RT',
#    'displayName': 'Danelle H',
#    'accountLink': '/user/id/978186590'},
#   'score': 5,
#   'timeFromCreation': '9h ago'},
#  {'rating': 'STAR_5',
#   'review': 'Just like the original movie! Visually stunning!',
#   'displayName': 'Andrew',
#   'displayImageUrl': None,
#   'isVerified': True,
#   'isSuperReviewer': False,
#   'hasSpoilers': False,
#   'hasProfanity': False,
#   'createDate': '2019-08-27T12:40:20.372Z',
#   'updateDate': '2019-08-27T12:40:20.813Z',
#   'user': {'userId': '4d7453b2-8052-4cd0-bfb3-8dbddd57de30',
#    'realm': 'Fandango',
#    'displayName': 'Andrew',
#    'accountLink': None},
#   'score': 5,
#   'timeFromCreation': '9h ago'},
#  {'rating': 'STAR_2',
#   'review': 'The story is sound, as it was in 1994. This animation update told the story. The casting was way off and was taken miles too seriously. Disney was clearly doing everything in its power to be relevant and diverse at the expense of quality. Nothing more than a cash grab to offset their recent billion dollar purchases. If you have seen Lion King... you have already seen this.',
#   'displayName': 'Shane G',
#   'displayImageUrl': 'https://graph.facebook.com/v3.3/10152507834680934/picture',
#   'isVerified': False,
#   'isSuperReviewer': False,
#   'hasSpoilers': False,
#   'hasProfanity': False,
#   'createDate': '2019-08-27T12:24:18.684Z',
#   'updateDate': '2019-08-27T12:24:18.684Z',
#   'user': {'userId': '974655827',
#    'realm': 'RT',
#    'displayName': 'Shane G',
#    'accountLink': '/user/id/974655827'},
#   'score': 2,
#   'timeFromCreation': '10h ago'},
#  {'rating': 'STAR_5',
#   'review': 'I liked the story and how they did the animation.',
#   'displayName': 'sherry',
#   'displayImageUrl': None,
#   'isVerified': True,
#   'isSuperReviewer': False,
#   'hasSpoilers': False,
#   'hasProfanity': False,
#   'createDate': '2019-08-27T10:53:02.119Z',
#   'updateDate': '2019-08-27T10:53:02.119Z',
#   'user': {'userId': '0791a557-c9c4-4f56-bdf3-c7c4a003b619',
#    'realm': 'Fandango',
#    'displayName': 'sherry',
#    'accountLink': None},
#   'score': 5,
#   'timeFromCreation': '11h ago'},
#  {'rating': 'STAR_4',
#   'review': 'Another great Disney movie!!',
#   'displayName': 'SP',
#   'displayImageUrl': None,
#   'isVerified': True,
#   'isSuperReviewer': False,
#   'hasSpoilers': False,
#   'hasProfanity': False,
#   'createDate': '2019-08-27T10:50:47.880Z',
#   'updateDate': '2019-08-27T10:50:47.880Z',
#   'user': {'userId': '6ba340da-3c16-4277-87d1-2dc62692caa4',
#    'realm': 'Fandango',
#    'displayName': 'SP',
#    'accountLink': None},
#   'score': 4,
#   'timeFromCreation': '11h ago'},
#  {'rating': 'STAR_3',
#   'review': 'Beyonce cannot act. Not even a little bit. That is all. ',
#   'displayName': None,
#   'displayImageUrl': None,
#   'isVerified': False,
#   'isSuperReviewer': False,
#   'hasSpoilers': False,
#   'hasProfanity': False,
#   'createDate': '2019-08-27T10:10:27.958Z',
#   'updateDate': '2019-08-27T10:10:27.958Z',
#   'user': {'userId': '867811394',
#    'realm': 'RT',
#    'displayName': None,
#    'accountLink': '/user/id/867811394'},
#   'score': 3,
#   'timeFromCreation': '12h ago'},
#  {'rating': 'STAR_5',
#   'review': 'We loved the movie!!  The storyline and integrity of the movie remained the same and the new modern elements were FANTASTIC! The actors character voices were PHENOMENAL! The songs (old and new) as well as the digital effects were OUTSTANDING! Thank you for keeping James Earl Jones as Mufasa! Lion King is simply a great movie for everyone to see!! THE BEST!!',
#   'displayName': 'Yolanda',
#   'displayImageUrl': None,
#   'isVerified': True,
#   'isSuperReviewer': False,
#   'hasSpoilers': False,
#   'hasProfanity': False,
#   'createDate': '2019-08-27T07:47:57.018Z',
#   'updateDate': '2019-08-27T07:48:01.447Z',
#   'user': {'userId': 'cf405655-e57b-445e-a67c-c026f75f63d4',
#    'realm': 'Fandango',
#    'displayName': 'Yolanda',
#    'accountLink': None},
#   'score': 5,
#   'timeFromCreation': '14h ago'},
#  {'rating': 'STAR_5',
#   'review': 'I liked everything, it is awesome to remember the marvelous story and the magnificent music!!',
#   'displayName': 'Maria',
#   'displayImageUrl': None,
#   'isVerified': True,
#   'isSuperReviewer': False,
#   'hasSpoilers': False,
#   'hasProfanity': False,
#   'createDate': '2019-08-27T07:20:02.412Z',
#   'updateDate': '2019-08-27T07:20:02.412Z',
#   'user': {'userId': '5414369d-cee7-41ae-8aab-4b366fb03c40',
#    'realm': 'Fandango',
#    'displayName': 'Maria',
#    'accountLink': None},
#   'score': 5,
#   'timeFromCreation': '15h ago'},
#  {'rating': 'STAR_5',
#   'review': 'Unbelievable imaging by computer.  I thought this was one of the best movies so far this year.',
#   'displayName': 'Dan',
#   'displayImageUrl': None,
#   'isVerified': True,
#   'isSuperReviewer': False,
#   'hasSpoilers': False,
#   'hasProfanity': False,
#   'createDate': '2019-08-27T05:38:02.493Z',
#   'updateDate': '2019-08-27T05:38:02.493Z',
#   'user': {'userId': 'ac9d6010-c559-42f5-8324-6ca667acd3c8',
#    'realm': 'Fandango',
#    'displayName': 'Dan',
#    'accountLink': None},
#   'score': 5,
#   'timeFromCreation': '16h ago'},
#  {'rating': 'STAR_2_5',
#   'review': 'Eh the movie was ok but literally a shot by shot remake of the original Lion King and seen a bit the original animated film at choir and I liked it more so the remake is a 6/10',
#   'displayName': 'Pokmon  G',
#   'displayImageUrl': None,
#   'isVerified': False,
#   'isSuperReviewer': False,
#   'hasSpoilers': False,
#   'hasProfanity': False,
#   'createDate': '2019-08-27T05:05:22.950Z',
#   'updateDate': '2019-08-27T05:05:22.950Z',
#   'user': {'userId': '978113631',
#    'realm': 'RT',
#    'displayName': 'Pokmon  G',
#    'accountLink': '/user/id/978113631'},
#   'score': 2.5,
#   'timeFromCreation': '17h ago'},
#  {'rating': 'STAR_5',
#   'review': "The movie was as emotional as the animated version and more dramatic because of it being live action, sort of . Jon Favreau does an excellent job as director Donald Glover, Beyonce Knowles-Carter were a great choice to voice Simba and Nala, as well as the other actors cast. Enjoyed that they included the new song Spirit and it fit in with all of the original songs. The critics who criticized the film were wrong I'm glad I ignored them. It's worth every dollar I spent to see it --18.70.",
#   'displayName': 'Sakinah A',
#   'displayImageUrl': None,
#   'isVerified': True,
#   'isSuperReviewer': False,
#   'hasSpoilers': False,
#   'hasProfanity': False,
#   'createDate': '2019-08-27T04:25:15.238Z',
#   'updateDate': '2019-08-27T04:25:15.238Z',
#   'user': {'userId': '0be115e3-b04c-4355-925a-2d94afdf2b2f',
#    'realm': 'Fandango',
#    'displayName': 'Sakinah A',
#    'accountLink': None},
#   'score': 5,
#   'timeFromCreation': '18h ago'},
#  {'rating': 'STAR_2',
#   'review': 'The original was way better.',
#   'displayName': 'Edurdo C',
#   'displayImageUrl': None,
#   'isVerified': True,
#   'isSuperReviewer': False,
#   'hasSpoilers': False,
#   'hasProfanity': False,
#   'createDate': '2019-08-27T04:02:28.129Z',
#   'updateDate': '2019-08-27T04:02:28.129Z',
#   'user': {'userId': '3914efd0-57cb-4d0a-8296-ffef76f877f7',
#    'realm': 'Fandango',
#    'displayName': 'Edurdo C',
#    'accountLink': None},
#   'score': 2,
#   'timeFromCreation': '18h ago'},
#  {'rating': 'STAR_5',
#   'review': 'Loved the Movie! It had the original story theme with more humor ! 5 stars !',
#   'displayName': 'Lorri',
#   'displayImageUrl': None,
#   'isVerified': True,
#   'isSuperReviewer': False,
#   'hasSpoilers': False,
#   'hasProfanity': False,
#   'createDate': '2019-08-27T03:10:47.578Z',
#   'updateDate': '2019-08-27T03:10:48.793Z',
#   'user': {'userId': '6c6b13c2-2f32-462c-bc99-93eef39da1e2',
#    'realm': 'Fandango',
#    'displayName': 'Lorri',
#    'accountLink': None},
#   'score': 5,
#   'timeFromCreation': '19h ago'},
#  {'rating': 'STAR_0_5',
#   'review': 'the picture of the movies was amazing. the reason for the half star. everything else with the movie was just horrible. they took out every good part from the original movie. there is no words to explain how horrible the singing was. dont care who they got to sing. honestly the 1980 movie was 100% better. even my 5yr old. said daddy can we go home and watch the original lion king. please you aim for the younger generation and they would rather watch the 1980 movie. now thays sad',
#   'displayName': None,
#   'displayImageUrl': None,
#   'isVerified': False,
#   'isSuperReviewer': False,
#   'hasSpoilers': False,
#   'hasProfanity': False,
#   'createDate': '2019-08-27T02:57:09.009Z',
#   'updateDate': '2019-08-27T02:57:09.009Z',
#   'user': {'userId': '260306393',
#    'realm': 'RT',
#    'displayName': None,
#    'accountLink': '/user/id/260306393'},
#   'score': 0.5,
#   'timeFromCreation': '19h ago'},
#  {'rating': 'STAR_3_5',
#   'review': 'I am just not a Beyoncé fan, however everything else was very cute and nostalgic!',
#   'displayName': 'dreastar',
#   'displayImageUrl': None,
#   'isVerified': True,
#   'isSuperReviewer': False,
#   'hasSpoilers': False,
#   'hasProfanity': False,
#   'createDate': '2019-08-27T02:24:25.377Z',
#   'updateDate': '2019-08-27T02:24:25.377Z',
#   'user': {'userId': 'C5EE83A1-187C-438E-8ABC-5170B3195159',
#    'realm': 'Fandango',
#    'displayName': 'dreastar',
#    'accountLink': None},
#   'score': 3.5,
#   'timeFromCreation': '20h ago'},
#  {'rating': 'STAR_2_5',
#   'review': 'Very low energy movie. Meh..  Zero excitement',
#   'displayName': 'Nichole C',
#   'displayImageUrl': None,
#   'isVerified': True,
#   'isSuperReviewer': False,
#   'hasSpoilers': False,
#   'hasProfanity': False,
#   'createDate': '2019-08-27T01:20:18.736Z',
#   'updateDate': '2019-08-27T15:20:53.718Z',
#   'user': {'userId': 'cb583034-8660-4736-ab31-45bab2794b36',
#    'realm': 'Fandango',
#    'displayName': 'Nichole C',
#    'accountLink': None},
#   'score': 2.5,
#   'timeFromCreation': '21h ago'},
#  {'rating': 'STAR_4_5',
#   'review': 'Really good, but missed some of the original moments.',
#   'displayName': 'Lindsey',
#   'displayImageUrl': None,
#   'isVerified': True,
#   'isSuperReviewer': False,
#   'hasSpoilers': False,
#   'hasProfanity': False,
#   'createDate': '2019-08-27T01:13:54.238Z',
#   'updateDate': '2019-08-27T01:13:54.238Z',
#   'user': {'userId': '4236761F-DFBB-4F10-8A89-C6B45AEA2178',
#    'realm': 'Fandango',
#    'displayName': 'Lindsey',
#    'accountLink': None},
#   'score': 4.5,
#   'timeFromCreation': '21h ago'},
#  {'rating': 'STAR_5',
#   'review': 'Great reproduction of the original animated film. Well done',
#   'displayName': 'Richard',
#   'displayImageUrl': None,
#   'isVerified': True,
#   'isSuperReviewer': False,
#   'hasSpoilers': False,
#   'hasProfanity': False,
#   'createDate': '2019-08-27T01:07:17.180Z',
#   'updateDate': '2019-08-27T01:07:17.180Z',
#   'user': {'userId': 'd06c19ad-9871-45d0-8bb3-b6fc5f086b2d',
#    'realm': 'Fandango',
#    'displayName': 'Richard',
#    'accountLink': None},
#   'score': 5,
#   'timeFromCreation': '21h ago'},
#  {'rating': 'STAR_5',
#   'review': 'Extraordinary. Animation was so lifelike. Entertaining, funny and emotional.',
#   'displayName': 'Francine',
#   'displayImageUrl': None,
#   'isVerified': True,
#   'isSuperReviewer': False,
#   'hasSpoilers': False,
#   'hasProfanity': False,
#   'createDate': '2019-08-27T00:55:12.486Z',
#   'updateDate': '2019-08-27T00:55:12.486Z',
#   'user': {'userId': 'c6698059-0d7f-48dc-a0d3-8c4537cc3ef9',
#    'realm': 'Fandango',
#    'displayName': 'Francine',
#    'accountLink': None},
#   'score': 5,
#   'timeFromCreation': '21h ago'},
#  {'rating': 'STAR_2_5',
#   'review': 'Seth Rogen was the only good thing in it. There were some songs they got right, but overall, not great.',
#   'displayName': 'Q T',
#   'displayImageUrl': None,
#   'isVerified': False,
#   'isSuperReviewer': False,
#   'hasSpoilers': False,
#   'hasProfanity': False,
#   'createDate': '2019-08-27T00:50:01.793Z',
#   'updateDate': '2019-08-27T00:50:01.793Z',
#   'user': {'userId': '972972878',
#    'realm': 'RT',
#    'displayName': 'Q T',
#    'accountLink': '/user/id/972972878'},
#   'score': 2.5,
#   'timeFromCreation': '21h ago'},
#  {'rating': 'STAR_4',
#   'review': 'Thought it was really good just some parts not appropriate for small children.',
#   'displayName': 'Wendy',
#   'displayImageUrl': None,
#   'isVerified': True,
#   'isSuperReviewer': False,
#   'hasSpoilers': False,
#   'hasProfanity': False,
#   'createDate': '2019-08-27T00:27:36.014Z',
#   'updateDate': '2019-08-27T00:27:36.014Z',
#   'user': {'userId': '318da3ee-5751-4b43-9032-fa774a35abd6',
#    'realm': 'Fandango',
#    'displayName': 'Wendy',
#    'accountLink': None},
#   'score': 4,
#   'timeFromCreation': '22h ago'},
#  {'rating': 'STAR_3',
#   'review': "Somewhat slow in beginning but very true to original. Beyonce's songs were awesome",
#   'displayName': 'LGG',
#   'displayImageUrl': None,
#   'isVerified': True,
#   'isSuperReviewer': False,
#   'hasSpoilers': False,
#   'hasProfanity': False,
#   'createDate': '2019-08-27T00:25:16.351Z',
#   'updateDate': '2019-08-27T00:25:16.351Z',
#   'user': {'userId': 'afddf757-4beb-4b2d-96cb-30d4ba921aa3',
#    'realm': 'Fandango',
#    'displayName': 'LGG',
#    'accountLink': None},
#   'score': 3,
#   'timeFromCreation': '22h ago'},
#  {'rating': 'STAR_4',
#   'review': 'a few great scenes from the original were missing, and should have been included.',
#   'displayName': 'Chris T',
#   'displayImageUrl': None,
#   'isVerified': True,
#   'isSuperReviewer': False,
#   'hasSpoilers': False,
#   'hasProfanity': False,
#   'createDate': '2019-08-26T23:35:26.089Z',
#   'updateDate': '2019-08-26T23:35:26.089Z',
#   'user': {'userId': '6c3daac0-3293-4d85-9db4-c6ede381a2fe',
#    'realm': 'Fandango',
#    'displayName': 'Chris T',
#    'accountLink': None},
#   'score': 4,
#   'timeFromCreation': '22h ago'},
#  {'rating': 'STAR_5',
#   'review': 'The live animation was amazing',
#   'displayName': 'Margaret',
#   'displayImageUrl': None,
#   'isVerified': True,
#   'isSuperReviewer': False,
#   'hasSpoilers': False,
#   'hasProfanity': False,
#   'createDate': '2019-08-26T23:33:03.538Z',
#   'updateDate': '2019-08-26T23:33:03.538Z',
#   'user': {'userId': 'bbaec584-bee3-4d13-8ae7-9ba0d46d416b',
#    'realm': 'Fandango',
#    'displayName': 'Margaret',
#    'accountLink': None},
#   'score': 5,
#   'timeFromCreation': '23h ago'},
#  {'rating': 'STAR_5',
#   'review': 'Very gd...Actors was great especially James Earl Jones...',
#   'displayName': 'Simon N',
#   'displayImageUrl': None,
#   'isVerified': True,
#   'isSuperReviewer': False,
#   'hasSpoilers': False,
#   'hasProfanity': False,
#   'createDate': '2019-08-26T23:15:15.148Z',
#   'updateDate': '2019-08-26T23:15:15.148Z',
#   'user': {'userId': '495dd7a6-2344-4dba-8c3d-ed2d44e8c087',
#    'realm': 'Fandango',
#    'displayName': 'Simon N',
#    'accountLink': None},
#   'score': 5,
#   'timeFromCreation': '23h ago'},
#  {'rating': 'STAR_5',
#   'review': 'Wonderful.     It made me feel like was back in Tanzania',
#   'displayName': 'Cindy E',
#   'displayImageUrl': None,
#   'isVerified': True,
#   'isSuperReviewer': False,
#   'hasSpoilers': False,
#   'hasProfanity': False,
#   'createDate': '2019-08-26T23:09:56.262Z',
#   'updateDate': '2019-08-26T23:09:56.262Z',
#   'user': {'userId': 'FC4FE3FF-A4A5-4C05-8434-F269811FFD70',
#    'realm': 'Fandango',
#    'displayName': 'Cindy E',
#    'accountLink': None},
#   'score': 5,
#   'timeFromCreation': '23h ago'},
#  {'rating': 'STAR_2_5',
#   'review': "Shot for shot remake of the original. As far as remakes go this was fine, but unfortunately most of what is praiseworthy about it belongs to a different movie. The animation was photorealistic, which deserves it's own sort of praise, but photorealistic lions don't emote much.",
#   'displayName': 'Kevin S',
#   'displayImageUrl': None,
#   'isVerified': False,
#   'isSuperReviewer': False,
#   'hasSpoilers': False,
#   'hasProfanity': False,
#   'createDate': '2019-08-26T22:49:07.853Z',
#   'updateDate': '2019-08-26T22:49:07.853Z',
#   'user': {'userId': '977880733',
#    'realm': 'RT',
#    'displayName': 'Kevin S',
#    'accountLink': '/user/id/977880733'},
#   'score': 2.5,
#   'timeFromCreation': '23h ago'},
#  {'rating': 'STAR_2_5',
#   'review': 'The Lion King in general is kind of a boring movie with a lot of long drawn out sequences (tuft of fur) but I loved the animation quality of this version and Timon was amazing. I’d recommend seeing it on a cheap day or matinee because it’s good but not full price ticket good.',
#   'displayName': 'Syd',
#   'displayImageUrl': None,
#   'isVerified': True,
#   'isSuperReviewer': False,
#   'hasSpoilers': False,
#   'hasProfanity': False,
#   'createDate': '2019-08-26T22:35:27.292Z',
#   'updateDate': '2019-08-26T22:35:27.292Z',
#   'user': {'userId': 'F0427196-46AB-4EBB-831E-543357040851',
#    'realm': 'Fandango',
#    'displayName': 'Syd',
#    'accountLink': None},
#   'score': 2.5,
#   'timeFromCreation': '23h ago'},
#  {'rating': 'STAR_3_5',
#   'review': "The cartoon was more emotional. \n(SPOILERS)\nWhat I don't understand is if they tried to copy the original almost scene by scene, why did they rush and changed the most important ones? Mufasa's death scene and the part when Nala and Simba find each other again and Nala talk to Pumbaa and Timon explaining Simba and Rafiki's interaction without running away quickly. Overall the movie was great, if you never saw the original one to make comparisons...",
#   'displayName': 'Serena S',
#   'displayImageUrl': 'https://graph.facebook.com/v3.3/10157063722973572/picture',
#   'isVerified': False,
#   'isSuperReviewer': False,
#   'hasSpoilers': False,
#   'hasProfanity': False,
#   'createDate': '2019-08-26T22:13:42.096Z',
#   'updateDate': '2019-08-26T22:24:49.321Z',
#   'user': {'userId': '977883009',
#    'realm': 'RT',
#    'displayName': 'Serena S',
#    'accountLink': '/user/id/977883009'},
#   'score': 3.5,
#   'timeFromCreation': 'Aug 26, 2019'},
#  {'rating': 'STAR_4_5',
#   'review': 'Minus Beyoncé as lion. Can’t act thought I was watching gold member all over again',
#   'displayName': 'Nelson',
#   'displayImageUrl': None,
#   'isVerified': True,
#   'isSuperReviewer': False,
#   'hasSpoilers': False,
#   'hasProfanity': False,
#   'createDate': '2019-08-26T22:08:25.913Z',
#   'updateDate': '2019-08-26T22:08:25.913Z',
#   'user': {'userId': '42D5FEB0-F5EE-4443-A41D-82B5D1EB19D0',
#    'realm': 'Fandango',
#    'displayName': 'Nelson',
#    'accountLink': None},
#   'score': 4.5,
#   'timeFromCreation': 'Aug 26, 2019'},
#  {'rating': 'STAR_5',
#   'review': 'It was cute, funny, entertaining, good all around family movie.',
#   'displayName': 'Lezlie Newton',
#   'displayImageUrl': None,
#   'isVerified': True,
#   'isSuperReviewer': False,
#   'hasSpoilers': False,
#   'hasProfanity': False,
#   'createDate': '2019-08-26T21:39:11.549Z',
#   'updateDate': '2019-08-26T21:39:12.094Z',
#   'user': {'userId': '7c696913-8365-494f-9219-1c4855e75445',
#    'realm': 'Fandango',
#    'displayName': 'Lezlie Newton',
#    'accountLink': None},
#   'score': 5,
#   'timeFromCreation': 'Aug 26, 2019'},
#  {'rating': 'STAR_4_5',
#   'review': 'Great movie!!!   The pictures and sound affect were amazing.  The theatre was clean and the employees were friendly.',
#   'displayName': 'Mary M',
#   'displayImageUrl': None,
#   'isVerified': True,
#   'isSuperReviewer': False,
#   'hasSpoilers': False,
#   'hasProfanity': False,
#   'createDate': '2019-08-26T21:23:28.078Z',
#   'updateDate': '2019-08-26T21:23:28.078Z',
#   'user': {'userId': '26140cf3-8e8e-4076-b43f-42235c2e15fc',
#    'realm': 'Fandango',
#    'displayName': 'Mary M',
#    'accountLink': None},
#   'score': 4.5,
#   'timeFromCreation': '1d ago'},
#  {'rating': 'STAR_0_5',
#   'review': 'Compared to the original one, this movie is dark, violent and depressing. ',
#   'displayName': 'David N',
#   'displayImageUrl': 'https://graph.facebook.com/v3.3/10157683556294180/picture',
#   'isVerified': False,
#   'isSuperReviewer': False,
#   'hasSpoilers': False,
#   'hasProfanity': False,
#   'createDate': '2019-08-26T20:58:40.039Z',
#   'updateDate': '2019-08-26T20:58:40.039Z',
#   'user': {'userId': '978213800',
#    'realm': 'RT',
#    'displayName': 'David N',
#    'accountLink': '/user/id/978213800'},
#   'score': 0.5,
#   'timeFromCreation': '1d ago'},
#  {'rating': 'STAR_5',
#   'review': 'Brought back memories!',
#   'displayName': None,
#   'displayImageUrl': None,
#   'isVerified': False,
#   'isSuperReviewer': False,
#   'hasSpoilers': False,
#   'hasProfanity': False,
#   'createDate': '2019-08-26T20:01:21.501Z',
#   'updateDate': '2019-08-26T20:01:21.501Z',
#   'user': {'userId': '921771525',
#    'realm': 'RT',
#    'displayName': None,
#    'accountLink': '/user/id/921771525'},
#   'score': 5,
#   'timeFromCreation': '1d ago'},
#  {'rating': 'STAR_3',
#   'review': 'Just made me want to watch the original instead ',
#   'displayName': 'jasmine e',
#   'displayImageUrl': None,
#   'isVerified': False,
#   'isSuperReviewer': False,
#   'hasSpoilers': False,
#   'hasProfanity': False,
#   'createDate': '2019-08-26T19:06:33.512Z',
#   'updateDate': '2019-08-26T19:06:33.512Z',
#   'user': {'userId': '978213361',
#    'realm': 'RT',
#    'displayName': 'jasmine e',
#    'accountLink': '/user/id/978213361'},
#   'score': 3,
#   'timeFromCreation': '1d ago'},
#  {'rating': 'STAR_3',
#   'review': 'Too similar to the cartoon.  I would have liked even a few unique differences.  The changes that were made was too few.',
#   'displayName': 'Christopher F',
#   'displayImageUrl': None,
#   'isVerified': True,
#   'isSuperReviewer': False,
#   'hasSpoilers': False,
#   'hasProfanity': False,
#   'createDate': '2019-08-26T18:48:00.383Z',
#   'updateDate': '2019-08-26T18:48:00.383Z',
#   'user': {'userId': 'a6cd65a4-27a7-479f-bd50-424fff9e5dab',
#    'realm': 'Fandango',
#    'displayName': 'Christopher F',
#    'accountLink': None},
#   'score': 3,
#   'timeFromCreation': '1d ago'},
#  {'rating': 'STAR_5',
#   'review': 'An outstanding recreating of the original! The CGI was amazing and the shot composition made for some truly outstanding scenes. The songs were still there but did not feel out of place. ',
#   'displayName': 'Forest N',
#   'displayImageUrl': None,
#   'isVerified': False,
#   'isSuperReviewer': False,
#   'hasSpoilers': False,
#   'hasProfanity': False,
#   'createDate': '2019-08-26T18:26:38.126Z',
#   'updateDate': '2019-08-26T18:26:38.126Z',
#   'user': {'userId': '977205517',
#    'realm': 'RT',
#    'displayName': 'Forest N',
#    'accountLink': '/user/id/977205517'},
#   'score': 5,
#   'timeFromCreation': '1d ago'},
#  {'rating': 'STAR_2_5',
#   'review': "If you want to watch the Lion King go see the original. The remake misses the mark. While the visuals are absolutely phenomenal everything else falls pretty flat. Due to the animals realism they lack facial expressions majorly taking you out of the story and making comedic moments fall flat. The voice casting was ok, though I found at some points Beyonce's voice lacked emotion at the most important times. And the most disappointing for me was all the covers of the original songs. \n\nTo sum it up: worth a watch for visuals and that's about it.",
#   'displayName': 'Delilah S',
#   'displayImageUrl': None,
#   'isVerified': False,
#   'isSuperReviewer': False,
#   'hasSpoilers': False,
#   'hasProfanity': False,
#   'createDate': '2019-08-26T17:31:48.474Z',
#   'updateDate': '2019-08-26T17:31:48.474Z',
#   'user': {'userId': '978213569',
#    'realm': 'RT',
#    'displayName': 'Delilah S',
#    'accountLink': '/user/id/978213569'},
#   'score': 2.5,
#   'timeFromCreation': '1d ago'},
#  {'rating': 'STAR_5',
#   'review': 'My Granddaughter and I loved this film.',
#   'displayName': 'Donna F',
#   'displayImageUrl': None,
#   'isVerified': True,
#   'isSuperReviewer': False,
#   'hasSpoilers': False,
#   'hasProfanity': False,
#   'createDate': '2019-08-26T17:31:28.492Z',
#   'updateDate': '2019-08-26T17:31:28.492Z',
#   'user': {'userId': 'b236f3c9-9375-4c72-a4f5-cada6485e11a',
#    'realm': 'Fandango',
#    'displayName': 'Donna F',
#    'accountLink': None},
#   'score': 5,
#   'timeFromCreation': '1d ago'},
#  {'rating': 'STAR_5',
#   'review': 'The cgi was amazing.  There should never be a need to use real animals for entertainment again.  These were creatures who looked real and had the behaviors of the real wild animals - except that they talked of course.  The story always gets and emotional reaction from me, but this movie was so much more than the other Lion Kings I have seen.',
#   'displayName': 'Tobylerone',
#   'displayImageUrl': None,
#   'isVerified': True,
#   'isSuperReviewer': False,
#   'hasSpoilers': False,
#   'hasProfanity': False,
#   'createDate': '2019-08-26T17:29:23.839Z',
#   'updateDate': '2019-08-26T17:29:23.839Z',
#   'user': {'userId': '8e79b8f1-0494-4e5e-85c3-8ab11d9c8dee',
#    'realm': 'Fandango',
#    'displayName': 'Tobylerone',
#    'accountLink': None},
#   'score': 5,
#   'timeFromCreation': '1d ago'},
#  {'rating': 'STAR_5',
#   'review': 'This movie was nicely done. It teaches families how to behave with one another and how animals are very similar to our  race. The movie teaches you lessons for children and adults. I recommend any age to watch this movie, and I would definitely see it again.',
#   'displayName': 'Lovelizzet.lc82',
#   'displayImageUrl': None,
#   'isVerified': True,
#   'isSuperReviewer': False,
#   'hasSpoilers': False,
#   'hasProfanity': False,
#   'createDate': '2019-08-26T16:55:56.406Z',
#   'updateDate': '2019-08-26T16:55:56.406Z',
#   'user': {'userId': 'de7fabc2-7a44-4f6d-8638-7cc4f0d915f0',
#    'realm': 'Fandango',
#    'displayName': 'Lovelizzet.lc82',
#    'accountLink': None},
#   'score': 5,
#   'timeFromCreation': '1d ago'},
#  {'rating': 'STAR_5',
#   'review': 'The impeccable details in this animation left me awe struck. It evoked more emotion than the original cartoon. I would definitely recommend to all ages for this reason.',
#   'displayName': 'Wendy',
#   'displayImageUrl': None,
#   'isVerified': True,
#   'isSuperReviewer': False,
#   'hasSpoilers': False,
#   'hasProfanity': False,
#   'createDate': '2019-08-26T16:39:20.794Z',
#   'updateDate': '2019-08-26T16:39:20.794Z',
#   'user': {'userId': '1d1a1719-a198-43a8-8a5e-daef73f2e6b2',
#    'realm': 'Fandango',
#    'displayName': 'Wendy',
#    'accountLink': None},
#   'score': 5,
#   'timeFromCreation': '1d ago'},
#  {'rating': 'STAR_4',
#   'review': 'It was good but not what I expected. Still has the feel of the original but not much of that “magic” factor',
#   'displayName': 'Long live the original!',
#   'displayImageUrl': None,
#   'isVerified': True,
#   'isSuperReviewer': False,
#   'hasSpoilers': False,
#   'hasProfanity': False,
#   'createDate': '2019-08-26T15:48:14.497Z',
#   'updateDate': '2019-08-26T15:48:14.497Z',
#   'user': {'userId': '7226CA2C-E8F6-41E7-AE2C-EC0480621DAD',
#    'realm': 'Fandango',
#    'displayName': 'Long live the original!',
#    'accountLink': None},
#   'score': 4,
#   'timeFromCreation': '1d ago'},
#  {'rating': 'STAR_5',
#   'review': 'Outstanding Entertainment for people of all ages',
#   'displayName': 'David F',
#   'displayImageUrl': None,
#   'isVerified': True,
#   'isSuperReviewer': False,
#   'hasSpoilers': False,
#   'hasProfanity': False,
#   'createDate': '2019-08-26T15:28:34.962Z',
#   'updateDate': '2019-08-26T15:28:34.962Z',
#   'user': {'userId': 'aa7cf1a0-24a9-4c00-97b1-b32473a2a1b5',
#    'realm': 'Fandango',
#    'displayName': 'David F',
#    'accountLink': None},
#   'score': 5,
#   'timeFromCreation': '1d ago'},
#  {'rating': 'STAR_4',
#   'review': "I love the movie!  But I'm only giving it 4 stars because I really think it was way more violent then it should have been.  The death scene wasn't really necessary and bothered me, even as a full grown adult!",
#   'displayName': 'Julie A',
#   'displayImageUrl': None,
#   'isVerified': True,
#   'isSuperReviewer': False,
#   'hasSpoilers': False,
#   'hasProfanity': False,
#   'createDate': '2019-08-26T14:32:11.884Z',
#   'updateDate': '2019-08-26T14:32:11.884Z',
#   'user': {'userId': '36658d88-4968-4228-a483-743f7cb659b1',
#    'realm': 'Fandango',
#    'displayName': 'Julie A',
#    'accountLink': None},
#   'score': 4,
#   'timeFromCreation': '1d ago'},
#  {'rating': 'STAR_5',
#   'review': 'Just wish they didn’t use, Beyoncé for, Nalas voice',
#   'displayName': 'Diane C',
#   'displayImageUrl': None,
#   'isVerified': True,
#   'isSuperReviewer': False,
#   'hasSpoilers': False,
#   'hasProfanity': False,
#   'createDate': '2019-08-26T13:45:58.907Z',
#   'updateDate': '2019-08-26T13:45:58.907Z',
#   'user': {'userId': '3BA51C54-A2FC-4063-A029-C8C3D04A23F4',
#    'realm': 'Fandango',
#    'displayName': 'Diane C',
#    'accountLink': None},
#   'score': 5,
#   'timeFromCreation': '1d ago'},
#  {'rating': 'STAR_5',
#   'review': 'Loved the animation and  adaptation to modern day conversing. \nDid think it was a bit over-violent',
#   'displayName': 'CAROLYN',
#   'displayImageUrl': None,
#   'isVerified': True,
#   'isSuperReviewer': False,
#   'hasSpoilers': False,
#   'hasProfanity': False,
#   'createDate': '2019-08-26T13:20:55.620Z',
#   'updateDate': '2019-08-26T13:20:55.620Z',
# ...
#   'score': 4.5,
#   'timeFromCreation': 'Aug 14, 2019'},
#  {'rating': 'STAR_4',
#   'review': 'The use of the real looking animals (and computer generated ones) were awesome. My wife and I are in our 40s and went to see it on a afternoon date. I thought it was great and would be for younger kids too...were just (old) kids at heart.',
#   'displayName': 'SAMUEL T',
#   'displayImageUrl': None,
#   'isVerified': True,
#   'isSuperReviewer': False,
#   'hasSpoilers': False,
#   'hasProfanity': False,
#   'createDate': '2019-08-14T11:07:00.956Z',
#   'updateDate': '2019-08-14T11:07:00.956Z',
#   'user': {'userId': '8b462ddd-5bb3-4684-86f9-0280430cc179',
#    'realm': 'Fandango',
#    'displayName': 'SAMUEL T',
#    'accountLink': None},
#   'score': 4,
#   'timeFromCreation': 'Aug 14, 2019'},
#  {'rating': 'STAR_5',
#   'review': 'Beautiful movie to see with my grandkids!',
#   'displayName': 'Michridley',
#   'displayImageUrl': None,
#   'isVerified': True,
#   'isSuperReviewer': False,
#   'hasSpoilers': False,
#   'hasProfanity': False,
#   'createDate': '2019-08-14T10:39:01.859Z',
#   'updateDate': '2019-08-14T10:39:01.859Z',
#   'user': {'userId': 'ffebf120-9791-48c6-b105-02b9ce435581',
#    'realm': 'Fandango',
#    'displayName': 'Michridley',
#    'accountLink': None},
#   'score': 5,
#   'timeFromCreation': 'Aug 14, 2019'},
#  {'rating': 'STAR_3',
#   'review': 'It was okay - took my granddaughter (10) and she liked it somewhat.  Although the story line was the same, and the movie was long, the characters were not developed enough - too choppy.  Recommend waiting for DVD',
#   'displayName': 'Cathy B',
#   'displayImageUrl': None,
#   'isVerified': True,
#   'isSuperReviewer': False,
#   'hasSpoilers': False,
#   'hasProfanity': False,
#   'createDate': '2019-08-14T10:28:55.930Z',
#   'updateDate': '2019-08-14T10:28:55.930Z',
#   'user': {'userId': 'd22dc3c6-f96d-4a6f-87d3-2f436efd1b29',
#    'realm': 'Fandango',
#    'displayName': 'Cathy B',
#    'accountLink': None},
#   'score': 3,
#   'timeFromCreation': 'Aug 14, 2019'},
#  {'rating': 'STAR_5',
#   'review': 'Animation was amazing!  Stuck close to the original, but with so much more. Very, very good!  Warning, though—Might be too much for young, sensitive viewers.',
#   'displayName': 'Penny',
#   'displayImageUrl': None,
#   'isVerified': True,
#   'isSuperReviewer': False,
#   'hasSpoilers': False,
#   'hasProfanity': False,
#   'createDate': '2019-08-14T08:00:00.989Z',
#   'updateDate': '2019-08-14T08:00:00.989Z',
#   'user': {'userId': '1ce0d873-32aa-46ce-a8ad-29d5d44d06d5',
#    'realm': 'Fandango',
#    'displayName': 'Penny',
#    'accountLink': None},
#   'score': 5,
#   'timeFromCreation': 'Aug 14, 2019'},
#  {'rating': 'STAR_5',
#   'review': 'It was amazing it made me cry❤️',
#   'displayName': 'Henry',
#   'displayImageUrl': None,
#   'isVerified': True,
#   'isSuperReviewer': False,
#   'hasSpoilers': False,
#   'hasProfanity': False,
#   'createDate': '2019-08-14T07:31:28.412Z',
#   'updateDate': '2019-08-14T07:31:28.412Z',
#   'user': {'userId': '31145206-15F4-4E0B-9640-09C5F0CA034C',
#    'realm': 'Fandango',
#    'displayName': 'Henry',
#    'accountLink': None},
#   'score': 5,
#   'timeFromCreation': 'Aug 14, 2019'},
#  {'rating': 'STAR_5',
#   'review': 'Everything about it was purrfect :)',
#   'displayName': 'Kamilla M',
#   'displayImageUrl': None,
#   'isVerified': False,
#   'isSuperReviewer': False,
#   'hasSpoilers': False,
#   'hasProfanity': False,
#   'createDate': '2019-08-14T07:10:42.435Z',
#   'updateDate': '2019-08-14T07:10:42.435Z',
#   'user': {'userId': '978198392',
#    'realm': 'RT',
#    'displayName': 'Kamilla M',
#    'accountLink': '/user/id/978198392'},
#   'score': 5,
#   'timeFromCreation': 'Aug 14, 2019'},
#  {'rating': 'STAR_4_5',
#   'review': 'Liked it better the second time I saw it for some reason. I’m so amazed by the amazing animal movements and expressions. Kudos!!! Wish it had more songs.',
#   'displayName': 'Alicia',
#   'displayImageUrl': None,
#   'isVerified': True,
#   'isSuperReviewer': False,
#   'hasSpoilers': False,
#   'hasProfanity': False,
#   'createDate': '2019-08-14T06:56:34.186Z',
#   'updateDate': '2019-08-14T06:56:34.186Z',
#   'user': {'userId': '24560D1A-115F-4901-BAE1-BEA805E40A18',
#    'realm': 'Fandango',
#    'displayName': 'Alicia',
#    'accountLink': None},
#   'score': 4.5,
#   'timeFromCreation': 'Aug 14, 2019'},
#  {'rating': 'STAR_5',
#   'review': 'Awesome Movie Love It',
#   'displayName': 'Giovanni H',
#   'displayImageUrl': None,
#   'isVerified': True,
#   'isSuperReviewer': False,
#   'hasSpoilers': False,
#   'hasProfanity': False,
#   'createDate': '2019-08-14T06:18:42.039Z',
#   'updateDate': '2019-08-14T06:18:42.039Z',
#   'user': {'userId': '12FA7D64-96FF-440D-BECB-B68128710A16',
#    'realm': 'Fandango',
#    'displayName': 'Giovanni H',
#    'accountLink': None},
#   'score': 5,
#   'timeFromCreation': 'Aug 14, 2019'},
#  {'rating': 'STAR_5',
#   'review': 'Could hardly believe this was animation the animals looked so real and the scenery was fantastic. Also enjoyed the music',
#   'displayName': 'Joy V',
#   'displayImageUrl': None,
#   'isVerified': True,
#   'isSuperReviewer': False,
#   'hasSpoilers': False,
#   'hasProfanity': False,
#   'createDate': '2019-08-14T05:56:15.111Z',
#   'updateDate': '2019-08-14T05:56:15.111Z',
#   'user': {'userId': '4dec4c47-e8c2-4547-b471-ddcc626704f7',
#    'realm': 'Fandango',
#    'displayName': 'Joy V',
#    'accountLink': None},
#   'score': 5,
#   'timeFromCreation': 'Aug 14, 2019'},
#  {'rating': 'STAR_4',
#   'review': "Great but the original voice cast can't be beat.",
#   'displayName': 'Jesse',
#   'displayImageUrl': None,
#   'isVerified': True,
#   'isSuperReviewer': False,
#   'hasSpoilers': False,
#   'hasProfanity': False,
#   'createDate': '2019-08-14T05:21:14.273Z',
#   'updateDate': '2019-08-14T05:21:14.273Z',
#   'user': {'userId': '146D473E-00BC-4541-9775-CD248226577D',
#    'realm': 'Fandango',
#    'displayName': 'Jesse',
#    'accountLink': None},
#   'score': 4,
#   'timeFromCreation': 'Aug 14, 2019'},
#  {'rating': 'STAR_1',
#   'review': 'Slow and a pointless remake',
#   'displayName': 'Chad',
#   'displayImageUrl': None,
#   'isVerified': True,
#   'isSuperReviewer': False,
#   'hasSpoilers': False,
#   'hasProfanity': False,
#   'createDate': '2019-08-14T04:28:18.506Z',
#   'updateDate': '2019-08-14T04:28:18.506Z',
#   'user': {'userId': '40bc01dd-32c8-4c2a-adf2-d2bd5c1a6b65',
#    'realm': 'Fandango',
#    'displayName': 'Chad',
#    'accountLink': None},
#   'score': 1,
#   'timeFromCreation': 'Aug 14, 2019'},
#  {'rating': 'STAR_4',
#   'review': 'I loved the graphics but the acting could have been a little better.',
#   'displayName': 'MT',
#   'displayImageUrl': None,
#   'isVerified': True,
#   'isSuperReviewer': False,
#   'hasSpoilers': False,
#   'hasProfanity': False,
#   'createDate': '2019-08-14T04:24:23.164Z',
#   'updateDate': '2019-08-14T04:24:23.164Z',
#   'user': {'userId': 'e0f11e9a-c79b-4211-9e07-77811565ee8f',
#    'realm': 'Fandango',
#    'displayName': 'MT',
#    'accountLink': None},
#   'score': 4,
#   'timeFromCreation': 'Aug 14, 2019'},
#  {'rating': 'STAR_5',
#   'review': 'my son really enjoyed the movie. it was really sweet the movie was great!',
#   'displayName': 'anna',
#   'displayImageUrl': None,
#   'isVerified': True,
#   'isSuperReviewer': False,
#   'hasSpoilers': False,
#   'hasProfanity': False,
#   'createDate': '2019-08-14T04:24:15.332Z',
#   'updateDate': '2019-08-14T04:24:15.332Z',
#   'user': {'userId': '8DC8E6C3-85DA-459B-AD6C-E6F4086F83E2',
#    'realm': 'Fandango',
#    'displayName': 'anna',
#    'accountLink': None},
#   'score': 5,
#   'timeFromCreation': 'Aug 14, 2019'},
#  {'rating': 'STAR_5',
#   'review': 'People walking in to movie late.  Issues with seats in front row after movie started.  Movie employee stood down front with light trying to figure out if people had wrong seats.  They just have had wrong seats.  Took forever for movie employee to determine.  All the while we are trying to see movie.',
#   'displayName': 'Debra',
#   'displayImageUrl': None,
#   'isVerified': True,
#   'isSuperReviewer': False,
#   'hasSpoilers': False,
#   'hasProfanity': False,
#   'createDate': '2019-08-14T04:17:48.285Z',
#   'updateDate': '2019-08-14T04:17:48.285Z',
#   'user': {'userId': '68b205ae-c433-47e2-afad-984d6c162a34',
#    'realm': 'Fandango',
#    'displayName': 'Debra',
#    'accountLink': None},
#   'score': 5,
#   'timeFromCreation': 'Aug 14, 2019'},
#  {'rating': 'STAR_5',
#   'review': 'nothing to report. great movie',
#   'displayName': 'Deanna',
#   'displayImageUrl': None,
#   'isVerified': True,
#   'isSuperReviewer': False,
#   'hasSpoilers': False,
#   'hasProfanity': False,
#   'createDate': '2019-08-14T04:16:15.152Z',
#   'updateDate': '2019-08-14T04:16:15.152Z',
#   'user': {'userId': 'D7FA1562-ABAE-4211-BAE8-ACE6EA5EE454',
#    'realm': 'Fandango',
#    'displayName': 'Deanna',
#    'accountLink': None},
#   'score': 5,
#   'timeFromCreation': 'Aug 14, 2019'},
#  {'rating': 'STAR_5',
#   'review': "It was amazing! How'd they do that!!",
#   'displayName': 'Sandy Lindquist',
#   'displayImageUrl': None,
#   'isVerified': False,
#   'isSuperReviewer': False,
#   'hasSpoilers': False,
#   'hasProfanity': False,
#   'createDate': '2019-08-14T04:15:30.140Z',
#   'updateDate': '2019-08-14T04:15:30.140Z',
#   'user': {'userId': 'e6e307f3-3f5f-48c3-afef-18aff05ba6a2',
#    'realm': 'Fandango',
#    'displayName': 'Sandy Lindquist',
#    'accountLink': None},
#   'score': 5,
#   'timeFromCreation': 'Aug 14, 2019'},
#  {'rating': 'STAR_5',
#   'review': 'Very nice! Very beautiful magical',
#   'displayName': 'Victor E',
#   'displayImageUrl': None,
#   'isVerified': True,
#   'isSuperReviewer': False,
#   'hasSpoilers': False,
#   'hasProfanity': False,
#   'createDate': '2019-08-14T03:37:20.600Z',
#   'updateDate': '2019-08-14T03:37:20.600Z',
#   'user': {'userId': '27D49262-D4D5-4F26-8CDA-40EB2198C9B6',
#    'realm': 'Fandango',
#    'displayName': 'Victor E',
#    'accountLink': None},
#   'score': 5,
#   'timeFromCreation': 'Aug 14, 2019'},
#  {'rating': 'STAR_3_5',
#   'review': 'Kept the legacy of this story going for a new generation ',
#   'displayName': 'Gary W',
#   'displayImageUrl': None,
#   'isVerified': False,
#   'isSuperReviewer': False,
#   'hasSpoilers': False,
#   'hasProfanity': False,
#   'createDate': '2019-08-14T03:36:43.086Z',
#   'updateDate': '2019-08-14T03:36:43.086Z',
#   'user': {'userId': '978102457',
#    'realm': 'RT',
#    'displayName': 'Gary W',
#    'accountLink': '/user/id/978102457'},
#   'score': 3.5,
#   'timeFromCreation': 'Aug 14, 2019'},
#  {'rating': 'STAR_5',
#   'review': 'The cinematography was great',
#   'displayName': 'Millie',
#   'displayImageUrl': None,
#   'isVerified': False,
#   'isSuperReviewer': False,
#   'hasSpoilers': False,
#   'hasProfanity': False,
#   'createDate': '2019-08-14T03:24:45.167Z',
#   'updateDate': '2019-08-14T03:24:45.167Z',
#   'user': {'userId': '827ee17c-e072-4687-98b8-b9c4f0b90060',
#    'realm': 'Fandango',
#    'displayName': 'Millie',
#    'accountLink': None},
#   'score': 5,
#   'timeFromCreation': 'Aug 14, 2019'},
#  {'rating': 'STAR_1_5',
#   'review': "This Lion King is a 'not-as-good' follow up. \nThank goodness for Beyonce who offers the only fresh thing worth seeing in this adaptation. \nWhile watching you want to leave the theatre and go watch the cartoon because they just didn't quite get the moments right, and it's super disappointing. \nSimilar to Robin Williams as the Genie, Rowan Atkinson brought so much life to Zazu that John Oliver just can't live up to.\nYa it was bad. Best go watch the 1994 cartoon version.",
#   'displayName': 'Graham S',
#   'displayImageUrl': 'https://graph.facebook.com/v3.3/501902118/picture',
#   'isVerified': False,
#   'isSuperReviewer': False,
#   'hasSpoilers': False,
#   'hasProfanity': False,
#   'createDate': '2019-08-14T03:22:51.500Z',
#   'updateDate': '2019-08-14T03:22:51.500Z',
#   'user': {'userId': '798702619',
#    'realm': 'RT',
#    'displayName': 'Graham S',
#    'accountLink': '/user/id/798702619'},
#   'score': 1.5,
#   'timeFromCreation': 'Aug 14, 2019'},
#  {'rating': 'STAR_4',
#   'review': 'Not much different than the 94 movie. Animals were realistic, good choice of voice actors, and dramatic scenes.',
#   'displayName': 'Chris S',
#   'displayImageUrl': None,
#   'isVerified': True,
#   'isSuperReviewer': False,
#   'hasSpoilers': False,
#   'hasProfanity': False,
#   'createDate': '2019-08-14T03:19:38.202Z',
#   'updateDate': '2019-08-14T03:19:38.202Z',
#   'user': {'userId': '4fddc77d-bf3c-4c0f-9c0d-aaa75f506d87',
#    'realm': 'Fandango',
#    'displayName': 'Chris S',
#    'accountLink': None},
#   'score': 4,
#   'timeFromCreation': 'Aug 14, 2019'},
#  {'rating': 'STAR_5',
#   'review': 'Loved it! Will definitely be buying it when it comes out on BluRay',
#   'displayName': 'Jessica',
#   'displayImageUrl': None,
#   'isVerified': True,
#   'isSuperReviewer': False,
#   'hasSpoilers': False,
#   'hasProfanity': False,
#   'createDate': '2019-08-14T03:08:48.572Z',
#   'updateDate': '2019-08-14T03:08:51.445Z',
#   'user': {'userId': '0ba1c6c5-0c30-49d8-886d-4c64bbcf5500',
#    'realm': 'Fandango',
#    'displayName': 'Jessica',
#    'accountLink': None},
#   'score': 5,
#   'timeFromCreation': 'Aug 14, 2019'},
#  {'rating': 'STAR_3_5',
#   'review': 'Disappointed in the singing',
#   'displayName': 'Google',
#   'displayImageUrl': None,
#   'isVerified': False,
#   'isSuperReviewer': False,
#   'hasSpoilers': False,
#   'hasProfanity': False,
#   'createDate': '2019-08-14T03:08:47.084Z',
#   'updateDate': '2019-08-14T03:08:47.084Z',
#   'user': {'userId': 'c5c4cef1-571b-46dd-b3f6-1b93495a6b97',
#    'realm': 'Fandango',
#    'displayName': 'Google',
#    'accountLink': None},
#   'score': 3.5,
#   'timeFromCreation': 'Aug 14, 2019'},
#  {'rating': 'STAR_5',
#   'review': 'As always, Disney produces an amazing show!!',
#   'displayName': 'love it',
#   'displayImageUrl': None,
#   'isVerified': True,
#   'isSuperReviewer': False,
#   'hasSpoilers': False,
#   'hasProfanity': False,
#   'createDate': '2019-08-14T02:40:52.336Z',
#   'updateDate': '2019-08-14T02:40:52.336Z',
#   'user': {'userId': '0CD36B14-3458-4B65-86C8-A02277631724',
#    'realm': 'Fandango',
#    'displayName': 'love it',
#    'accountLink': None},
#   'score': 5,
#   'timeFromCreation': 'Aug 14, 2019'},
#  {'rating': 'STAR_0_5',
#   'review': "As I would never in a million years actually pay disney money to watch their regurgitated garbage, I got a ticket from a friend and watched in horror as my favorite childhood film was turned into diarrhea garbage in front of my eyes. There was absolutely NOTHING good about this, from the music to the horrible, soulless visuals. There is no inspiration. No creativity. No improvement. Just the vapid urge to make as much easy money as possible. I hope they're ashamed of themselves for continuing to do this crap.",
#   'displayName': 'Victoria J',
#   'displayImageUrl': 'https://graph.facebook.com/v3.3/1736072991/picture',
#   'isVerified': False,
#   'isSuperReviewer': False,
#   'hasSpoilers': False,
#   'hasProfanity': True,
#   'createDate': '2019-08-14T02:33:35.095Z',
#   'updateDate': '2019-08-14T02:33:35.095Z',
#   'user': {'userId': '876487642',
#    'realm': 'RT',
#    'displayName': 'Victoria J',
#    'accountLink': '/user/id/876487642'},
#   'score': 0.5,
#   'timeFromCreation': 'Aug 14, 2019'},
#  {'rating': 'STAR_3',
#   'review': 'A pointless remake of a classic film that leaves viewers with nothing but a need to watch the original. Nostalgia is a wonderful drug and Hollywood is the dealer. ',
#   'displayName': 'David H',
#   'displayImageUrl': None,
#   'isVerified': False,
#   'isSuperReviewer': False,
#   'hasSpoilers': False,
#   'hasProfanity': False,
#   'createDate': '2019-08-14T02:29:56.584Z',
#   'updateDate': '2019-08-14T02:29:56.584Z',
#   'user': {'userId': '934080184',
#    'realm': 'RT',
#    'displayName': 'David H',
#    'accountLink': '/user/id/934080184'},
#   'score': 3,
#   'timeFromCreation': 'Aug 14, 2019'},
#  {'rating': 'STAR_5',
#   'review': 'it was amazing i liked it more then the kids and im 37',
#   'displayName': 'Tina',
#   'displayImageUrl': None,
#   'isVerified': True,
#   'isSuperReviewer': False,
#   'hasSpoilers': False,
#   'hasProfanity': False,
#   'createDate': '2019-08-14T02:24:07.827Z',
#   'updateDate': '2019-08-14T02:25:59.069Z',
#   'user': {'userId': '10E17509-A4D1-4E63-8844-8E5E16107CBD',
#    'realm': 'Fandango',
#    'displayName': 'Tina',
#    'accountLink': None},
#   'score': 5,
#   'timeFromCreation': 'Aug 14, 2019'},
#  ...]

# %%
from pandas.io.json import json_normalize
data =theLionKing_reviews

lionking_dt = pd.DataFrame.from_dict(json_normalize(data), orient='columns')

lionking_dt
# Out:
#         rating                                             review displayName  \
# 0     STAR_2_5  almost shot for shot. scar is a very weak char...        None
# 1       STAR_5  Loved the movie! Great CGI, acting, music, fel...       Logan
# 2       STAR_3  If you grew up with (and love) the original an...    Rachel C
# 3     STAR_2_5  While it can take pride in its visual achievem...     Peter J
# 4       STAR_5  It was seriously a stunning movie. Great graph...       Devon
# ...        ...                                                ...         ...
# 3995    STAR_3        The scenes where so different from original        Lori
# 3996    STAR_5                       Great sound, looked so real.       Diane
# 3997    STAR_3  We thought it was good but I would not rate it...      Google
# 3998    STAR_5               Grat family movie and great graphics  Catrina  L
# 3999    STAR_3            It's okay to watch once but watch in 3D     sandeep
#
#                                         displayImageUrl  isVerified  \
# 0                                                  None       False
# 1                                                  None        True
# 2     https://graph.facebook.com/v3.3/10221590382855...       False
# 3                                                  None       False
# 4                                                  None        True
# ...                                                 ...         ...
# 3995                                               None        True
# 3996                                               None        True
# 3997                                               None       False
# 3998                                               None        True
# 3999                                               None        True
#
#       isSuperReviewer  hasSpoilers  hasProfanity                createDate  \
# 0               False        False         False  2019-08-27T21:39:31.395Z
# 1               False        False         False  2019-08-27T21:13:12.178Z
# 2               False        False         False  2019-08-27T20:58:51.447Z
# 3               False        False         False  2019-08-27T20:27:50.707Z
# 4               False        False         False  2019-08-27T20:15:05.755Z
# ...               ...          ...           ...                       ...
# 3995            False        False         False  2019-07-31T14:06:35.578Z
# 3996            False        False         False  2019-07-31T14:02:12.091Z
# 3997            False        False         False  2019-07-31T14:01:47.340Z
# 3998            False        False         False  2019-07-31T13:57:38.010Z
# 3999            False        False         False  2019-07-31T13:54:54.398Z
#
#                     updateDate  score timeFromCreation  \
# 0     2019-08-27T21:39:31.395Z    2.5          24m ago
# 1     2019-08-27T21:13:12.178Z    5.0          50m ago
# 2     2019-08-27T20:58:51.447Z    3.0           1h ago
# 3     2019-08-27T20:27:54.169Z    2.5           2h ago
# 4     2019-08-27T20:15:05.755Z    5.0           2h ago
# ...                        ...    ...              ...
# 3995  2019-07-31T14:06:35.578Z    3.0     Jul 31, 2019
# 3996  2019-07-31T14:02:12.091Z    5.0     Jul 31, 2019
# 3997  2019-07-31T14:01:47.340Z    3.0     Jul 31, 2019
# 3998  2019-07-31T13:57:38.010Z    5.0     Jul 31, 2019
# 3999  2019-07-31T13:54:54.830Z    3.0     Jul 31, 2019
#
#                                user.userId user.realm user.displayName  \
# 0                                260316344         RT             None
# 1     02750CCE-D2AB-4E3B-A998-6576C1A240E0   Fandango            Logan
# 2                                978214951         RT         Rachel C
# 3                                977694797         RT          Peter J
# 4     AC172773-33D5-466B-8E82-C5178AB51CAF   Fandango            Devon
# ...                                    ...        ...              ...
# 3995  e5bb9290-69ce-48bf-8eed-27946372974f   Fandango             Lori
# 3996  897c4479-47d8-4207-8365-4e03d9717e86   Fandango            Diane
# 3997  39854b35-4b68-44fc-b273-ab4ca7b8574c   Fandango           Google
# 3998  ce1db709-a600-4e5d-bd5a-a2ea22118a09   Fandango       Catrina  L
# 3999  f0b03319-bb12-498b-83ee-221e41065e17   Fandango          sandeep
#
#         user.accountLink
# 0     /user/id/260316344
# 1                   None
# 2     /user/id/978214951
# 3     /user/id/977694797
# 4                   None
# ...                  ...
# 3995                None
# 3996                None
# 3997                None
# 3998                None
# 3999                None
#
# [4000 rows x 16 columns]

# %%
lionking_dt.to_csv("4000reviews.csv",header=True,index=False)

# %%
lionking_dt=pd.read_csv("4000reviews.csv")

# %%
#extracting our target feature from rating
lionking_dt['sentiment'] = np.where(lionking_dt['score']>3, 0, 1)

# %%
lionking_dt.isna().sum()
# Out:
# review                0
# sentiment             0
# review_processed_1    0
# dtype: int64

# %%
lionking_dt.sentiment.value_counts()
# Out:
# 0    2923
# 1    1077
# Name: sentiment, dtype: int64

# %%
#collecting and increasing the no of negative records in the 3000 reviews by-
#sampling postive and negative records seperatly from 4000 records
positive_dt = lionking_dt[lionking_dt.sentiment == 0].sample(n=1923)
negative_dt = lionking_dt[lionking_dt.sentiment == 1].sample(n=1077)

# %%
lionking_dt= pd.concat([positive_dt,negative_dt],axis=0,ignore_index=True)

# %%
lionking_dt.sentiment.value_counts(normalize=True)
# Out:
# 0    0.641
# 1    0.359
# Name: sentiment, dtype: float64

# %%
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize

# %%
final_test_dt = pd.read_csv("test.csv")

# %%
type(final_test_dt)
# Out:
# pandas.core.frame.DataFrame

# %%
#type of data
type(lionking_dt["review"])
# Out:
# pandas.core.series.Series

# %%
#seeing the first two reviews
lionking_dt["review"][:2]
# Out:
# 0    It was just as good as the original. The anima...
# 1    They stayed true to the cartoon except for the...
# Name: review, dtype: object

# %%
CONTRACTION_MAP = {"ain't": "is not","aren't": "are not","can't": "cannot","can't've": "cannot have","'cause": "because","could've": "could have","couldn't": "could not","couldn't've": "could not have","didn't": "did not","doesn't": "does not","don't": "do not","hadn't": "had not","hadn't've": "had not have","hasn't": "has not","haven't": "have not","he'd": "he would","he'd've": "he would have","he'll": "he will","he'll've": "he he will have","he's": "he is","how'd": "how did","how'd'y": "how do you","how'll": "how will","how's": "how is","I'd": "I would","I'd've": "I would have","I'll": "I will","I'll've": "I will have","I'm": "I am","I've": "I have","i'd": "i would","i'd've": "i would have","i'll": "i will","i'll've": "i will have","i'm": "i am","i've": "i have","isn't": "is not","it'd": "it would","it'd've": "it would have","it'll": "it will","it'll've": "it will have","it's": "it is","let's": "let us","ma'am": "madam","mayn't": "may not","might've": "might have","mightn't": "might not","mightn't've": "might not have","must've": "must have","mustn't": "must not","mustn't've": "must not have","needn't": "need not","needn't've": "need not have","o'clock": "of the clock","oughtn't": "ought not","oughtn't've": "ought not have","shan't": "shall not","sha'n't": "shall not","shan't've": "shall not have","she'd": "she would","she'd've": "she would have","she'll": "she will","she'll've": "she will have","she's": "she is","should've": "should have","shouldn't": "should not","shouldn't've": "should not have","so've": "so have","so's": "so as","that'd": "that would","that'd've": "that would have","that's": "that is","there'd": "there would","there'd've": "there would have","there's": "there is","they'd": "they would","they'd've": "they would have","they'll": "they will","they'll've": "they will have","they're": "they are","they've": "they have","to've": "to have","wasn't": "was not","we'd": "we would","we'd've": "we would have","we'll": "we will","we'll've": "we will have","we're": "we are","we've": "we have","weren't": "were not","what'll": "what will","what'll've": "what will have","what're": "what are","what's": "what is","what've": "what have","when's": "when is","when've": "when have","where'd": "where did","where's": "where is","where've": "where have","who'll": "who will","who'll've": "who will have","who's": "who is","who've": "who have","why's": "why is","why've": "why have","will've": "will have","won't": "will not","won't've": "will not have","would've": "would have","wouldn't": "would not","wouldn't've": "would not have","y'all": "you all","y'all'd": "you all would","y'all'd've": "you all would have","y'all're": "you all are","y'all've": "you all have","you'd": "you would","you'd've": "you would have","you'll": "you will","you'll've": "you will have","you're": "you are","you've": "you have"}

# %%
### Contractions
import re


def expand_contractions(text, contraction_mapping=CONTRACTION_MAP):
   
    contractions_pattern = re.compile('({})'.format('|'.join(contraction_mapping.keys())),
                                      flags=re.IGNORECASE | re.DOTALL)

    def expand_match(contraction):
        match = contraction.group(0)
        first_char = match[0]
        expanded_contraction = contraction_mapping.get(match)\
            if contraction_mapping.get(match)\
            else contraction_mapping.get(match.lower())
        expanded_contraction = first_char+expanded_contraction[1:]
        return expanded_contraction

    expanded_text = contractions_pattern.sub(expand_match, text)
    expanded_text = re.sub("'", "", expanded_text)

    return expanded_text

# %%
## for extracting polarity, review length, word count features from the data after pre processing
from textblob import TextBlob

def preprocess(Text):
    Text = Text.str.replace("(<br/>)", "")
    Text = Text.str.replace('(<a).*(>).*(</a>)', '')
    Text = Text.str.replace('(&amp)', '')
    Text = Text.str.replace('(&gt)', '')
    Text = Text.str.replace('(&lt)', '')
    Text = Text.str.replace('(\xa0)', ' ')  
    return Text
lionking_dt['review_processed_1'] = preprocess(lionking_dt['review'])

lionking_dt['polarity'] = lionking_dt['review_processed_1'].map(lambda text: TextBlob(text).sentiment.polarity)
lionking_dt['review_len'] = lionking_dt['review_processed_1'].astype(str).apply(len)
lionking_dt['word_count'] = lionking_dt['review_processed_1'].apply(lambda x: len(str(x).split()))

# %%
# pre processing of the review data an d assigning it to new feature column review_processed_2
lionking_dt["review_processed_1"] = [expand_contractions(re.sub('’',"'",i)) for i in lionking_dt['review']]
# pre processing of the review data an d assigning it to new feature column review_processed_2
final_test_dt["review_processed_1"] = [expand_contractions(re.sub('’',"'",i)) for i in final_test_dt.Review]

# %%
lionking_dt.review_processed_1[2323]
# Out:
# 'The voice acting was not great, the songs were awkward and forced, and this movie left me feeling disappointed. '

# %%
#removing special characters from the review data and assigning it to a new column feature review_processed_1
lionking_dt['review_processed_1']=[re.sub(r"[^a-zA-Z#\s]",' ',i)for i in lionking_dt["review_processed_1"]]
final_test_dt['review_processed_1']=[re.sub(r"[^a-zA-Z#\s]",' ',i)for i in final_test_dt["review_processed_1"]]

# %%
lionking_dt.review_processed_1[2323]
# Out:
# 'Without having seen the original  I would probably think even less of this movie  I got through bad parts scenes that did not make much sense by remembering the old version  However  it looks incredible  and the  D is fantastic '

# %%
lionking_dt['review_processed_1'][1121]
# Out:
# 'Much better than I expected   the start of the movie was amazing '

# %%
#converting all the upper case letters to lower case after stripping
lionking_dt['review_processed_1']=[each_review.strip().lower() for each_review in lionking_dt['review_processed_1']]
final_test_dt['review_processed_1']=[each_review.strip().lower() for each_review in final_test_dt['review_processed_1']]

# %%
lionking_dt.review_processed_1[2323]
# Out:
# 'without having seen the original  i would probably think even less of this movie  i got through bad parts scenes that did not make much sense by remembering the old version  however  it looks incredible  and the  d is fantastic'

# %%
#removing stopwords in the review text
stop = stopwords.words('english')
lionking_dt['review_processed_1']=lionking_dt['review_processed_1'].apply(lambda x: ' '.join([i for i in x.split() if (len(i)>3)&(i.lower() not in stop)]))
final_test_dt['review_processed_1']=final_test_dt['review_processed_1'].apply(lambda x: ' '.join([i for i in x.split() if (len(i)>3)&(i.lower() not in stop)]))

# %%
lionking_dt.review_processed_1[2323]
# Out:
# 'without seen original would probably think even less movie parts scenes make much sense remembering version however looks incredible fantastic'

# %%
lionking_dt['review_processed_1'][1121]
# Out:
# 'much better expected start movie amazing'

# %%
#splitting the words into root form
lionking_dt['review_processed_1']= lionking_dt['review_processed_1'].apply(lambda x: x.split())
final_test_dt['review_processed_1']= final_test_dt['review_processed_1'].apply(lambda x: x.split())

# %%
lionking_dt['review_processed_1'][2323]
# Out:
# ['without',
#  'seen',
#  'original',
#  'would',
#  'probably',
#  'think',
#  'even',
#  'less',
#  'movie',
#  'parts',
#  'scenes',
#  'make',
#  'much',
#  'sense',
#  'remembering',
#  'version',
#  'however',
#  'looks',
#  'incredible',
#  'fantastic']

# %%
#converting words into rootform by lemmatizing
import nltk
lmtzr = nltk.stem.WordNetLemmatizer()
lionking_dt['review_processed_1']=lionking_dt['review_processed_1'].apply(lambda x: [lmtzr.lemmatize(i) for i in x])
final_test_dt['review_processed_1']=final_test_dt['review_processed_1'].apply(lambda x: [lmtzr.lemmatize(i) for i in x])

# %%
lionking_dt['review_processed_1'][2323]
# Out:
# ['without',
#  'seen',
#  'original',
#  'would',
#  'probably',
#  'think',
#  'even',
#  'le',
#  'movie',
#  'part',
#  'scene',
#  'make',
#  'much',
#  'sense',
#  'remembering',
#  'version',
#  'however',
#  'look',
#  'incredible',
#  'fantastic']

# %%
lionking_dt['review_processed_1'] = lionking_dt['review_processed_1'].apply(lambda x:' '.join(x))
final_test_dt['review_processed_1'] = final_test_dt['review_processed_1'].apply(lambda x:' '.join(x))

# %%
lionking_dt.to_pickle("4000reviews_preprocessed.csv")
final_test_dt.to_pickle("final_preprocessed.csv")

# %%
from sklearn.model_selection import train_test_split

X = lionking_dt.review
y = lionking_dt.sentiment

X_train_r, X_test_r, y_train_r, y_test_r = train_test_split(X,y,test_size=0.2,random_state=123)

# %%
X = lionking_dt.review_processed_1
y = lionking_dt.sentiment

X_train_r1, X_test_r1, y_train_r1, y_test_r1 = train_test_split(X,y,test_size=0.2,random_state=123)

# %%
## Import Libraries 
import numpy as np      # for array operations
import pandas as pd     # for reading data operations

from keras.preprocessing.text import Tokenizer          # for tokenizing text
from keras.preprocessing.sequence import pad_sequences  # for padding sentences with zeros. To make the sentence length same
from keras.utils import to_categorical                  # for one-hot encoding of the labels
from keras.layers import Dense, Input, Flatten, Dropout, BatchNormalization
from keras.layers import SimpleRNN, LSTM, GRU, Input, Concatenate
from keras.layers import Conv1D, MaxPooling1D, GlobalMaxPool1D, Embedding, GlobalAvgPool1D
from keras.models import Sequential, Model
import os
os.environ["CUDA_VISIBLE_DEVICES"]="1"

import pandas as pd
import numpy as np
from nltk.corpus import stopwords
from nltk.classify.scikitlearn import SklearnClassifier
from nltk.tokenize import sent_tokenize,word_tokenize
from nltk.collocations import BigramCollocationFinder 
from wordcloud import WordCloud

import spacy
nlp = spacy.load('en_core_web_sm')

from sklearn.model_selection import train_test_split
from sklearn.metrics import f1_score

import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

pd.set_option('display.max_colwidth',-1)

import urllib.request as url
from bs4 import BeautifulSoup as bs
import re
import requests
import warnings
warnings.filterwarnings("ignore")
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

import random
random.seed(123)

from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize

import os
import random
import string
import datetime as dt

# import warnings
# warnings.filterwarnings('ignore','RuntimeWarning')

import nltk
import re
from nltk.corpus import stopwords
from nltk.classify.scikitlearn import SklearnClassifier
from nltk.tokenize import sent_tokenize, word_tokenize
from nltk.collocations import BigramCollocationFinder, TrigramCollocationFinder
from wordcloud import WordCloud

import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from sklearn.metrics import f1_score
from sklearn.model_selection import GridSearchCV
from sklearn.svm import SVC
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.feature_extraction.text import TfidfVectorizer
from nltk.corpus import movie_reviews
from nltk.classify.scikitlearn import SklearnClassifier
from nltk.tokenize import word_tokenize
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.metrics import confusion_matrix,accuracy_score,recall_score,precision_score
from sklearn.linear_model import LogisticRegression
import warnings
warnings.filterwarnings("ignore")
from sklearn.model_selection import train_test_split
import nltk

from sklearn.metrics import f1_score
# Out:
# Using TensorFlow backend.

# %%
lionking_dt.columns
# Out:
# Index(['rating', 'review', 'displayName', 'displayImageUrl', 'isVerified',
#        'isSuperReviewer', 'hasSpoilers', 'hasProfanity', 'createDate',
#        'updateDate', 'score', 'timeFromCreation', 'user.userId', 'user.realm',
#        'user.displayName', 'user.accountLink', 'sentiment',
#        'review_processed_1', 'polarity', 'review_len', 'word_count'],
#       dtype='object')

# %%
lionking_dt = lionking_dt.drop(labels=['rating', 'displayName', 'displayImageUrl', 'isVerified',
       'isSuperReviewer', 'hasSpoilers', 'hasProfanity', 'createDate',
       'updateDate', 'score', 'timeFromCreation', 'user.userId', 'user.realm',
       'user.displayName', 'user.accountLink', 'polarity', 'review_len', 'word_count'], axis=1)

# %%
lionking_dt.sample()
# Out:
#                                     review  sentiment  \
# 210  Just like the childhood movie I love.  0
#
#             review_processed_1
# 210  like childhood movie love

# %% [markdown]
# # For  Raw Review (cv & Tfidf)

# %%
from sklearn.feature_extraction.text import CountVectorizer
cv = CountVectorizer(stop_words="english",strip_accents="unicode",decode_error="ignore")
tdm_train_r = cv.fit_transform(X_train_r)
tdm_test_r = cv.transform(X_test_r)
tdm_final_test_dt=cv.transform(final_test_dt.Review)
##########################################################################################
from sklearn.feature_extraction.text import TfidfVectorizer
tfidf_vectorizer = TfidfVectorizer(ngram_range=(1,2))
tfidf_train_r = tfidf_vectorizer.fit_transform(X_train_r)
tfidf_test_r = tfidf_vectorizer.transform(X_test_r)
tfidf_final_test_dt = tfidf_vectorizer.transform(final_test_dt.Review)

# %%
# from sklearn.feature_extraction.text import CountVectorizer
# cv = CountVectorizer(stop_words="english",strip_accents="unicode",decode_error="ignore")
# tdm_train_r1 = cv.fit_transform(X_train_r1)
# tdm_test_r1 = cv.transform(X_test_r1)

# ##########################################################################################
# from sklearn.feature_extraction.text import TfidfVectorizer
# tfidf_vectorizer = TfidfVectorizer(ngram_range=(1,2))
# tfidf_train_r1 = tfidf_vectorizer.fit_transform(X_train_r1)
# tfidf_test_r1 = tfidf_vectorizer.transform(X_test_r1)

# %% [markdown]
# ## Logistic regression
#     1.count vectorizer

# %%
from sklearn.linear_model import LogisticRegression
import warnings
warnings.filterwarnings("ignore")

#training the model
logreg = LogisticRegression()
lr_clf = logreg.fit(tdm_train_r,y_train_r) #or mat which is in dense format can also be used

#prediction on train data
train_pred_log_tdm_r = lr_clf.predict(tdm_train_r)

#predicting on test data
test_pred_log_tdm_r = lr_clf.predict(tdm_test_r)

# %%
f1_train_r_log=f1_score( y_train_r, train_pred_log_tdm_r, labels=None, pos_label=1, average='binary')
f1_test_r_log=f1_score( y_test_r, test_pred_log_tdm_r, labels=None, pos_label=1, average='binary')
print(f1_train_r_log)
print(f1_test_r_log)
# Out:
# 0.9235400361228175
# 0.7425742574257426

# %% [markdown]
# ## logistic regression tfidf vectorizer

# %%
from sklearn.linear_model import LogisticRegression
import warnings
warnings.filterwarnings("ignore")

#training the model
logreg = LogisticRegression()
lr_clf = logreg.fit(tfidf_train_r,y_train_r) #or mat which is in dense format can also be used

#prediction on train data
train_pred_log_tf_r = lr_clf.predict(tfidf_train_r)

#predicting on test data
test_pred_log_tf_r = lr_clf.predict(tfidf_test_r)

# %%
f1_train_r_log=f1_score( y_train_r, train_pred_log_tf_r, labels=None, pos_label=1, average='binary')
f1_test_r_log=f1_score( y_test_r, test_pred_log_tf_r, labels=None, pos_label=1, average='binary')
print(f1_train_r_log)
print(f1_test_r_log)
# Out:
# 0.9241126070991433
# 0.7575757575757576

# %%
# >>> param_grid = {'C': [0.001, 0.01, 0.1, 1, 10, 100, 1000] }
# >>> clf = GridSearchCV(LogisticRegression(penalty='l2'), param_grid)
# GridSearchCV(cv=None,
#              estimator=LogisticRegression(C=1.0, intercept_scaling=1,   
#                dual=False, fit_intercept=True, penalty='l2', tol=0.0001),
#              param_grid={'C': [0.001, 0.01, 0.1, 1, 10, 100, 1000]})

# %% [markdown]
# ## Grid search on logistic regression

# %%
## Use Grid Search for parameter tuning

from sklearn.model_selection import GridSearchCV

 

param_grid = {'C': [0.001, 0.01, 0.1, 1, 10, 100, 1000],}

 
log_grid_r= GridSearchCV(estimator = LogisticRegression(penalty='l2'), param_grid = param_grid, cv =None)

# %%
#training the model
lr_clf = log_grid_r.fit(tdm_train_r,y_train_r) #or mat which is in dense format can also be used

#prediction on train data
train_pred_log_tdm__grid_r = lr_clf.predict(tdm_train_r)

#predicting on test data
test_pred_log_tdm_grid_r = lr_clf.predict(tdm_test_r)

# %%
f1_train_r_log=f1_score( y_train_r, train_pred_log_tdm__grid_r, labels=None, pos_label=1, average='binary')
f1_test_r_log=f1_score( y_test_r, test_pred_log_tdm_grid_r, labels=None, pos_label=1, average='binary')
print(f1_train_r_log)
print(f1_test_r_log)
# Out:
# 0.9235400361228175
# 0.7425742574257426

# %%
lr_clf = log_grid_r.fit(tfidf_train_r,y_train_r) #or mat which is in dense format can also be used

#prediction on train data
train_pred_log_tf_grid_r = lr_clf.predict(tfidf_train_r)

#predicting on test data
test_pred_log_tf_grid_r = lr_clf.predict(tfidf_test_r)

# %%
f1_train_r_log=f1_score( y_train_r, train_pred_log_tf_grid_r, labels=None, pos_label=1, average='binary')
f1_test_r_log=f1_score( y_test_r, test_pred_log_tf_grid_r, labels=None, pos_label=1, average='binary')
print(f1_train_r_log)
print(f1_test_r_log)
# Out:
# 1.0
# 0.781038374717833

# %%
final_predict_m4=log_grid_r.predict(tfidf_final_test_dt)

# %%
final_predict_m4
# Out:
# array([0, 0, 0, ..., 1, 0, 1])

# %%
pd.Series(final_predict_m2).value_counts()
# Out:
# 0    878
# 1    322
# dtype: int64

# %%
final_test_dt.sample
# Out:
# <bound method NDFrame.sample of       ReviewID  \
# 0     92876
# 1     92877
# 2     92878
# 3     92879
# 4     92880
# ...     ...
# 1195  94071
# 1196  94072
# 1197  94073
# 1198  94074
# 1199  94075
#
#                                                                                                                                                                                                                                                                                                                      Review  \
# 0     Was good. Nothing like the original but I believe that was the point.
# 1     I absolutely loved it! A wonderful rendition of the original. Just dont compare to the cartoon version. Let this movie be its own and you will like it
# 2     I love the movie! Good job director! \nI appreciate all the work some great people have put in for years.
# 3     GREAT MOVIE!!  Same as the original, but the cinematography made a huge difference!!
# 4     Realistic.   Fantastic special effects
# ...                                      ...
# 1195  Best Disney movie ever!!!!
# 1196  They butchered almost everything that is loved In the originals....
# 1197  animals should have more facial expressions to what was going on .
# 1198  I love how they didnt really change much from the original movie.
# 1199  As an avid fan of the original, I waited in anticipation for this movie for months. CGI was well done. But everything else was a disappointment. I suppose when something is perfect as is (the original), it shouldn't be toyed with. The voices were just not as endearing and the overall emotin just wasnt there.
#
#                                                                                                                                                         review_processed_1  \
# 0     good nothing like original believe point
# 1     absolutely loved wonderful rendition original dont compare cartoon version movie like
# 2     love movie good director appreciate work great people year
# 3     great movie original cinematography made huge difference
# 4     realistic fantastic special effect
# ...                                  ...
# 1195  best disney movie ever
# 1196  butchered almost everything loved original
# 1197  animal facial expression going
# 1198  love didnt really change much original movie
# 1199  avid original waited anticipation movie month well done everything else disappointment suppose something perfect original toyed voice endearing overall emotin wasnt
#
#       sentiment
# 0     0
# 1     0
# 2     0
# 3     0
# 4     0
# ...  ..
# 1195  0
# 1196  0
# 1197  1
# 1198  0
# 1199  1
#
# [1200 rows x 4 columns]>

# %%
final_test_dt['sentiment']=final_predict_m

f11=final_test_dt.drop(labels=['Review','review_processed_1'], axis=1)

f11.sample(20)

f11.to_csv("model29.csv",header=True,index=False)

# %%
from sklearn.feature_extraction.text import CountVectorizer
cv = CountVectorizer(stop_words="english",strip_accents="unicode",decode_error="ignore")
tdm_train_r1 = cv.fit_transform(X_train_r1)
tdm_test_r1 = cv.transform(X_test_r1)

##########################################################################################
from sklearn.feature_extraction.text import TfidfVectorizer
tfidf_vectorizer = TfidfVectorizer(ngram_range=(1,2))
tfidf_train_r1 = tfidf_vectorizer.fit_transform(X_train_r1)
tfidf_test_r1 = tfidf_vectorizer.transform(X_test_r1)

# %%
from sklearn.linear_model import LogisticRegression
import warnings
warnings.filterwarnings("ignore")

#training the model
logreg = LogisticRegression()
lr_clf = logreg.fit(tdm_train_r1,y_train_r1) #or mat which is in dense format can also be used

#prediction on train data
train_pred_r1 = lr_clf.predict(tdm_train_r1)

#predicting on test data
test_pred_r1 = lr_clf.predict(tdm_test_r1)

# %%
f1_train_r1_log=f1_score( y_train_r1, train_pred_r1, labels=None, pos_label=1, average='binary')
f1_test_r1_log=f1_score( y_test_r1, test_pred_r1, labels=None, pos_label=1, average='binary')
print(f1_train_r1_log)
print(f1_test_r1_log)
# Out:
# 0.9073288915808602
# 0.7461928934010152

# %%
from sklearn.linear_model import LogisticRegression
import warnings
warnings.filterwarnings("ignore")

#training the model
logreg = LogisticRegression()
lr_clf = logreg.fit(tfidf_train_r1,y_train_r1) #or mat which is in dense format can also be used

#prediction on train data
train_pred_r1 = lr_clf.predict(tfidf_train_r1)

#predicting on test data
test_pred_r1 = lr_clf.predict(tfidf_test_r1)

# %%
f1_train_r1_log=f1_score( y_train_r1, train_pred_r1, labels=None, pos_label=1, average='binary')
f1_test_r1_log=f1_score( y_test_r1, test_pred_r1, labels=None, pos_label=1, average='binary')
print(f1_train_r1_log)
print(f1_test_r1_log)
# Out:
# 0.9093167701863354
# 0.7239583333333333

# %% [markdown]
# #### random forest

# %%
from sklearn.feature_extraction.text import CountVectorizer
cv = CountVectorizer(stop_words="english",strip_accents="unicode",decode_error="ignore")
tdm_train_r = cv.fit_transform(X_train_r)
tdm_test_r = cv.transform(X_test_r)
tdm_final_test_dt=cv.transform(final_test_dt.Review)
##########################################################################################
from sklearn.feature_extraction.text import TfidfVectorizer
tfidf_vectorizer = TfidfVectorizer(ngram_range=(1,2))
tfidf_train_r = tfidf_vectorizer.fit_transform(X_train_r)
tfidf_test_r = tfidf_vectorizer.transform(X_test_r)
tfidf_final_test_dt = tfidf_vectorizer.transform(final_test_dt.Review)

# %%
#build a random forest classifiers
from sklearn.ensemble import RandomForestClassifier

rf = RandomForestClassifier()

# %%
rf_clf = rf.fit(tdm_train_r,y_train_r)
#prediction on train data
train_pred_r = rf_clf.predict(tdm_train_r)

#predicting on test data
test_pred_r = rf_clf.predict(tdm_test_r)

# %%
f1_train_r_rf=f1_score( y_train_r, train_pred_r, labels=None, pos_label=1, average='binary')
f1_test_r_rf=f1_score( y_test_r, test_pred_r, labels=None, pos_label=1, average='binary')
print(f1_train_r_rf)
print(f1_test_r_rf)
# Out:
# 0.9769094138543517
# 0.5754189944134079

# %%
rf_clf = rf.fit(tfidf_train_r,y_train_r)
#prediction on train data
train_pred_r = rf_clf.predict(tfidf_train_r)

#predicting on test data
test_pred_r = rf_clf.predict(tfidf_test_r)

# %%
f1_train_r_rf=f1_score( y_train_r, train_pred_r, labels=None, pos_label=1, average='binary')
f1_test_r_rf=f1_score( y_test_r, test_pred_r, labels=None, pos_label=1, average='binary')
print(f1_train_r_rf)
print(f1_test_r_rf)
# Out:
# 0.9707112970711297
# 0.513595166163142

# %% [markdown]
# #### svm/cv

# %%
from sklearn.feature_extraction.text import CountVectorizer
cv = CountVectorizer(stop_words="english",strip_accents="unicode",decode_error="ignore")
tdm_train_r = cv.fit_transform(X_train_r)
tdm_test_r = cv.transform(X_test_r)
tdm_final_test_dt=cv.transform(final_test_dt.Review)
##########################################################################################
from sklearn.feature_extraction.text import TfidfVectorizer
tfidf_vectorizer = TfidfVectorizer(ngram_range=(1,2))
tfidf_train_r = tfidf_vectorizer.fit_transform(X_train_r)
tfidf_test_r = tfidf_vectorizer.transform(X_test_r)
tfidf_final_test_dt = tfidf_vectorizer.transform(final_test_dt.Review)

# %%
## Build a SVM Classifier
from sklearn.svm import SVC

## Create an SVC object and print it to see the default arguments
svc = SVC()
svc
# Out:
# SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#     decision_function_shape='ovr', degree=3, gamma='auto_deprecated',
#     kernel='rbf', max_iter=-1, probability=False, random_state=None,
#     shrinking=True, tol=0.001, verbose=False)

# %%
svc_c10_rbf = SVC(C=10,kernel='rbf')
svc_c10_rbf
# Out:
# SVC(C=10, cache_size=200, class_weight=None, coef0=0.0,
#     decision_function_shape='ovr', degree=3, gamma='auto_deprecated',
#     kernel='rbf', max_iter=-1, probability=False, random_state=None,
#     shrinking=True, tol=0.001, verbose=False)

# %%
## Fit the model svc_c10_rbf on the train data (X_train,y_train)
svc_c10_rbf.fit(X = tdm_train_r,y = y_train_r)

#prediction on train data
train_pred_r = svc_c10_rbf.predict(tdm_train_r)

#predicting on test data
test_pred_r = svc_c10_rbf.predict(tdm_test_r)

# %%
f1_train_r_svc=f1_score( y_train_r, train_pred_r, labels=None, pos_label=1, average='binary')
f1_test_r_svc=f1_score( y_test_r, test_pred_r, labels=None, pos_label=1, average='binary')
print(f1_train_r_svc)
print(f1_test_r_svc)
# Out:
# 0.30531400966183575
# 0.2421875

# %% [markdown]
# #### Grid search on svc

# %%
## Use Grid Search for parameter tuning

from sklearn.model_selection import GridSearchCV

svc_grid = SVC()
 

param_grid = {

'C': [0.001, 0.01, 0.1, 1, 10],
'gamma': [0.001, 0.01, 0.1, 1], 
'kernel':['linear', 'poly', 'rbf', 'sigmoid']}

 
svc_cv_grid = GridSearchCV(estimator = svc_grid, param_grid = param_grid, cv = 10)

# %%
## Fit the grid search model
svc_cv_grid.fit(X = tfidf_train_r1, y = y_train_r1)

train_pred_r1 = svc_cv_grid.predict(tfidf_train_r1)

test_pred_r1 = svc_cv_grid.predict(tfidf_test_r1)

# %%
## Print best score and parameters
print(svc_cv_grid.best_score_,svc_cv_grid.best_params_)
# Out:
# 0.82875 {'C': 1, 'gamma': 0.001, 'kernel': 'linear'}

# %%
svc_clf_grid = SVC(C=10, gamma=0.001, kernel= 'linear')

# %%
## Fit the grid search model
svc_clf_grid.fit(X = tfidf_train_r1, y = y_train_r)

train_pred_r = svc_clf_grid.predict(tfidf_train_r1)

test_pred_r = svc_clf_grid.predict(tfidf_test_r1)

# %%
f1_train_r_svc=f1_score( y_train_r, train_pred_r, labels=None, pos_label=1, average='binary')
f1_test_r_svc=f1_score( y_test_r, test_pred_r, labels=None, pos_label=1, average='binary')
print(f1_train_r_svc)
print(f1_test_r_svc)
# Out:
# 0.9982507288629737
# 0.724220623501199

# %%
## Fit the grid search model
svc_cv_grid.fit(X = tfidf_train_r1, y = y_train_r1)

train_pred_r1_tf = svc_cv_grid.predict(tfidf_train_r1)

test_pred_r1_tf = svc_cv_grid.predict(tfidf_test_r1)

# %%
f1_train_r1_svc=f1_score( y_train_r1, train_pred_r1, labels=None, pos_label=1, average='binary')
f1_test_r1_svc=f1_score( y_test_r1, test_pred_r1, labels=None, pos_label=1, average='binary')
print(f1_train_r1_svc)
print(f1_test_r1_svc)
# Out:
# 0.8653500897666068
# 0.6257668711656441

# %%
## Print best score and parameters
print(svc_cv_grid.best_score_,svc_cv_grid.best_params_)
# Out:
# 0.8257777777777778 {'C': 10, 'gamma': 0.1, 'kernel': 'rbf'}

# %%
svc_clf_grid = SVC(C=7.1, gamma=0.1, kernel= 'rbf')

# %%
## Fit the grid search model
svc_clf_grid.fit(X = tfidf_train_r, y = y_train_r)

train_pred_r = svc_clf_grid.predict(tfidf_train_r)

test_pred_r = svc_clf_grid.predict(tfidf_test_r)

# %%
f1_train_r_svc=f1_score( y_train_r, train_pred_r, labels=None, pos_label=1, average='binary')
f1_test_r_svc=f1_score( y_test_r, test_pred_r, labels=None, pos_label=1, average='binary')
print(f1_train_r_svc)
print(f1_test_r_svc)
# Out:
# 0.9935785172212492
# 0.7835990888382689

# %%
final_test_ids_dt=pd.read_csv("test.csv")

# %%
tfidf_final_test_2= tfidf_vectorizer.transform(final_test_ids_dt)

# %%
final_predict_m=svc_clf_grid.predict(tfidf_final_test_dt)

# %%
final_predict_m
# Out:
# array([0, 0, 0, ..., 1, 0, 1])

# %%
pd.Series(final_predict_m).value_counts()
# Out:
# 0    878
# 1    322
# dtype: int64

# %%
final_test_dt.sample
# Out:
# <bound method NDFrame.sample of       ReviewID  \
# 0     92876
# 1     92877
# 2     92878
# 3     92879
# 4     92880
# ...     ...
# 1195  94071
# 1196  94072
# 1197  94073
# 1198  94074
# 1199  94075
#
#                                                                                                                                                                                                                                                                                                                      Review  \
# 0     Was good. Nothing like the original but I believe that was the point.
# 1     I absolutely loved it! A wonderful rendition of the original. Just dont compare to the cartoon version. Let this movie be its own and you will like it
# 2     I love the movie! Good job director! \nI appreciate all the work some great people have put in for years.
# 3     GREAT MOVIE!!  Same as the original, but the cinematography made a huge difference!!
# 4     Realistic.   Fantastic special effects
# ...                                      ...
# 1195  Best Disney movie ever!!!!
# 1196  They butchered almost everything that is loved In the originals....
# 1197  animals should have more facial expressions to what was going on .
# 1198  I love how they didnt really change much from the original movie.
# 1199  As an avid fan of the original, I waited in anticipation for this movie for months. CGI was well done. But everything else was a disappointment. I suppose when something is perfect as is (the original), it shouldn't be toyed with. The voices were just not as endearing and the overall emotin just wasnt there.
#
#                                                                                                                                                         review_processed_1
# 0     good nothing like original believe point
# 1     absolutely loved wonderful rendition original dont compare cartoon version movie like
# 2     love movie good director appreciate work great people year
# 3     great movie original cinematography made huge difference
# 4     realistic fantastic special effect
# ...                                  ...
# 1195  best disney movie ever
# 1196  butchered almost everything loved original
# 1197  animal facial expression going
# 1198  love didnt really change much original movie
# 1199  avid original waited anticipation movie month well done everything else disappointment suppose something perfect original toyed voice endearing overall emotin wasnt
#
# [1200 rows x 3 columns]>

# %%
final_test_dt['sentiment']=final_predict_m

f11=final_test_dt.drop(labels=['Review','review_processed_1'], axis=1)

f11.sample(20)

f11.to_csv("model27.csv",header=True,index=False)

# %% [markdown]
# ## review processed 1

# %%
from sklearn.model_selection import train_test_split
X_train_r2, X_test_r2, y_train_r2, y_test_r2 = train_test_split(lionking_dt['review_processed_1'],lionking_dt['sentiment'],test_size=0.20,random_state=123)

# %%
print(len(X_train_r2))
print(len(X_test_r2))
# Out:
# 2400
# 600

# %%
from sklearn.feature_extraction.text import CountVectorizer
cv = CountVectorizer(stop_words="english",strip_accents="unicode",decode_error="ignore")
tdm_train_r2 = cv.fit_transform(X_train_r2)
tdm_test_r2 = cv.transform(X_test_r2)

##########################################################################################
from sklearn.feature_extraction.text import TfidfVectorizer
tfidf_vectorizer = TfidfVectorizer(ngram_range=(1,2))
tfidf_train_r2 = tfidf_vectorizer.fit_transform(X_train_r2)
tfidf_test_r2 = tfidf_vectorizer.transform(X_test_r2)

# %%
from sklearn.linear_model import LogisticRegression
import warnings
warnings.filterwarnings("ignore")

#training the model
logreg = LogisticRegression()
lr_clf = logreg.fit(tdm_train_r2,y_train_r2) #or mat which is in dense format can also be used

#prediction on train data
train_pred_r2 = lr_clf.predict(tdm_train_r2)

#predicting on test data
test_pred_r2 = lr_clf.predict(tdm_test_r2)

# %%
print("train cfm :","\n", confusion_matrix(y_train_r2,train_pred_r2))
print("train cfm :","\n", confusion_matrix(y_test_r2,test_pred_r2))
# Out:
# train cfm :
#  [[1499   42]
#  [ 111  748]]
# train cfm :
#  [[334  48]
#  [ 73 145]]

# %%
f1_train_r2_log=f1_score( y_train_r2, train_pred_r2, labels=None, pos_label=1, average='binary')
f1_test_r2_log=f1_score( y_test_r2, test_pred_r2, labels=None, pos_label=1, average='binary')
print(f1_train_r2_log)
print(f1_test_r2_log)
# Out:
# 0.9072164948453609
# 0.7055961070559612

# %% [markdown]
# #### tfidf

# %%
from sklearn.feature_extraction.text import CountVectorizer
cv = CountVectorizer(stop_words="english",strip_accents="unicode",decode_error="ignore")
tdm_train_r2 = cv.fit_transform(X_train_r2)
tdm_test_r2 = cv.transform(X_test_r2)

##########################################################################################
from sklearn.feature_extraction.text import TfidfVectorizer
tfidf_vectorizer = TfidfVectorizer(ngram_range=(1,2))
tfidf_train_r2 = tfidf_vectorizer.fit_transform(X_train_r2)
tfidf_test_r2 = tfidf_vectorizer.transform(X_test_r2)

# %%
from sklearn.linear_model import LogisticRegression
import warnings
warnings.filterwarnings("ignore")

#training the model
logreg = LogisticRegression()
lr_clf = logreg.fit(tfidf_train_r2,y_train_r2) #or mat which is in dense format can also be used

#prediction on train data
train_pred_r2 = lr_clf.predict(tfidf_train_r2)

#predicting on test data
test_pred_r2 = lr_clf.predict(tfidf_test_r2)

# %%
print("train cfm :","\n", confusion_matrix(y_train_r2,train_pred_r2))
print("train cfm :","\n", confusion_matrix(y_test_r2,test_pred_r2))
# Out:
# train cfm :
#  [[1521   20]
#  [ 123  736]]
# train cfm :
#  [[346  36]
#  [ 87 131]]

# %%
f1_train_r2_log=f1_score( y_train_r2, train_pred_r2, labels=None, pos_label=1, average='binary')
f1_test_r2_log=f1_score( y_test_r2, test_pred_r2, labels=None, pos_label=1, average='binary')
print(f1_train_r2_log)
print(f1_test_r2_log)
# Out:
# 0.9114551083591331
# 0.6805194805194804

# %% [markdown]
# #### random forest

# %%
#build a random forest classifiers
from sklearn.ensemble import RandomForestClassifier

rf = RandomForestClassifier()

# %%
rf_clf = rf.fit(tdm_train_r2,y_train_r2)
#prediction on train data
train_pred_r2 = rf_clf.predict(tdm_train_r2)

#predicting on test data
test_predr2 = rf_clf.predict(tdm_test_r2)

# %%
f1_train_r2_rf=f1_score( y_train_r2, train_pred_r2, labels=None, pos_label=1, average='binary')
f1_test_r2_rf=f1_score( y_test_r2, test_pred_r2, labels=None, pos_label=1, average='binary')
print(f1_train_r2_rf)
print(f1_test_r2_rf)
# Out:
# 0.9775147928994083
# 0.6805194805194804

# %% [markdown]
# #### svm

# %%
## Build a SVM Classifier
from sklearn.svm import SVC

## Create an SVC object and print it to see the default arguments
svc = SVC()
svc
# Out:
# SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#     decision_function_shape='ovr', degree=3, gamma='auto_deprecated',
#     kernel='rbf', max_iter=-1, probability=False, random_state=None,
#     shrinking=True, tol=0.001, verbose=False)

# %%
svc_c10_rbf = SVC(C=10,kernel='rbf')
svc_c10_rbf
# Out:
# SVC(C=10, cache_size=200, class_weight=None, coef0=0.0,
#     decision_function_shape='ovr', degree=3, gamma='auto_deprecated',
#     kernel='rbf', max_iter=-1, probability=False, random_state=None,
#     shrinking=True, tol=0.001, verbose=False)

# %%
## Fit the model svc_c10_rbf on the train data (X_train,y_train)
svc_c10_rbf.fit(X = tdm_train_r2,y = y_train_r2)

#prediction on train data
train_pred_r2 = svc_c10_rbf.predict(tdm_train_r2)

#predicting on test data
test_pred_r2 = svc_c10_rbf.predict(tdm_test_r2)

# %%
f1_train_r2_svc=f1_score( y_train_r2, train_pred_r2, labels=None, pos_label=1, average='binary')
f1_test_r2_svc=f1_score( y_test_r2, test_pred_r2, labels=None, pos_label=1, average='binary')
print(f1_train_r2_svc)
print(f1_test_r2_svc)
# Out:
# 0.32887189292543023
# 0.234375

# %% [markdown]
# #### Grid search on svc

# %%
## Use Grid Search for parameter tuning

from sklearn.model_selection import GridSearchCV

svc_grid = SVC()
 

param_grid = {

'C': [0.001, 0.01, 0.1, 1, 10],
'gamma': [0.001, 0.01, 0.1, 1], 
'kernel':['linear', 'poly', 'rbf', 'sigmoid']}

 
svc_cv_grid = GridSearchCV(estimator = svc_grid, param_grid = param_grid, cv = 10)

# %%
## Fit the grid search model
svc_cv_grid.fit(X = tdm_train_r1, y = y_train_r1)

train_pred_r1 = svc_cv_grid.predict(tdm_train_r1)

test_pred_r1 = svc_cv_grid.predict(tdm_test_r1)

# %%
## Print best score and parameters
print(svc_cv_grid.best_score_,svc_cv_grid.best_params_)
# Out:
# 0.8093333333333333 {'C': 10, 'gamma': 0.01, 'kernel': 'rbf'}

# %%
svc_clf_grid = SVC(C=10, gamma=0.01, kernel= 'rbf')

# %%
## Fit the grid search model
svc_clf_grid.fit(X = tdm_train_r1, y = y_train_r1)

train_pred_r1 = svc_clf_grid.predict(tdm_train_r1)

test_pred_r1= svc_clf_grid.predict(tdm_test_r1)

# %%
f1_train_r2_svc=f1_score( y_train_r2, train_pred_r2, labels=None, pos_label=1, average='binary')
f1_test_r2_svc=f1_score( y_test_r2, test_pred_r2, labels=None, pos_label=1, average='binary')
print(f1_train_r2_svc)
print(f1_test_r2_svc)
# Out:
# 0.8902589395807645
# 0.7076923076923076

# %%
# ## Fit the grid search model
# svc_cv_grid.fit(X = tfidf_train_r1, y = y_train_r1)

# train_pred_r1_tf = svc_cv_grid.predict(tfidf_train_r1)

# test_pred_r1_tf = svc_cv_grid.predict(tfidf_test_r1)

# %%
f1_train_r_svc=f1_score( y_train_r1, train_pred_r1, labels=None, pos_label=1, average='binary')
f1_test_r_svc=f1_score( y_test_r1, test_pred_r1, labels=None, pos_label=1, average='binary')
print(f1_train_r_svc)
print(f1_test_r_svc)
# Out:
# 0.8899876390605685
# 0.7253886010362695

# %%
# ## Print best score and parameters
# print(svc_cv_grid.best_score_,svc_cv_grid.best_params_)
# Out:
# 0.8257777777777778 {'C': 10, 'gamma': 0.1, 'kernel': 'rbf'}

# %%
svc_clf_grid = SVC(C=10, gamma=0.1, kernel= 'rbf')

# %%
## Fit the grid search model
svc_clf_grid.fit(X = tfidf_train_r2, y = y_train_r2)

train_pred_r2_svc = svc_clf_grid.predict(tfidf_train_r2)

test_pred_r2_svc = svc_clf_grid.predict(tfidf_test_r2)

# %%
f1_train_r2_svc=f1_score( y_train_r2, train_pred_r2_svc, labels=None, pos_label=1, average='binary')
f1_test_r2_svc=f1_score( y_test_r2, test_pred_r2_svc, labels=None, pos_label=1, average='binary')
print(f1_train_r2_svc)
print(f1_test_r2_svc)
# Out:
# 0.9941724941724941
# 0.7327188940092166

# %% [markdown]
# ### review processed 3

# %%
from sklearn.model_selection import train_test_split
X_train_r3, X_test_r3, y_train_r3, y_test_r3 = train_test_split(train_text_dt['review_processed_3'],train_text_dt['sentiment'],test_size=0.25,random_state=123)

# %%
print(len(X_train_r3))
print(len(X_test_r3))
# Out:
# 2250
# 750

# %%
from sklearn.feature_extraction.text import CountVectorizer
cv = CountVectorizer(stop_words="english",strip_accents="unicode",decode_error="ignore")
tdm_train_r3 = cv.fit_transform(X_train_r3)
tdm_test_r3 = cv.transform(X_test_r3)

##########################################################################################
from sklearn.feature_extraction.text import TfidfVectorizer
tfidf_vectorizer = TfidfVectorizer(ngram_range=(1,2))
tfidf_train_r3 = tfidf_vectorizer.fit_transform(X_train_r3)
tfidf_test_r3 = tfidf_vectorizer.transform(X_test_r3)

# %%
from sklearn.linear_model import LogisticRegression
import warnings
warnings.filterwarnings("ignore")

#training the model
logreg = LogisticRegression()
lr_clf = logreg.fit(tdm_train_r3,y_train_r3) #or mat which is in dense format can also be used

#prediction on train data
train_pred_r3 = lr_clf.predict(tdm_train_r3)

#predicting on test data
test_pred_r3 = lr_clf.predict(tdm_test_r3)

# %%
print("train cfm :","\n", confusion_matrix(y_train_r3,train_pred_r3))
print("train cfm :","\n", confusion_matrix(y_test_r3,test_pred_r3))
# Out:
# train cfm :
#  [[1610   16]
#  [ 105  519]]
# train cfm :
#  [[511  40]
#  [ 87 112]]

# %%
f1_train_r3_log=f1_score( y_train_r3, train_pred_r3, labels=None, pos_label=1, average='binary')
f1_test_r3_log=f1_score( y_test_r3, test_pred_r3, labels=None, pos_label=1, average='binary')
print(f1_train_r3_log)
print(f1_test_r3_log)
# Out:
# 0.8955996548748921
# 0.6381766381766382

# %% [markdown]
# #### tfidf

# %%
from sklearn.model_selection import train_test_split
X_train_r3, X_test_r3, y_train_r3, y_test_r3 = train_test_split(train_text_dt['review_processed_3'],train_text_dt['sentiment'],test_size=0.25,random_state=123)

# %%
print(len(X_train_r3))
print(len(X_test_r3))
# Out:
# 2250
# 750

# %%
from sklearn.feature_extraction.text import CountVectorizer
cv = CountVectorizer(stop_words="english",strip_accents="unicode",decode_error="ignore")
tdm_train_r3 = cv.fit_transform(X_train_r3)
tdm_test_r3 = cv.transform(X_test_r3)

##########################################################################################
from sklearn.feature_extraction.text import TfidfVectorizer
tfidf_vectorizer = TfidfVectorizer(ngram_range=(1,2))
tfidf_train_r3 = tfidf_vectorizer.fit_transform(X_train_r3)
tfidf_test_r3 = tfidf_vectorizer.transform(X_test_r3)

# %%
from sklearn.linear_model import LogisticRegression
import warnings
warnings.filterwarnings("ignore")

#training the model
logreg = LogisticRegression()
lr_clf = logreg.fit(tfidf_train_r3,y_train_r3) #or mat which is in dense format can also be used

#prediction on train data
train_pred_r3 = lr_clf.predict(tfidf_train_r3)

#predicting on test data
test_pred_r3 = lr_clf.predict(tfidf_test_r3)

# %%
print("train cfm :","\n", confusion_matrix(y_train_r3,train_pred_r3))
print("train cfm :","\n", confusion_matrix(y_test_r3,test_pred_r3))
# Out:
# train cfm :
#  [[1622    4]
#  [ 259  365]]
# train cfm :
#  [[537  14]
#  [132  67]]

# %%
f1_train_r3_log=f1_score( y_train_r3, train_pred_r3, labels=None, pos_label=1, average='binary')
f1_test_r3_log=f1_score( y_test_r3, test_pred_r3, labels=None, pos_label=1, average='binary')
print(f1_train_r3_log)
print(f1_test_r3_log)
# Out:
# 0.7351460221550856
# 0.47857142857142865

# %% [markdown]
# #### random forest

# %%
#build a random forest classifiers
from sklearn.ensemble import RandomForestClassifier

rf = RandomForestClassifier()

# %%
rf_clf = rf.fit(tdm_train_r3,y_train_r3)
#prediction on train data
train_pred_r3 = rf_clf.predict(tdm_train_r3)

#predicting on test data
test_pred_r3 = rf_clf.predict(tdm_test_r3)

# %%
f1_train_r3_rf=f1_score( y_train_r3, train_pred_r3, labels=None, pos_label=1, average='binary')
f1_test_r3_rf=f1_score( y_test_r3, test_pred_r3, labels=None, pos_label=1, average='binary')
print(f1_train_r3_rf)
print(f1_test_r3_rf)
# Out:
# 0.9713349713349713
# 0.47741935483870973

# %% [markdown]
# #### svm

# %%
## Build a SVM Classifier
from sklearn.svm import SVC

## Create an SVC object and print it to see the default arguments
svc = SVC()
svc
# Out:
# SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#     decision_function_shape='ovr', degree=3, gamma='auto_deprecated',
#     kernel='rbf', max_iter=-1, probability=False, random_state=None,
#     shrinking=True, tol=0.001, verbose=False)

# %%
svc_c10_rbf = SVC(C=10,kernel='rbf')
svc_c10_rbf
# Out:
# SVC(C=10, cache_size=200, class_weight=None, coef0=0.0,
#     decision_function_shape='ovr', degree=3, gamma='auto_deprecated',
#     kernel='rbf', max_iter=-1, probability=False, random_state=None,
#     shrinking=True, tol=0.001, verbose=False)

# %%
## Fit the model svc_c10_rbf on the train data (X_train,y_train)
svc_c10_rbf.fit(X = tdm_train_r3,y = y_train_r3)

#prediction on train data
train_pred_r3 = svc_c10_rbf.predict(tdm_train_r3)

#predicting on test data
test_pred_r3 = svc_c10_rbf.predict(tdm_test_r3)

# %%
f1_train_r3_svc=f1_score( y_train_r3, train_pred_r3, labels=None, pos_label=1, average='binary')
f1_test_r3_svc=f1_score( y_test_r3, test_pred_r3, labels=None, pos_label=1, average='binary')
print(f1_train_r3_svc)
print(f1_test_r3_svc)
# Out:
# 0.16593886462882096
# 0.12962962962962962

# %% [markdown]
# #### Grid search on svc

# %%
## Use Grid Search for parameter tuning

from sklearn.model_selection import GridSearchCV

svc_grid = SVC()
 

param_grid = {

'C': [0.001, 0.01, 0.1, 1, 10],
'gamma': [0.001, 0.01, 0.1, 1], 
'kernel':['linear', 'poly', 'rbf', 'sigmoid']}

 
svc_cv_grid = GridSearchCV(estimator = svc_grid, param_grid = param_grid, cv = 10)

# %%
# ## Fit the grid search model
# svc_cv_grid.fit(X = tdm_train_r3, y = y_train_r3)

# train_pred_r3 = svc_cv_grid.predict(tdm_train_r3)

# test_pred_r3 = svc_cv_grid.predict(tdm_test_r3)

# %%
# ## Print best score and parameters
# print(svc_cv_grid.best_score_,svc_cv_grid.best_params_)
# Out:
# 0.8093333333333333 {'C': 10, 'gamma': 0.01, 'kernel': 'rbf'}

# %%
svc_clf_grid = SVC(C=10, gamma=0.01, kernel= 'rbf')

# %%
## Fit the grid search model
svc_clf_grid.fit(X = tdm_train_r3, y = y_train_r3)

train_pred_r3 = svc_clf_grid.predict(tdm_train_r3)

test_pred_r3 = svc_clf_grid.predict(tdm_test_r3)

# %%
f1_train_r3_svc=f1_score( y_train_r3, train_pred_r3, labels=None, pos_label=1, average='binary')
f1_test_r3_svc=f1_score( y_test_r3, test_pred_r3, labels=None, pos_label=1, average='binary')
print(f1_train_r3_svc)
print(f1_test_r3_svc)
# Out:
# 0.875886524822695
# 0.6312684365781711

# %%
# ## Fit the grid search model
# svc_cv_grid.fit(X = tfidf_train_r1, y = y_train_r1)

# train_pred_r1_tf = svc_cv_grid.predict(tfidf_train_r1)

# test_pred_r1_tf = svc_cv_grid.predict(tfidf_test_r1)

# %%
# f1_train_r1_svc=f1_score( y_train_r1, train_pred_r1, labels=None, pos_label=1, average='binary')
# f1_test_r1_svc=f1_score( y_test_r1, test_pred_r1, labels=None, pos_label=1, average='binary')
# print(f1_train_r1_svc)
# print(f1_test_r1_svc)
# Out:
# 0.8653500897666068
# 0.6257668711656441

# %%
# ## Print best score and parameters
# print(svc_cv_grid.best_score_,svc_cv_grid.best_params_)
# Out:
# 0.8257777777777778 {'C': 10, 'gamma': 0.1, 'kernel': 'rbf'}

# %%
svc_clf_grid = SVC(C=8, gamma=0.1, kernel= 'rbf')

# %%
## Fit the grid search model
svc_clf_grid.fit(X = tfidf_train_r3, y = y_train_r3)

train_pred_r3_svc = svc_clf_grid.predict(tfidf_train_r3)

test_pred_r3_svc = svc_clf_grid.predict(tfidf_test_r3)

# %%
f1_train_r3_svc=f1_score( y_train_r3, train_pred_r3_svc, labels=None, pos_label=1, average='binary')
f1_test_r3_svc=f1_score( y_test_r3, test_pred_r3_svc, labels=None, pos_label=1, average='binary')
print(f1_train_r3_svc)
print(f1_test_r3_svc)
# Out:
# 0.9952
# 0.7379679144385026

# %% [markdown]
# ### review

# %%
from sklearn.model_selection import train_test_split
X_train_r, X_test_r, y_train_r, y_test_r = train_test_split(train_text_dt['review'],train_text_dt['sentiment'],test_size=0.25,random_state=123)

# %%
print(len(X_train_r))
print(len(X_test_r))
# Out:
# 2250
# 750

# %%
from sklearn.feature_extraction.text import CountVectorizer
cv = CountVectorizer(stop_words="english",strip_accents="unicode",decode_error="ignore")
tdm_train_r = cv.fit_transform(X_train_r)
tdm_test_r = cv.transform(X_test_r)

##########################################################################################
from sklearn.feature_extraction.text import TfidfVectorizer
tfidf_vectorizer = TfidfVectorizer(ngram_range=(1,2))
tfidf_train_r = tfidf_vectorizer.fit_transform(X_train_r)
tfidf_test_r = tfidf_vectorizer.transform(X_test_r)

# %%
from sklearn.linear_model import LogisticRegression
import warnings
warnings.filterwarnings("ignore")

#training the model
logreg = LogisticRegression()
lr_clf = logreg.fit(tdm_train_r,y_train_r) #or mat which is in dense format can also be used

#prediction on train data
train_pred_r = lr_clf.predict(tdm_train_r)

#predicting on test data
test_pred_r = lr_clf.predict(tdm_test_r)

# %%
print("train cfm :","\n", confusion_matrix(y_train_r,train_pred_r))
print("train cfm :","\n", confusion_matrix(y_test_r,test_pred_r))
# Out:
# train cfm :
#  [[1610   16]
#  [ 105  519]]
# train cfm :
#  [[511  40]
#  [ 87 112]]

# %%
f1_train_r_log=f1_score( y_train_r, train_pred_r, labels=None, pos_label=1, average='binary')
f1_test_r_log=f1_score( y_test_r, test_pred_r, labels=None, pos_label=1, average='binary')
print(f1_train_r_log)
print(f1_test_r_log)
# Out:
# 0.8955996548748921
# 0.6381766381766382

# %% [markdown]
# #### tfidf

# %%
from sklearn.model_selection import train_test_split
X_train_r, X_test_r, y_train_r, y_test_r = train_test_split(train_text_dt['review'],train_text_dt['sentiment'],test_size=0.25,random_state=123)

# %%
print(len(X_train_r))
print(len(X_test_r))
# Out:
# 2250
# 750

# %%
from sklearn.feature_extraction.text import CountVectorizer
cv = CountVectorizer(stop_words="english",strip_accents="unicode",decode_error="ignore")
tdm_train_r = cv.fit_transform(X_train_r)
tdm_test_r = cv.transform(X_test_r)

##########################################################################################
from sklearn.feature_extraction.text import TfidfVectorizer
tfidf_vectorizer = TfidfVectorizer(ngram_range=(1,2))
tfidf_train_r = tfidf_vectorizer.fit_transform(X_train_r)
tfidf_test_r = tfidf_vectorizer.transform(X_test_r)

# %%
from sklearn.linear_model import LogisticRegression
import warnings
warnings.filterwarnings("ignore")

#training the model
logreg = LogisticRegression()
lr_clf = logreg.fit(tfidf_train_r,y_train_r) #or mat which is in dense format can also be used

#prediction on train data
train_pred_r = lr_clf.predict(tfidf_train_r)

#predicting on test data
test_pred_r = lr_clf.predict(tfidf_test_r)

# %%
print("train cfm :","\n", confusion_matrix(y_train_r,train_pred_r))
print("train cfm :","\n", confusion_matrix(y_test_r,test_pred_r))
# Out:
# train cfm :
#  [[1622    4]
#  [ 259  365]]
# train cfm :
#  [[537  14]
#  [132  67]]

# %%
f1_train_r_log=f1_score( y_train_r, train_pred_r, labels=None, pos_label=1, average='binary')
f1_test_r_log=f1_score( y_test_r, test_pred_r, labels=None, pos_label=1, average='binary')
print(f1_train_r_log)
print(f1_test_r_log)
# Out:
# 0.7351460221550856
# 0.47857142857142865

# %% [markdown]
# #### random forest

# %%
#build a random forest classifiers
from sklearn.ensemble import RandomForestClassifier

rf = RandomForestClassifier()

# %%
rf_clf = rf.fit(tdm_train_r,y_train_r)
#prediction on train data
train_pred_r = rf_clf.predict(tdm_train_r)

#predicting on test data
test_pred_r = rf_clf.predict(tdm_test_r)

# %%
f1_train_r_rf=f1_score( y_train_r, train_pred_r, labels=None, pos_label=1, average='binary')
f1_test_r_rf=f1_score( y_test_r, test_pred_r, labels=None, pos_label=1, average='binary')
print(f1_train_r_rf)
print(f1_test_r_rf)
# Out:
# 0.9617940199335548
# 0.47297297297297297

# %% [markdown]
# #### svm

# %%
## Build a SVM Classifier
from sklearn.svm import SVC

## Create an SVC object and print it to see the default arguments
svc = SVC()
svc
# Out:
# SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#     decision_function_shape='ovr', degree=3, gamma='auto_deprecated',
#     kernel='rbf', max_iter=-1, probability=False, random_state=None,
#     shrinking=True, tol=0.001, verbose=False)

# %%
svc_c10_rbf = SVC(C=10,kernel='rbf')
svc_c10_rbf
# Out:
# SVC(C=10, cache_size=200, class_weight=None, coef0=0.0,
#     decision_function_shape='ovr', degree=3, gamma='auto_deprecated',
#     kernel='rbf', max_iter=-1, probability=False, random_state=None,
#     shrinking=True, tol=0.001, verbose=False)

# %%
## Fit the model svc_c10_rbf on the train data (X_train,y_train)
svc_c10_rbf.fit(X = tdm_train_r,y = y_train_r)

#prediction on train data
train_pred_r = svc_c10_rbf.predict(tdm_train_r)

#predicting on test data
test_pred_r = svc_c10_rbf.predict(tdm_test_r)

# %%
f1_train_r_svc=f1_score( y_train_r, train_pred_r, labels=None, pos_label=1, average='binary')
f1_test_r_svc=f1_score( y_test_r, test_pred_r, labels=None, pos_label=1, average='binary')
print(f1_train_r_svc)
print(f1_test_r_svc)
# Out:
# 0.16593886462882096
# 0.12962962962962962
